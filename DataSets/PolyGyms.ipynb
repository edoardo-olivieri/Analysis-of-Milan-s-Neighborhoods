# %%
import pandas as pd
import geopandas as gpd
import requests
import time
from shapely.geometry import Point
from geopandas.tools import sjoin

# %%
# Import of the Polygons
gdf_combined = gpd.read_file("C:/Users/edoar/combined_quartieri.geojson")

# %% [markdown]
# # API di YELP

# %%
neighborhoods = [f"{name}, Milan" for name in gdf_combined["Neighborhood"].tolist()]
neighborhoods
# Out:
# ['Parco delle Abbazie, Milan',
#  'Adriano, Milan',
#  'Affori, Milan',
#  'Baggio, Milan',
#  'Bande Nere, Milan',
#  'Barona, Milan',
#  'Bicocca, Milan',
#  'Bovisasca, Milan',
#  'Bovisa, Milan',
#  'Brera, Milan',
#  'Bruzzano, Milan',
#  'Buenos Aires - Venezia, Milan',
#  'Cantalupa, Milan',
#  'Cascina Triulza - Expo, Milan',
#  'Centrale, Milan',
#  'Chiaravalle, Milan',
#  'Città Studi, Milan',
#  'Comasina, Milan',
#  'Corsica, Milan',
#  'De Angeli - Monte Rosa, Milan',
#  'Dergano, Milan',
#  'Duomo, Milan',
#  'Ex Om - Morivione, Milan',
#  'Farini, Milan',
#  'GARIBALDI REPUBBLICA, Milan',
#  'Gallaratese, Milan',
#  'Ghisolfa, Milan',
#  'Giambellino, Milan',
#  'Giardini Porta Venezia, Milan',
#  'Gratosoglio - Ticinello, Milan',
#  'Greco, Milan',
#  'Guastalla, Milan',
#  'Isola, Milan',
#  'Lambrate, Milan',
#  'Lodi - Corvetto, Milan',
#  'Lorenteggio, Milan',
#  'Loreto, Milan',
#  'Maciachini - Maggiolina, Milan',
#  'Magenta - San Vittore, Milan',
#  'Maggiore - Musocco, Milan',
#  'Mecenate, Milan',
#  'Muggiano, Milan',
#  'Navigli, Milan',
#  'Niguarda - Cà Granda, Milan',
#  'Ortomercato, Milan',
#  'Padova, Milan',
#  'Pagano, Milan',
#  'Parco Agricolo Sud, Milan',
#  'Parco Bosco In Città, Milan',
#  'Parco Forlanini - Ortica, Milan',
#  'Parco Lambro - Cimiano, Milan',
#  'Parco Monluè - Ponte Lambro, Milan',
#  'Parco Nord, Milan',
#  'Parco Sempione, Milan',
#  'Parco dei Navigli, Milan',
#  'Porta Romana, Milan',
#  'Portello, Milan',
#  'Qt 8, Milan',
#  'Quarto Cagnino, Milan',
#  'Quinto Romano, Milan',
#  'Quintosole, Milan',
#  'Ripamonti, Milan',
#  'Rogoredo, Milan',
#  'Ronchetto Sul Naviglio, Milan',
#  'Ronchetto delle Rane, Milan',
#  'San Cristoforo, Milan',
#  'San Siro, Milan',
#  'Sarpi, Milan',
#  'Scalo Romana, Milan',
#  'Selinunte, Milan',
#  'Stadera, Milan',
#  'Stephenson, Milan',
#  'Tibaldi, Milan',
#  'Ticinese, Milan',
#  'Tortona, Milan',
#  'Tre Torri, Milan',
#  'Trenno, Milan',
#  'Triulzo Superiore, Milan',
#  'Umbria - Molise, Milan',
#  'Viale Monza, Milan',
#  'Vigentina, Milan',
#  'Villapizzone, Milan',
#  'Washington, Milan',
#  'XXII Marzo, Milan',
#  'Forze Armate, Milan']

# %%
# Replace with your Yelp API key
API_KEY = "6CbFJGYPopltfBbkb00hIFGRI4XBrAsccPevTJ53ol4YIuJrF48kEylTmKvEl4-TEP8p0pEc3ydzUsatpgGI5aqSHCsysi5-yWyeJD3V-6al5x6_AcFkw23LehKEZ3Yx"
HEADERS = {"Authorization": f"Bearer {API_KEY}"}

# Constants
businesses_per_request = 48  # Maximum allowed by Yelp per request

def make_request(url, params=None):
    """
    Makes a request to the Yelp API.
    """
    response = requests.get(url, headers=HEADERS, params=params)
    response.raise_for_status()
    return response

def search_businesses(location, term="gym", limit=businesses_per_request, offset=0):
    """
    Searches for businesses (gyms) in a given location with pagination.
    """
    url = "https://api.yelp.com/v3/businesses/search"
    params = {
        "location": location,  # Neighborhood or address
        "term": term,  # Use "gym" or "palestre"
        "limit": limit,
        "offset": offset
    }
    response = make_request(url, params=params)
    return response.json().get("businesses", [])

# Initialize data storage
data = []

try:
    for neighborhood in neighborhoods:  # Loop through each neighborhood
        offset = 0
        while True:  # Keep fetching data until no more results
            print(f"Fetching gyms in {neighborhood} with offset: {offset}...")

            try:
                # Fetch businesses using the current offset and location
                businesses = search_businesses(location=neighborhood, term="gym", limit=businesses_per_request, offset=offset)

                if not businesses:
                    # No more gyms to fetch
                    print(f"No more gyms returned for {neighborhood}.")
                    break

                for biz in businesses:
                    name = biz.get("name", "N/A")
                    location_info = biz.get("location", {})
                    address = location_info.get("address1", "N/A")
                    categories = biz.get("categories", [])
                    category_list = [cat.get("title", "") for cat in categories if cat.get("title")]
                    category_str = ", ".join(category_list) if category_list else "N/A"
                    rating = biz.get("rating", "N/A")
                    review_count = biz.get("review_count", "N/A")

                    # Extract coordinates
                    coordinates = biz.get("coordinates", {})
                    latitude = coordinates.get("latitude", None)
                    longitude = coordinates.get("longitude", None)

                    # Append to data
                    data.append({
                        "Fetch Location": neighborhood,
                        "Gym Name": name,
                        "Gym Address": address,
                        "Categories": category_str,
                        "Average Star Rating": rating,
                        "Review Count": review_count,
                        "Latitude": latitude,
                        "Longitude": longitude
                    })

                # Increment offset for the next batch
                offset += len(businesses)

                # Optional: Sleep to respect API rate limits
                time.sleep(0.5)

                # Break if the offset exceeds Yelp's maximum results per query
                if offset >= 240:  # Maximum 240 results per query
                    print(f"Reached maximum results for {neighborhood}.")
                    break

            except requests.HTTPError as he:
                # Log the error and skip this neighborhood
                print(f"HTTP error occurred for {neighborhood}: {he}")
                break

    # Convert the collected data into a DataFrame
    df = pd.DataFrame(data)

    # Convert DataFrame to GeoDataFrame
    df["geometry"] = df.apply(
        lambda row: Point(row["Longitude"], row["Latitude"]) if row["Longitude"] and row["Latitude"] else None,
        axis=1
    )
    Gyms = gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:4326")

    # Print summary
    print(Gyms.head())
    print(f"Total gyms collected: {len(data)}")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Fetching gyms in Parco delle Abbazie, Milan with offset: 0...
# Fetching gyms in Parco delle Abbazie, Milan with offset: 48...
# Fetching gyms in Parco delle Abbazie, Milan with offset: 96...
# Fetching gyms in Parco delle Abbazie, Milan with offset: 144...
# Fetching gyms in Parco delle Abbazie, Milan with offset: 192...
# Reached maximum results for Parco delle Abbazie, Milan.
# Fetching gyms in Adriano, Milan with offset: 0...
# HTTP error occurred for Adriano, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Adriano%2C+Milan&term=gym&limit=48&offset=0
# Fetching gyms in Affori, Milan with offset: 0...
# Fetching gyms in Affori, Milan with offset: 48...
# Fetching gyms in Affori, Milan with offset: 93...
# No more gyms returned for Affori, Milan.
# Fetching gyms in Baggio, Milan with offset: 0...
# Fetching gyms in Baggio, Milan with offset: 48...
# Fetching gyms in Baggio, Milan with offset: 96...
# Fetching gyms in Baggio, Milan with offset: 144...
# Fetching gyms in Baggio, Milan with offset: 192...
# Reached maximum results for Baggio, Milan.
# Fetching gyms in Bande Nere, Milan with offset: 0...
# Fetching gyms in Bande Nere, Milan with offset: 48...
# Fetching gyms in Bande Nere, Milan with offset: 96...
# Fetching gyms in Bande Nere, Milan with offset: 109...
# No more gyms returned for Bande Nere, Milan.
# Fetching gyms in Barona, Milan with offset: 0...
# Fetching gyms in Barona, Milan with offset: 21...
# No more gyms returned for Barona, Milan.
# Fetching gyms in Bicocca, Milan with offset: 0...
# Fetching gyms in Bicocca, Milan with offset: 48...
# Fetching gyms in Bicocca, Milan with offset: 96...
# Fetching gyms in Bicocca, Milan with offset: 144...
# Fetching gyms in Bicocca, Milan with offset: 192...
# Reached maximum results for Bicocca, Milan.
# Fetching gyms in Bovisasca, Milan with offset: 0...
# Fetching gyms in Bovisasca, Milan with offset: 48...
# Fetching gyms in Bovisasca, Milan with offset: 60...
# No more gyms returned for Bovisasca, Milan.
# Fetching gyms in Bovisa, Milan with offset: 0...
# Fetching gyms in Bovisa, Milan with offset: 48...
# Fetching gyms in Bovisa, Milan with offset: 96...
# Fetching gyms in Bovisa, Milan with offset: 137...
# No more gyms returned for Bovisa, Milan.
# Fetching gyms in Brera, Milan with offset: 0...
# Fetching gyms in Brera, Milan with offset: 48...
# Fetching gyms in Brera, Milan with offset: 96...
# Fetching gyms in Brera, Milan with offset: 115...
# No more gyms returned for Brera, Milan.
# Fetching gyms in Bruzzano, Milan with offset: 0...
# Fetching gyms in Bruzzano, Milan with offset: 11...
# No more gyms returned for Bruzzano, Milan.
# Fetching gyms in Buenos Aires - Venezia, Milan with offset: 0...
# Fetching gyms in Buenos Aires - Venezia, Milan with offset: 48...
# Fetching gyms in Buenos Aires - Venezia, Milan with offset: 96...
# Fetching gyms in Buenos Aires - Venezia, Milan with offset: 144...
# Fetching gyms in Buenos Aires - Venezia, Milan with offset: 192...
# Reached maximum results for Buenos Aires - Venezia, Milan.
# Fetching gyms in Cantalupa, Milan with offset: 0...
# Fetching gyms in Cantalupa, Milan with offset: 48...
# Fetching gyms in Cantalupa, Milan with offset: 96...
# Fetching gyms in Cantalupa, Milan with offset: 144...
# Fetching gyms in Cantalupa, Milan with offset: 192...
# Reached maximum results for Cantalupa, Milan.
# Fetching gyms in Cascina Triulza - Expo, Milan with offset: 0...
# Fetching gyms in Cascina Triulza - Expo, Milan with offset: 48...
# Fetching gyms in Cascina Triulza - Expo, Milan with offset: 96...
# Fetching gyms in Cascina Triulza - Expo, Milan with offset: 144...
# Fetching gyms in Cascina Triulza - Expo, Milan with offset: 192...
# Fetching gyms in Cascina Triulza - Expo, Milan with offset: 213...
# HTTP error occurred for Cascina Triulza - Expo, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Cascina+Triulza+-+Expo%2C+Milan&term=gym&limit=48&offset=213
# Fetching gyms in Centrale, Milan with offset: 0...
# Fetching gyms in Centrale, Milan with offset: 48...
# Fetching gyms in Centrale, Milan with offset: 92...
# No more gyms returned for Centrale, Milan.
# Fetching gyms in Chiaravalle, Milan with offset: 0...
# Fetching gyms in Chiaravalle, Milan with offset: 48...
# Fetching gyms in Chiaravalle, Milan with offset: 96...
# Fetching gyms in Chiaravalle, Milan with offset: 144...
# Fetching gyms in Chiaravalle, Milan with offset: 159...
# No more gyms returned for Chiaravalle, Milan.
# Fetching gyms in Città Studi, Milan with offset: 0...
# Fetching gyms in Città Studi, Milan with offset: 48...
# Fetching gyms in Città Studi, Milan with offset: 96...
# Fetching gyms in Città Studi, Milan with offset: 144...
# Fetching gyms in Città Studi, Milan with offset: 189...
# No more gyms returned for Città Studi, Milan.
# Fetching gyms in Comasina, Milan with offset: 0...
# Fetching gyms in Comasina, Milan with offset: 48...
# Fetching gyms in Comasina, Milan with offset: 96...
# Fetching gyms in Comasina, Milan with offset: 144...
# Fetching gyms in Comasina, Milan with offset: 192...
# Reached maximum results for Comasina, Milan.
# Fetching gyms in Corsica, Milan with offset: 0...
# Fetching gyms in Corsica, Milan with offset: 31...
# No more gyms returned for Corsica, Milan.
# Fetching gyms in De Angeli - Monte Rosa, Milan with offset: 0...
# HTTP error occurred for De Angeli - Monte Rosa, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=De+Angeli+-+Monte+Rosa%2C+Milan&term=gym&limit=48&offset=0
# Fetching gyms in Dergano, Milan with offset: 0...
# Fetching gyms in Dergano, Milan with offset: 32...
# No more gyms returned for Dergano, Milan.
# Fetching gyms in Duomo, Milan with offset: 0...
# Fetching gyms in Duomo, Milan with offset: 48...
# Fetching gyms in Duomo, Milan with offset: 96...
# Fetching gyms in Duomo, Milan with offset: 144...
# Fetching gyms in Duomo, Milan with offset: 192...
# Reached maximum results for Duomo, Milan.
# Fetching gyms in Ex Om - Morivione, Milan with offset: 0...
# Fetching gyms in Ex Om - Morivione, Milan with offset: 48...
# Fetching gyms in Ex Om - Morivione, Milan with offset: 96...
# Fetching gyms in Ex Om - Morivione, Milan with offset: 144...
# Fetching gyms in Ex Om - Morivione, Milan with offset: 192...
# Reached maximum results for Ex Om - Morivione, Milan.
# Fetching gyms in Farini, Milan with offset: 0...
# Fetching gyms in Farini, Milan with offset: 48...
# Fetching gyms in Farini, Milan with offset: 58...
# No more gyms returned for Farini, Milan.
# Fetching gyms in GARIBALDI REPUBBLICA, Milan with offset: 0...
# Fetching gyms in GARIBALDI REPUBBLICA, Milan with offset: 48...
# Fetching gyms in GARIBALDI REPUBBLICA, Milan with offset: 96...
# Fetching gyms in GARIBALDI REPUBBLICA, Milan with offset: 144...
# Fetching gyms in GARIBALDI REPUBBLICA, Milan with offset: 192...
# Reached maximum results for GARIBALDI REPUBBLICA, Milan.
# Fetching gyms in Gallaratese, Milan with offset: 0...
# Fetching gyms in Gallaratese, Milan with offset: 48...
# Fetching gyms in Gallaratese, Milan with offset: 94...
# No more gyms returned for Gallaratese, Milan.
# Fetching gyms in Ghisolfa, Milan with offset: 0...
# Fetching gyms in Ghisolfa, Milan with offset: 42...
# No more gyms returned for Ghisolfa, Milan.
# Fetching gyms in Giambellino, Milan with offset: 0...
# Fetching gyms in Giambellino, Milan with offset: 48...
# Fetching gyms in Giambellino, Milan with offset: 96...
# Fetching gyms in Giambellino, Milan with offset: 144...
# Fetching gyms in Giambellino, Milan with offset: 149...
# No more gyms returned for Giambellino, Milan.
# Fetching gyms in Giardini Porta Venezia, Milan with offset: 0...
# Fetching gyms in Giardini Porta Venezia, Milan with offset: 48...
# Fetching gyms in Giardini Porta Venezia, Milan with offset: 96...
# Fetching gyms in Giardini Porta Venezia, Milan with offset: 144...
# Fetching gyms in Giardini Porta Venezia, Milan with offset: 192...
# Reached maximum results for Giardini Porta Venezia, Milan.
# Fetching gyms in Gratosoglio - Ticinello, Milan with offset: 0...
# Fetching gyms in Gratosoglio - Ticinello, Milan with offset: 48...
# Fetching gyms in Gratosoglio - Ticinello, Milan with offset: 96...
# Fetching gyms in Gratosoglio - Ticinello, Milan with offset: 144...
# Fetching gyms in Gratosoglio - Ticinello, Milan with offset: 192...
# Reached maximum results for Gratosoglio - Ticinello, Milan.
# Fetching gyms in Greco, Milan with offset: 0...
# Fetching gyms in Greco, Milan with offset: 48...
# Fetching gyms in Greco, Milan with offset: 96...
# Fetching gyms in Greco, Milan with offset: 144...
# Fetching gyms in Greco, Milan with offset: 151...
# No more gyms returned for Greco, Milan.
# Fetching gyms in Guastalla, Milan with offset: 0...
# Fetching gyms in Guastalla, Milan with offset: 48...
# Fetching gyms in Guastalla, Milan with offset: 96...
# Fetching gyms in Guastalla, Milan with offset: 101...
# No more gyms returned for Guastalla, Milan.
# Fetching gyms in Isola, Milan with offset: 0...
# Fetching gyms in Isola, Milan with offset: 16...
# No more gyms returned for Isola, Milan.
# Fetching gyms in Lambrate, Milan with offset: 0...
# Fetching gyms in Lambrate, Milan with offset: 48...
# Fetching gyms in Lambrate, Milan with offset: 96...
# Fetching gyms in Lambrate, Milan with offset: 118...
# No more gyms returned for Lambrate, Milan.
# Fetching gyms in Lodi - Corvetto, Milan with offset: 0...
# Fetching gyms in Lodi - Corvetto, Milan with offset: 48...
# Fetching gyms in Lodi - Corvetto, Milan with offset: 96...
# Fetching gyms in Lodi - Corvetto, Milan with offset: 144...
# Fetching gyms in Lodi - Corvetto, Milan with offset: 159...
# No more gyms returned for Lodi - Corvetto, Milan.
# Fetching gyms in Lorenteggio, Milan with offset: 0...
# Fetching gyms in Lorenteggio, Milan with offset: 48...
# Fetching gyms in Lorenteggio, Milan with offset: 96...
# Fetching gyms in Lorenteggio, Milan with offset: 144...
# Fetching gyms in Lorenteggio, Milan with offset: 149...
# No more gyms returned for Lorenteggio, Milan.
# Fetching gyms in Loreto, Milan with offset: 0...
# Fetching gyms in Loreto, Milan with offset: 48...
# Fetching gyms in Loreto, Milan with offset: 66...
# No more gyms returned for Loreto, Milan.
# Fetching gyms in Maciachini - Maggiolina, Milan with offset: 0...
# Fetching gyms in Maciachini - Maggiolina, Milan with offset: 48...
# Fetching gyms in Maciachini - Maggiolina, Milan with offset: 57...
# No more gyms returned for Maciachini - Maggiolina, Milan.
# Fetching gyms in Magenta - San Vittore, Milan with offset: 0...
# Fetching gyms in Magenta - San Vittore, Milan with offset: 48...
# Fetching gyms in Magenta - San Vittore, Milan with offset: 96...
# No more gyms returned for Magenta - San Vittore, Milan.
# Fetching gyms in Maggiore - Musocco, Milan with offset: 0...
# Fetching gyms in Maggiore - Musocco, Milan with offset: 48...
# Fetching gyms in Maggiore - Musocco, Milan with offset: 96...
# Fetching gyms in Maggiore - Musocco, Milan with offset: 144...
# Fetching gyms in Maggiore - Musocco, Milan with offset: 192...
# Reached maximum results for Maggiore - Musocco, Milan.
# Fetching gyms in Mecenate, Milan with offset: 0...
# Fetching gyms in Mecenate, Milan with offset: 16...
# No more gyms returned for Mecenate, Milan.
# Fetching gyms in Muggiano, Milan with offset: 0...
# Fetching gyms in Muggiano, Milan with offset: 48...
# Fetching gyms in Muggiano, Milan with offset: 96...
# Fetching gyms in Muggiano, Milan with offset: 144...
# Fetching gyms in Muggiano, Milan with offset: 192...
# Reached maximum results for Muggiano, Milan.
# Fetching gyms in Navigli, Milan with offset: 0...
# Fetching gyms in Navigli, Milan with offset: 48...
# Fetching gyms in Navigli, Milan with offset: 74...
# No more gyms returned for Navigli, Milan.
# Fetching gyms in Niguarda - Cà Granda, Milan with offset: 0...
# Fetching gyms in Niguarda - Cà Granda, Milan with offset: 48...
# Fetching gyms in Niguarda - Cà Granda, Milan with offset: 96...
# Fetching gyms in Niguarda - Cà Granda, Milan with offset: 144...
# Fetching gyms in Niguarda - Cà Granda, Milan with offset: 192...
# Reached maximum results for Niguarda - Cà Granda, Milan.
# Fetching gyms in Ortomercato, Milan with offset: 0...
# Fetching gyms in Ortomercato, Milan with offset: 48...
# Fetching gyms in Ortomercato, Milan with offset: 96...
# Fetching gyms in Ortomercato, Milan with offset: 99...
# No more gyms returned for Ortomercato, Milan.
# Fetching gyms in Padova, Milan with offset: 0...
# Fetching gyms in Padova, Milan with offset: 48...
# Fetching gyms in Padova, Milan with offset: 50...
# No more gyms returned for Padova, Milan.
# Fetching gyms in Pagano, Milan with offset: 0...
# Fetching gyms in Pagano, Milan with offset: 48...
# Fetching gyms in Pagano, Milan with offset: 96...
# Fetching gyms in Pagano, Milan with offset: 144...
# Fetching gyms in Pagano, Milan with offset: 192...
# Reached maximum results for Pagano, Milan.
# Fetching gyms in Parco Agricolo Sud, Milan with offset: 0...
# Fetching gyms in Parco Agricolo Sud, Milan with offset: 48...
# Fetching gyms in Parco Agricolo Sud, Milan with offset: 96...
# Fetching gyms in Parco Agricolo Sud, Milan with offset: 144...
# Fetching gyms in Parco Agricolo Sud, Milan with offset: 192...
# Reached maximum results for Parco Agricolo Sud, Milan.
# Fetching gyms in Parco Bosco In Città, Milan with offset: 0...
# Fetching gyms in Parco Bosco In Città, Milan with offset: 48...
# Fetching gyms in Parco Bosco In Città, Milan with offset: 96...
# Fetching gyms in Parco Bosco In Città, Milan with offset: 144...
# Fetching gyms in Parco Bosco In Città, Milan with offset: 192...
# Fetching gyms in Parco Bosco In Città, Milan with offset: 213...
# HTTP error occurred for Parco Bosco In Città, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Parco+Bosco+In+Citt%C3%A0%2C+Milan&term=gym&limit=48&offset=213
# Fetching gyms in Parco Forlanini - Ortica, Milan with offset: 0...
# Fetching gyms in Parco Forlanini - Ortica, Milan with offset: 48...
# Fetching gyms in Parco Forlanini - Ortica, Milan with offset: 96...
# Fetching gyms in Parco Forlanini - Ortica, Milan with offset: 144...
# Fetching gyms in Parco Forlanini - Ortica, Milan with offset: 192...
# Reached maximum results for Parco Forlanini - Ortica, Milan.
# Fetching gyms in Parco Lambro - Cimiano, Milan with offset: 0...
# Fetching gyms in Parco Lambro - Cimiano, Milan with offset: 48...
# Fetching gyms in Parco Lambro - Cimiano, Milan with offset: 96...
# Fetching gyms in Parco Lambro - Cimiano, Milan with offset: 144...
# Fetching gyms in Parco Lambro - Cimiano, Milan with offset: 192...
# Reached maximum results for Parco Lambro - Cimiano, Milan.
# Fetching gyms in Parco Monluè - Ponte Lambro, Milan with offset: 0...
# Fetching gyms in Parco Monluè - Ponte Lambro, Milan with offset: 48...
# Fetching gyms in Parco Monluè - Ponte Lambro, Milan with offset: 96...
# Fetching gyms in Parco Monluè - Ponte Lambro, Milan with offset: 144...
# Fetching gyms in Parco Monluè - Ponte Lambro, Milan with offset: 192...
# Reached maximum results for Parco Monluè - Ponte Lambro, Milan.
# Fetching gyms in Parco Nord, Milan with offset: 0...
# Fetching gyms in Parco Nord, Milan with offset: 48...
# Fetching gyms in Parco Nord, Milan with offset: 96...
# Fetching gyms in Parco Nord, Milan with offset: 144...
# Fetching gyms in Parco Nord, Milan with offset: 192...
# Reached maximum results for Parco Nord, Milan.
# Fetching gyms in Parco Sempione, Milan with offset: 0...
# Fetching gyms in Parco Sempione, Milan with offset: 48...
# Fetching gyms in Parco Sempione, Milan with offset: 96...
# Fetching gyms in Parco Sempione, Milan with offset: 102...
# No more gyms returned for Parco Sempione, Milan.
# Fetching gyms in Parco dei Navigli, Milan with offset: 0...
# Fetching gyms in Parco dei Navigli, Milan with offset: 48...
# Fetching gyms in Parco dei Navigli, Milan with offset: 96...
# Fetching gyms in Parco dei Navigli, Milan with offset: 144...
# Fetching gyms in Parco dei Navigli, Milan with offset: 192...
# Reached maximum results for Parco dei Navigli, Milan.
# Fetching gyms in Porta Romana, Milan with offset: 0...
# Fetching gyms in Porta Romana, Milan with offset: 48...
# Fetching gyms in Porta Romana, Milan with offset: 96...
# Fetching gyms in Porta Romana, Milan with offset: 144...
# Fetching gyms in Porta Romana, Milan with offset: 192...
# Fetching gyms in Porta Romana, Milan with offset: 199...
# HTTP error occurred for Porta Romana, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Porta+Romana%2C+Milan&term=gym&limit=48&offset=199
# Fetching gyms in Portello, Milan with offset: 0...
# Fetching gyms in Portello, Milan with offset: 37...
# No more gyms returned for Portello, Milan.
# Fetching gyms in Qt 8, Milan with offset: 0...
# Fetching gyms in Qt 8, Milan with offset: 48...
# Fetching gyms in Qt 8, Milan with offset: 96...
# Fetching gyms in Qt 8, Milan with offset: 144...
# Fetching gyms in Qt 8, Milan with offset: 163...
# No more gyms returned for Qt 8, Milan.
# Fetching gyms in Quarto Cagnino, Milan with offset: 0...
# Fetching gyms in Quarto Cagnino, Milan with offset: 48...
# Fetching gyms in Quarto Cagnino, Milan with offset: 68...
# No more gyms returned for Quarto Cagnino, Milan.
# Fetching gyms in Quinto Romano, Milan with offset: 0...
# Fetching gyms in Quinto Romano, Milan with offset: 48...
# Fetching gyms in Quinto Romano, Milan with offset: 96...
# Fetching gyms in Quinto Romano, Milan with offset: 144...
# Fetching gyms in Quinto Romano, Milan with offset: 192...
# Reached maximum results for Quinto Romano, Milan.
# Fetching gyms in Quintosole, Milan with offset: 0...
# Fetching gyms in Quintosole, Milan with offset: 48...
# Fetching gyms in Quintosole, Milan with offset: 96...
# Fetching gyms in Quintosole, Milan with offset: 144...
# Fetching gyms in Quintosole, Milan with offset: 179...
# No more gyms returned for Quintosole, Milan.
# Fetching gyms in Ripamonti, Milan with offset: 0...
# Fetching gyms in Ripamonti, Milan with offset: 48...
# Fetching gyms in Ripamonti, Milan with offset: 96...
# Fetching gyms in Ripamonti, Milan with offset: 144...
# Fetching gyms in Ripamonti, Milan with offset: 192...
# Reached maximum results for Ripamonti, Milan.
# Fetching gyms in Rogoredo, Milan with offset: 0...
# Fetching gyms in Rogoredo, Milan with offset: 48...
# Fetching gyms in Rogoredo, Milan with offset: 96...
# Fetching gyms in Rogoredo, Milan with offset: 144...
# Fetching gyms in Rogoredo, Milan with offset: 192...
# Reached maximum results for Rogoredo, Milan.
# Fetching gyms in Ronchetto Sul Naviglio, Milan with offset: 0...
# Fetching gyms in Ronchetto Sul Naviglio, Milan with offset: 48...
# Fetching gyms in Ronchetto Sul Naviglio, Milan with offset: 96...
# Fetching gyms in Ronchetto Sul Naviglio, Milan with offset: 100...
# No more gyms returned for Ronchetto Sul Naviglio, Milan.
# Fetching gyms in Ronchetto delle Rane, Milan with offset: 0...
# Fetching gyms in Ronchetto delle Rane, Milan with offset: 48...
# Fetching gyms in Ronchetto delle Rane, Milan with offset: 96...
# Fetching gyms in Ronchetto delle Rane, Milan with offset: 144...
# Fetching gyms in Ronchetto delle Rane, Milan with offset: 192...
# Reached maximum results for Ronchetto delle Rane, Milan.
# Fetching gyms in San Cristoforo, Milan with offset: 0...
# Fetching gyms in San Cristoforo, Milan with offset: 44...
# No more gyms returned for San Cristoforo, Milan.
# Fetching gyms in San Siro, Milan with offset: 0...
# Fetching gyms in San Siro, Milan with offset: 48...
# Fetching gyms in San Siro, Milan with offset: 96...
# Fetching gyms in San Siro, Milan with offset: 123...
# No more gyms returned for San Siro, Milan.
# Fetching gyms in Sarpi, Milan with offset: 0...
# Fetching gyms in Sarpi, Milan with offset: 48...
# Fetching gyms in Sarpi, Milan with offset: 96...
# Fetching gyms in Sarpi, Milan with offset: 144...
# Fetching gyms in Sarpi, Milan with offset: 192...
# Reached maximum results for Sarpi, Milan.
# Fetching gyms in Scalo Romana, Milan with offset: 0...
# Fetching gyms in Scalo Romana, Milan with offset: 48...
# Fetching gyms in Scalo Romana, Milan with offset: 96...
# Fetching gyms in Scalo Romana, Milan with offset: 144...
# Fetching gyms in Scalo Romana, Milan with offset: 192...
# Reached maximum results for Scalo Romana, Milan.
# Fetching gyms in Selinunte, Milan with offset: 0...
# Fetching gyms in Selinunte, Milan with offset: 48...
# Fetching gyms in Selinunte, Milan with offset: 96...
# Fetching gyms in Selinunte, Milan with offset: 144...
# Fetching gyms in Selinunte, Milan with offset: 159...
# No more gyms returned for Selinunte, Milan.
# Fetching gyms in Stadera, Milan with offset: 0...
# Fetching gyms in Stadera, Milan with offset: 48...
# Fetching gyms in Stadera, Milan with offset: 96...
# Fetching gyms in Stadera, Milan with offset: 144...
# Fetching gyms in Stadera, Milan with offset: 179...
# No more gyms returned for Stadera, Milan.
# Fetching gyms in Stephenson, Milan with offset: 0...
# Fetching gyms in Stephenson, Milan with offset: 10...
# No more gyms returned for Stephenson, Milan.
# Fetching gyms in Tibaldi, Milan with offset: 0...
# Fetching gyms in Tibaldi, Milan with offset: 48...
# Fetching gyms in Tibaldi, Milan with offset: 60...
# No more gyms returned for Tibaldi, Milan.
# Fetching gyms in Ticinese, Milan with offset: 0...
# Fetching gyms in Ticinese, Milan with offset: 48...
# Fetching gyms in Ticinese, Milan with offset: 96...
# Fetching gyms in Ticinese, Milan with offset: 144...
# Fetching gyms in Ticinese, Milan with offset: 192...
# Fetching gyms in Ticinese, Milan with offset: 224...
# HTTP error occurred for Ticinese, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Ticinese%2C+Milan&term=gym&limit=48&offset=224
# Fetching gyms in Tortona, Milan with offset: 0...
# Fetching gyms in Tortona, Milan with offset: 48...
# Fetching gyms in Tortona, Milan with offset: 86...
# No more gyms returned for Tortona, Milan.
# Fetching gyms in Tre Torri, Milan with offset: 0...
# Fetching gyms in Tre Torri, Milan with offset: 48...
# Fetching gyms in Tre Torri, Milan with offset: 96...
# Fetching gyms in Tre Torri, Milan with offset: 144...
# Fetching gyms in Tre Torri, Milan with offset: 192...
# Fetching gyms in Tre Torri, Milan with offset: 218...
# HTTP error occurred for Tre Torri, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Tre+Torri%2C+Milan&term=gym&limit=48&offset=218
# Fetching gyms in Trenno, Milan with offset: 0...
# Fetching gyms in Trenno, Milan with offset: 48...
# Fetching gyms in Trenno, Milan with offset: 94...
# No more gyms returned for Trenno, Milan.
# Fetching gyms in Triulzo Superiore, Milan with offset: 0...
# Fetching gyms in Triulzo Superiore, Milan with offset: 48...
# Fetching gyms in Triulzo Superiore, Milan with offset: 96...
# Fetching gyms in Triulzo Superiore, Milan with offset: 144...
# Fetching gyms in Triulzo Superiore, Milan with offset: 192...
# Reached maximum results for Triulzo Superiore, Milan.
# Fetching gyms in Umbria - Molise, Milan with offset: 0...
# Fetching gyms in Umbria - Molise, Milan with offset: 48...
# Fetching gyms in Umbria - Molise, Milan with offset: 96...
# Fetching gyms in Umbria - Molise, Milan with offset: 144...
# Fetching gyms in Umbria - Molise, Milan with offset: 192...
# Reached maximum results for Umbria - Molise, Milan.
# Fetching gyms in Viale Monza, Milan with offset: 0...
# Fetching gyms in Viale Monza, Milan with offset: 48...
# Fetching gyms in Viale Monza, Milan with offset: 96...
# Fetching gyms in Viale Monza, Milan with offset: 144...
# Fetching gyms in Viale Monza, Milan with offset: 192...
# Reached maximum results for Viale Monza, Milan.
# Fetching gyms in Vigentina, Milan with offset: 0...
# Fetching gyms in Vigentina, Milan with offset: 48...
# Fetching gyms in Vigentina, Milan with offset: 96...
# Fetching gyms in Vigentina, Milan with offset: 128...
# No more gyms returned for Vigentina, Milan.
# Fetching gyms in Villapizzone, Milan with offset: 0...
# Fetching gyms in Villapizzone, Milan with offset: 24...
# No more gyms returned for Villapizzone, Milan.
# Fetching gyms in Washington, Milan with offset: 0...
# Fetching gyms in Washington, Milan with offset: 48...
# Fetching gyms in Washington, Milan with offset: 96...
# Fetching gyms in Washington, Milan with offset: 144...
# Fetching gyms in Washington, Milan with offset: 192...
# No more gyms returned for Washington, Milan.
# Fetching gyms in XXII Marzo, Milan with offset: 0...
# Fetching gyms in XXII Marzo, Milan with offset: 48...
# Fetching gyms in XXII Marzo, Milan with offset: 85...
# No more gyms returned for XXII Marzo, Milan.
# Fetching gyms in Forze Armate, Milan with offset: 0...
# Fetching gyms in Forze Armate, Milan with offset: 48...
# Fetching gyms in Forze Armate, Milan with offset: 96...
# Fetching gyms in Forze Armate, Milan with offset: 144...
# Fetching gyms in Forze Armate, Milan with offset: 192...
# Reached maximum results for Forze Armate, Milan.
#                Fetch Location                      Gym Name  \
# 0  Parco delle Abbazie, Milan                         McFit
# 1  Parco delle Abbazie, Milan            Hard Candy Fitness
# 2  Parco delle Abbazie, Milan               Get Fit Express
# 3  Parco delle Abbazie, Milan  Centro balneare Lido Locarno
# 4  Parco delle Abbazie, Milan                         Tonic
#
#                    Gym Address  \
# 0   Via Pier Francesco Mola 48
# 1                 Via Parini 1
# 2  Piazza Città di Lombardia 5
# 3    Via Gioacchino Respini 11
# 4            Via Giambellino 5
#
#                                        Categories  Average Star Rating  \
# 0                                            Gyms                  4.0
# 1                                            Gyms                  3.7
# 2                                            Gyms                  4.3
# 3  Gyms, Swimming Pools, Swimming Lessons/Schools                  4.7
# 4                                            Gyms                  4.0
#
#    Review Count   Latitude  Longitude                  geometry
# 0             1  45.495993   9.139686  POINT (9.13969 45.49599)
# 1             3  45.477589   9.195213  POINT (9.19521 45.47759)
# 2             3  45.483848   9.192945  POINT (9.19294 45.48385)
# 3             3  46.161382   8.803369  POINT (8.80337 46.16138)
# 4             3  45.451830   9.152850  POINT (9.15285 45.45183)
# Total gyms collected: 12884

# %%
Gyms
# Out:
#                    Fetch Location                        Gym Name  \
# 0      Parco delle Abbazie, Milan                           McFit
# 1      Parco delle Abbazie, Milan              Hard Candy Fitness
# 2      Parco delle Abbazie, Milan                 Get Fit Express
# 3      Parco delle Abbazie, Milan    Centro balneare Lido Locarno
# 4      Parco delle Abbazie, Milan                           Tonic
# ...                           ...                             ...
# 12879         Forze Armate, Milan                  Alina Quintana
# 12880         Forze Armate, Milan                   Virgin Active
# 12881         Forze Armate, Milan                    Nonsolodanza
# 12882         Forze Armate, Milan                     Let's Dance
# 12883         Forze Armate, Milan  Onstage di Donatella Bianchini
#
#                        Gym Address  \
# 0       Via Pier Francesco Mola 48
# 1                     Via Parini 1
# 2      Piazza Città di Lombardia 5
# 3        Via Gioacchino Respini 11
# 4                Via Giambellino 5
# ...                            ...
# 12879       Galleria San Babila 4A
# 12880       Via Carlo Imbonati 24A
# 12881             Via Pastrengo 16
# 12882             Via Puricelli 20
# 12883            Via Rutilia, 10/8
#
#                                            Categories  Average Star Rating  \
# 0                                                Gyms                  4.0
# 1                                                Gyms                  3.7
# 2                                                Gyms                  4.3
# 3      Gyms, Swimming Pools, Swimming Lessons/Schools                  4.7
# 4                                                Gyms                  4.0
# ...                                               ...                  ...
# 12879                                   Dance Studios                  0.0
# 12880                         Gyms, Trainers, Pilates                  2.0
# 12881                                   Dance Studios                  0.0
# 12882                                   Dance Studios                  5.0
# 12883                                   Dance Studios                  0.0
#
#        Review Count   Latitude  Longitude                  geometry
# 0                 1  45.495993   9.139686  POINT (9.13969 45.49599)
# 1                 3  45.477589   9.195213  POINT (9.19521 45.47759)
# 2                 3  45.483848   9.192945  POINT (9.19294 45.48385)
# 3                 3  46.161382   8.803369  POINT (8.80337 46.16138)
# 4                 3  45.451830   9.152850  POINT (9.15285 45.45183)
# ...             ...        ...        ...                       ...
# 12879             0  45.466360   9.198580  POINT (9.19858 45.46636)
# 12880             1  45.502156   9.182671  POINT (9.18267 45.50216)
# 12881             0  45.486760   9.185670  POINT (9.18567 45.48676)
# 12882             1  45.464980   9.129650  POINT (9.12965 45.46498)
# 12883             0  45.440720   9.198540  POINT (9.19854 45.44072)
#
# [12884 rows x 9 columns]

# %%
# Removing the dupes
Gyms_nodup = Gyms.drop_duplicates(subset=['Gym Name','Gym Address','Categories','Average Star Rating',
                                                        'Review Count','geometry'])
# Saving the file
Gyms_nodup.to_file("Gyms.geojson", driver="GeoJSON")

Gyms_nodup
# Out:
#                    Fetch Location                                  Gym Name  \
# 0      Parco delle Abbazie, Milan                                     McFit
# 1      Parco delle Abbazie, Milan                        Hard Candy Fitness
# 2      Parco delle Abbazie, Milan                           Get Fit Express
# 3      Parco delle Abbazie, Milan              Centro balneare Lido Locarno
# 4      Parco delle Abbazie, Milan                                     Tonic
# ...                           ...                                       ...
# 7763            Parco Nord, Milan                            Elena Sokolova
# 7764            Parco Nord, Milan                         Studio Pole Dance
# 7766            Parco Nord, Milan                    La Palestra S.S.D.R.L.
# 11596    Triulzo Superiore, Milan  Accademia di Musica e Danza, F. Gaffurio
# 11708    Triulzo Superiore, Milan                           Studiomovimento
#
#                        Gym Address  \
# 0       Via Pier Francesco Mola 48
# 1                     Via Parini 1
# 2      Piazza Città di Lombardia 5
# 3        Via Gioacchino Respini 11
# 4                Via Giambellino 5
# ...                            ...
# 7763                Via Mentana, 6
# 7764                Via Mentana, 6
# 7766          Via SAN Gottardo, 58
# 11596        LG. Carlo Crocetta, 8
# 11708    Viale della Repubblica 23
#
#                                            Categories  Average Star Rating  \
# 0                                                Gyms                  4.0
# 1                                                Gyms                  3.7
# 2                                                Gyms                  4.3
# 3      Gyms, Swimming Pools, Swimming Lessons/Schools                  4.7
# 4                                                Gyms                  4.0
# ...                                               ...                  ...
# 7763                                    Dance Studios                  0.0
# 7764                                    Dance Studios                  0.0
# 7766                                    Dance Studios                  0.0
# 11596                                   Dance Studios                  0.0
# 11708                             Gyms, Pilates, Yoga                  0.0
#
#        Review Count   Latitude  Longitude                  geometry
# 0                 1  45.495993   9.139686  POINT (9.13969 45.49599)
# 1                 3  45.477589   9.195213  POINT (9.19521 45.47759)
# 2                 3  45.483848   9.192945  POINT (9.19294 45.48385)
# 3                 3  46.161382   8.803369  POINT (8.80337 46.16138)
# 4                 3  45.451830   9.152850  POINT (9.15285 45.45183)
# ...             ...        ...        ...                       ...
# 7763              0  45.577499   9.276400    POINT (9.2764 45.5775)
# 7764              0  45.577499   9.276400    POINT (9.2764 45.5775)
# 7766              0  45.584100   9.268260   POINT (9.26826 45.5841)
# 11596             0  45.358787   9.329503   POINT (9.3295 45.35879)
# 11708             0  45.357489   9.316936  POINT (9.31694 45.35749)
#
# [825 rows x 9 columns]

# %%
# DEVONO ESSERE LO STESSO TIPO DI COORDINATE
print(Gyms_nodup.crs)  # Restaurants CRS
print(gdf_combined.crs)  # Neighborhood polygons CRS
# Out:
# EPSG:4326
# EPSG:4326

# %% [markdown]
# # Join Spaziale

# %%
# Perform the spatial join
joined = sjoin(Gyms_nodup, gdf_combined, how="left", predicate="within")

# Check the result
joined
# Out:
#                    Fetch Location                                  Gym Name  \
# 0      Parco delle Abbazie, Milan                                     McFit
# 1      Parco delle Abbazie, Milan                        Hard Candy Fitness
# 2      Parco delle Abbazie, Milan                           Get Fit Express
# 3      Parco delle Abbazie, Milan              Centro balneare Lido Locarno
# 4      Parco delle Abbazie, Milan                                     Tonic
# ...                           ...                                       ...
# 7763            Parco Nord, Milan                            Elena Sokolova
# 7764            Parco Nord, Milan                         Studio Pole Dance
# 7766            Parco Nord, Milan                    La Palestra S.S.D.R.L.
# 11596    Triulzo Superiore, Milan  Accademia di Musica e Danza, F. Gaffurio
# 11708    Triulzo Superiore, Milan                           Studiomovimento
#
#                        Gym Address  \
# 0       Via Pier Francesco Mola 48
# 1                     Via Parini 1
# 2      Piazza Città di Lombardia 5
# 3        Via Gioacchino Respini 11
# 4                Via Giambellino 5
# ...                            ...
# 7763                Via Mentana, 6
# 7764                Via Mentana, 6
# 7766          Via SAN Gottardo, 58
# 11596        LG. Carlo Crocetta, 8
# 11708    Viale della Repubblica 23
#
#                                            Categories  Average Star Rating  \
# 0                                                Gyms                  4.0
# 1                                                Gyms                  3.7
# 2                                                Gyms                  4.3
# 3      Gyms, Swimming Pools, Swimming Lessons/Schools                  4.7
# 4                                                Gyms                  4.0
# ...                                               ...                  ...
# 7763                                    Dance Studios                  0.0
# 7764                                    Dance Studios                  0.0
# 7766                                    Dance Studios                  0.0
# 11596                                   Dance Studios                  0.0
# 11708                             Gyms, Pilates, Yoga                  0.0
#
#        Review Count   Latitude  Longitude                  geometry  \
# 0                 1  45.495993   9.139686  POINT (9.13969 45.49599)
# 1                 3  45.477589   9.195213  POINT (9.19521 45.47759)
# 2                 3  45.483848   9.192945  POINT (9.19294 45.48385)
# 3                 3  46.161382   8.803369  POINT (8.80337 46.16138)
# 4                 3  45.451830   9.152850  POINT (9.15285 45.45183)
# ...             ...        ...        ...                       ...
# 7763              0  45.577499   9.276400    POINT (9.2764 45.5775)
# 7764              0  45.577499   9.276400    POINT (9.2764 45.5775)
# 7766              0  45.584100   9.268260   POINT (9.26826 45.5841)
# 11596             0  45.358787   9.329503   POINT (9.3295 45.35879)
# 11708             0  45.357489   9.316936  POINT (9.31694 45.35749)
#
#        index_right          Neighborhood
# 0             81.0          Villapizzone
# 1              9.0                 Brera
# 2             24.0  GARIBALDI REPUBBLICA
# 3              NaN                   NaN
# 4             27.0           Giambellino
# ...            ...                   ...
# 7763           NaN                   NaN
# 7764           NaN                   NaN
# 7766           NaN                   NaN
# 11596          NaN                   NaN
# 11708          NaN                   NaN
#
# [825 rows x 11 columns]

# %%
joined[joined['Gym Name']=='McFit'] # giusto
# Out:
#                  Fetch Location Gym Name                     Gym Address  \
# 0    Parco delle Abbazie, Milan    McFit      Via Pier Francesco Mola 48
# 800              Bicocca, Milan    McFit  Via Luisa Battistotti Sassi 11
#
#     Categories  Average Star Rating  Review Count   Latitude  Longitude  \
# 0         Gyms                  4.0             1  45.495993   9.139686
# 800       Gyms                  0.0             0  45.463380   9.227671
#
#                      geometry  index_right  Neighborhood
# 0    POINT (9.13969 45.49599)         81.0  Villapizzone
# 800  POINT (9.22767 45.46338)         18.0       Corsica

# %%
joined.nunique()
# Out:
# Fetch Location          22
# Gym Name               747
# Gym Address            808
# Categories             170
# Average Star Rating     27
# Review Count            14
# Latitude               808
# Longitude              806
# geometry               811
# index_right             58
# Neighborhood            58
# dtype: int64

# %%
# Remove rows where the geometry is NaN
PolyGyms = joined[~joined["Neighborhood"].isna()]

# Reset the index if needed
PolyGyms = PolyGyms.reset_index(drop=True)

# Keeping only relevant variables
PolyGyms = PolyGyms[["Gym Name", "Gym Address", "Categories", "Average Star Rating",
                           "Review Count", "geometry", "Neighborhood"]].rename(columns={"Gym Name": "Nome",
                                                                                       "Gym Address": "Indirizzo"})
PolyGyms["info"] = "PALESTRA"

# Saving the file
PolyGyms.to_file("PolyGyms.geojson", driver="GeoJSON")

# Print the cleaned GeoDataFrame
PolyGyms
# Out:
#                                                   Nome  \
# 0                                                McFit
# 1                                   Hard Candy Fitness
# 2                                      Get Fit Express
# 3                                                Tonic
# 4                                            Milanimal
# ..                                                 ...
# 324                                            Level 2
# 325  Associazione Sportiva Dilettantistica Lo Studi...
# 326                                  Tilt Spazio Danza
# 327                      A.s.fitness Professionals FIA
# 328                           Palestra Venditti Walter
#
#                        Indirizzo                           Categories  \
# 0     Via Pier Francesco Mola 48                                 Gyms
# 1                   Via Parini 1                                 Gyms
# 2    Piazza Città di Lombardia 5                                 Gyms
# 3              Via Giambellino 5                                 Gyms
# 4       Via Lodovico Muratori 34                   Martial Arts, Gyms
# ..                           ...                                  ...
# 324                Via Pitteri 8                   Martial Arts, Gyms
# 325              Via Rutilia, 16                        Dance Studios
# 326       Via Averardo Buschi, 1                        Dance Studios
# 327         Via Monte Nevoso, 17  Sports Clubs, Fitness & Instruction
# 328               Via Feltre, 27                        Dance Studios
#
#      Average Star Rating  Review Count                  geometry  \
# 0                    4.0             1  POINT (9.13969 45.49599)
# 1                    3.7             3  POINT (9.19521 45.47759)
# 2                    4.3             3  POINT (9.19294 45.48385)
# 3                    4.0             3  POINT (9.15285 45.45183)
# 4                    4.8             4  POINT (9.20972 45.45129)
# ..                   ...           ...                       ...
# 324                  4.0             1  POINT (9.24887 45.47333)
# 325                  0.0             0  POINT (9.19761 45.44014)
# 326                  0.0             0  POINT (9.23254 45.48233)
# 327                  0.0             0  POINT (9.23403 45.48763)
# 328                  0.0             0  POINT (9.24079 45.49135)
#
#                Neighborhood      info
# 0              Villapizzone  PALESTRA
# 1                     Brera  PALESTRA
# 2      GARIBALDI REPUBBLICA  PALESTRA
# 3               Giambellino  PALESTRA
# 4              Porta Romana  PALESTRA
# ..                      ...       ...
# 324                Lambrate  PALESTRA
# 325       Ex Om - Morivione  PALESTRA
# 326             Città Studi  PALESTRA
# 327                  Loreto  PALESTRA
# 328  Parco Lambro - Cimiano  PALESTRA
#
# [329 rows x 8 columns]
