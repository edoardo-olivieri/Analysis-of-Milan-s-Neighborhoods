# %%
import pandas as pd
import geopandas as gpd
import requests
import time
from shapely.geometry import Point
from geopandas.tools import sjoin

# %%
# Import of the Polygons
gdf_combined = gpd.read_file("C:/Users/edoar/combined_quartieri.geojson")

# %% [markdown]
# # YELP API

# %%
neighborhoods = [f"{name}, Milan" for name in gdf_combined["Neighborhood"].tolist()]
neighborhoods
# Out:
# ['Parco delle Abbazie, Milan',
#  'Adriano, Milan',
#  'Affori, Milan',
#  'Baggio, Milan',
#  'Bande Nere, Milan',
#  'Barona, Milan',
#  'Bicocca, Milan',
#  'Bovisasca, Milan',
#  'Bovisa, Milan',
#  'Brera, Milan',
#  'Bruzzano, Milan',
#  'Buenos Aires - Venezia, Milan',
#  'Cantalupa, Milan',
#  'Cascina Triulza - Expo, Milan',
#  'Centrale, Milan',
#  'Chiaravalle, Milan',
#  'Città Studi, Milan',
#  'Comasina, Milan',
#  'Corsica, Milan',
#  'De Angeli - Monte Rosa, Milan',
#  'Dergano, Milan',
#  'Duomo, Milan',
#  'Ex Om - Morivione, Milan',
#  'Farini, Milan',
#  'GARIBALDI REPUBBLICA, Milan',
#  'Gallaratese, Milan',
#  'Ghisolfa, Milan',
#  'Giambellino, Milan',
#  'Giardini Porta Venezia, Milan',
#  'Gratosoglio - Ticinello, Milan',
#  'Greco, Milan',
#  'Guastalla, Milan',
#  'Isola, Milan',
#  'Lambrate, Milan',
#  'Lodi - Corvetto, Milan',
#  'Lorenteggio, Milan',
#  'Loreto, Milan',
#  'Maciachini - Maggiolina, Milan',
#  'Magenta - San Vittore, Milan',
#  'Maggiore - Musocco, Milan',
#  'Mecenate, Milan',
#  'Muggiano, Milan',
#  'Navigli, Milan',
#  'Niguarda - Cà Granda, Milan',
#  'Ortomercato, Milan',
#  'Padova, Milan',
#  'Pagano, Milan',
#  'Parco Agricolo Sud, Milan',
#  'Parco Bosco In Città, Milan',
#  'Parco Forlanini - Ortica, Milan',
#  'Parco Lambro - Cimiano, Milan',
#  'Parco Monluè - Ponte Lambro, Milan',
#  'Parco Nord, Milan',
#  'Parco Sempione, Milan',
#  'Parco dei Navigli, Milan',
#  'Porta Romana, Milan',
#  'Portello, Milan',
#  'Qt 8, Milan',
#  'Quarto Cagnino, Milan',
#  'Quinto Romano, Milan',
#  'Quintosole, Milan',
#  'Ripamonti, Milan',
#  'Rogoredo, Milan',
#  'Ronchetto Sul Naviglio, Milan',
#  'Ronchetto delle Rane, Milan',
#  'San Cristoforo, Milan',
#  'San Siro, Milan',
#  'Sarpi, Milan',
#  'Scalo Romana, Milan',
#  'Selinunte, Milan',
#  'Stadera, Milan',
#  'Stephenson, Milan',
#  'Tibaldi, Milan',
#  'Ticinese, Milan',
#  'Tortona, Milan',
#  'Tre Torri, Milan',
#  'Trenno, Milan',
#  'Triulzo Superiore, Milan',
#  'Umbria - Molise, Milan',
#  'Viale Monza, Milan',
#  'Vigentina, Milan',
#  'Villapizzone, Milan',
#  'Washington, Milan',
#  'XXII Marzo, Milan',
#  'Forze Armate, Milan']

# %%
# Replace with your Yelp API key
API_KEY = "6CbFJGYPopltfBbkb00hIFGRI4XBrAsccPevTJ53ol4YIuJrF48kEylTmKvEl4-TEP8p0pEc3ydzUsatpgGI5aqSHCsysi5-yWyeJD3V-6al5x6_AcFkw23LehKEZ3Yx"
HEADERS = {"Authorization": f"Bearer {API_KEY}"}

# Constants
businesses_per_request = 48  # Maximum allowed by Yelp per request

def make_request(url, params=None):
    """
    Makes a request to the Yelp API.
    """
    response = requests.get(url, headers=HEADERS, params=params)
    response.raise_for_status()
    return response

def search_businesses(location, term="restaurant", limit=businesses_per_request, offset=0):
    """
    Searches for businesses in a given location with pagination.
    """
    url = "https://api.yelp.com/v3/businesses/search"
    params = {
        "location": location,
        "term": term,
        "limit": limit,
        "offset": offset
    }
    response = make_request(url, params=params)
    return response.json().get("businesses", [])

# Initialize data storage
data = []

try:
    for neighborhood in neighborhoods:  # Loop through each neighborhood
        offset = 0
        while True:  # fetching data until no more results
            print(f"Fetching businesses in {neighborhood} with offset: {offset}...")

            try:
                # fetch businesses using the current offset and location
                businesses = search_businesses(location=neighborhood, term="restaurant", limit=businesses_per_request, offset=offset)

                if not businesses:
                    # No more businesses to fetch
                    print(f"No more businesses returned for {neighborhood}.")
                    break

                for biz in businesses:
                    name = biz.get("name", "N/A")
                    location_info = biz.get("location", {})
                    address = location_info.get("address1", "N/A")
                    categories = biz.get("categories", [])
                    category_list = [cat.get("title", "") for cat in categories if cat.get("title")]
                    category_str = ", ".join(category_list) if category_list else "N/A"
                    rating = biz.get("rating", "N/A")
                    review_count = biz.get("review_count", "N/A")
                    price = biz.get("price", "N/A")

                    # Extract coordinates
                    coordinates = biz.get("coordinates", {})
                    latitude = coordinates.get("latitude", None)
                    longitude = coordinates.get("longitude", None)

                    # Append to data
                    data.append({
                        "Fetch Location": neighborhood,
                        "Business Name": name,
                        "Business Address": address,
                        "Categories": category_str,
                        "Average Star Rating": rating,
                        "Review Count": review_count,
                        "Price": price,
                        "Latitude": latitude,
                        "Longitude": longitude
                    })

                # Increment offset for the next batch
                offset += len(businesses)

                # Optional: Sleep to respect API rate limits
                time.sleep(0.5)

                # Break if the offset exceeds Yelp's maximum results per query
                if offset >= 240:  # Maximum 240 results per query
                    print(f"Reached maximum results for {neighborhood}.")
                    break

            except requests.HTTPError as he:
                # Log the error and skip this neighborhood
                print(f"HTTP error occurred for {neighborhood}: {he}")
                break

    # Convert the collected data into a DataFrame
    df = pd.DataFrame(data)

    # Convert DataFrame to GeoDataFrame
    df["geometry"] = df.apply(
        lambda row: Point(row["Longitude"], row["Latitude"]) if row["Longitude"] and row["Latitude"] else None,
        axis=1
    )
    Restaurants = gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:4326")

    # Print summary
    print(Restaurants.head())
    print(f"Total businesses collected: {len(data)}")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Fetching businesses in Parco delle Abbazie, Milan with offset: 0...
# Fetching businesses in Parco delle Abbazie, Milan with offset: 48...
# Fetching businesses in Parco delle Abbazie, Milan with offset: 96...
# Fetching businesses in Parco delle Abbazie, Milan with offset: 144...
# Fetching businesses in Parco delle Abbazie, Milan with offset: 192...
# Reached maximum results for Parco delle Abbazie, Milan.
# Fetching businesses in Adriano, Milan with offset: 0...
# HTTP error occurred for Adriano, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Adriano%2C+Milan&term=restaurant&limit=48&offset=0
# Fetching businesses in Affori, Milan with offset: 0...
# Fetching businesses in Affori, Milan with offset: 48...
# Fetching businesses in Affori, Milan with offset: 96...
# Fetching businesses in Affori, Milan with offset: 144...
# Fetching businesses in Affori, Milan with offset: 192...
# Reached maximum results for Affori, Milan.
# Fetching businesses in Baggio, Milan with offset: 0...
# Fetching businesses in Baggio, Milan with offset: 44...
# No more businesses returned for Baggio, Milan.
# Fetching businesses in Bande Nere, Milan with offset: 0...
# Fetching businesses in Bande Nere, Milan with offset: 48...
# Fetching businesses in Bande Nere, Milan with offset: 96...
# Fetching businesses in Bande Nere, Milan with offset: 144...
# Fetching businesses in Bande Nere, Milan with offset: 192...
# Reached maximum results for Bande Nere, Milan.
# Fetching businesses in Barona, Milan with offset: 0...
# Fetching businesses in Barona, Milan with offset: 48...
# Fetching businesses in Barona, Milan with offset: 96...
# Fetching businesses in Barona, Milan with offset: 144...
# Fetching businesses in Barona, Milan with offset: 192...
# Reached maximum results for Barona, Milan.
# Fetching businesses in Bicocca, Milan with offset: 0...
# Fetching businesses in Bicocca, Milan with offset: 48...
# Fetching businesses in Bicocca, Milan with offset: 96...
# Fetching businesses in Bicocca, Milan with offset: 144...
# Fetching businesses in Bicocca, Milan with offset: 192...
# Reached maximum results for Bicocca, Milan.
# Fetching businesses in Bovisasca, Milan with offset: 0...
# Fetching businesses in Bovisasca, Milan with offset: 48...
# Fetching businesses in Bovisasca, Milan with offset: 96...
# Fetching businesses in Bovisasca, Milan with offset: 144...
# Fetching businesses in Bovisasca, Milan with offset: 192...
# Reached maximum results for Bovisasca, Milan.
# Fetching businesses in Bovisa, Milan with offset: 0...
# Fetching businesses in Bovisa, Milan with offset: 48...
# Fetching businesses in Bovisa, Milan with offset: 96...
# Fetching businesses in Bovisa, Milan with offset: 144...
# Fetching businesses in Bovisa, Milan with offset: 192...
# Reached maximum results for Bovisa, Milan.
# Fetching businesses in Brera, Milan with offset: 0...
# Fetching businesses in Brera, Milan with offset: 48...
# Fetching businesses in Brera, Milan with offset: 96...
# Fetching businesses in Brera, Milan with offset: 144...
# Fetching businesses in Brera, Milan with offset: 192...
# Reached maximum results for Brera, Milan.
# Fetching businesses in Bruzzano, Milan with offset: 0...
# Fetching businesses in Bruzzano, Milan with offset: 48...
# Fetching businesses in Bruzzano, Milan with offset: 63...
# No more businesses returned for Bruzzano, Milan.
# Fetching businesses in Buenos Aires - Venezia, Milan with offset: 0...
# Fetching businesses in Buenos Aires - Venezia, Milan with offset: 48...
# Fetching businesses in Buenos Aires - Venezia, Milan with offset: 96...
# Fetching businesses in Buenos Aires - Venezia, Milan with offset: 144...
# Fetching businesses in Buenos Aires - Venezia, Milan with offset: 192...
# Reached maximum results for Buenos Aires - Venezia, Milan.
# Fetching businesses in Cantalupa, Milan with offset: 0...
# Fetching businesses in Cantalupa, Milan with offset: 48...
# Fetching businesses in Cantalupa, Milan with offset: 96...
# Fetching businesses in Cantalupa, Milan with offset: 144...
# Fetching businesses in Cantalupa, Milan with offset: 192...
# Reached maximum results for Cantalupa, Milan.
# Fetching businesses in Cascina Triulza - Expo, Milan with offset: 0...
# Fetching businesses in Cascina Triulza - Expo, Milan with offset: 48...
# Fetching businesses in Cascina Triulza - Expo, Milan with offset: 96...
# Fetching businesses in Cascina Triulza - Expo, Milan with offset: 144...
# Fetching businesses in Cascina Triulza - Expo, Milan with offset: 192...
# Reached maximum results for Cascina Triulza - Expo, Milan.
# Fetching businesses in Centrale, Milan with offset: 0...
# Fetching businesses in Centrale, Milan with offset: 48...
# Fetching businesses in Centrale, Milan with offset: 96...
# Fetching businesses in Centrale, Milan with offset: 144...
# Fetching businesses in Centrale, Milan with offset: 192...
# Reached maximum results for Centrale, Milan.
# Fetching businesses in Chiaravalle, Milan with offset: 0...
# Fetching businesses in Chiaravalle, Milan with offset: 48...
# Fetching businesses in Chiaravalle, Milan with offset: 96...
# Fetching businesses in Chiaravalle, Milan with offset: 144...
# Fetching businesses in Chiaravalle, Milan with offset: 192...
# Reached maximum results for Chiaravalle, Milan.
# Fetching businesses in Città Studi, Milan with offset: 0...
# Fetching businesses in Città Studi, Milan with offset: 48...
# Fetching businesses in Città Studi, Milan with offset: 96...
# Fetching businesses in Città Studi, Milan with offset: 144...
# Fetching businesses in Città Studi, Milan with offset: 192...
# Reached maximum results for Città Studi, Milan.
# Fetching businesses in Comasina, Milan with offset: 0...
# Fetching businesses in Comasina, Milan with offset: 18...
# No more businesses returned for Comasina, Milan.
# Fetching businesses in Corsica, Milan with offset: 0...
# Fetching businesses in Corsica, Milan with offset: 48...
# Fetching businesses in Corsica, Milan with offset: 96...
# Fetching businesses in Corsica, Milan with offset: 144...
# Fetching businesses in Corsica, Milan with offset: 192...
# Fetching businesses in Corsica, Milan with offset: 209...
# HTTP error occurred for Corsica, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Corsica%2C+Milan&term=restaurant&limit=48&offset=209
# Fetching businesses in De Angeli - Monte Rosa, Milan with offset: 0...
# HTTP error occurred for De Angeli - Monte Rosa, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=De+Angeli+-+Monte+Rosa%2C+Milan&term=restaurant&limit=48&offset=0
# Fetching businesses in Dergano, Milan with offset: 0...
# Fetching businesses in Dergano, Milan with offset: 48...
# Fetching businesses in Dergano, Milan with offset: 96...
# Fetching businesses in Dergano, Milan with offset: 144...
# Fetching businesses in Dergano, Milan with offset: 192...
# Reached maximum results for Dergano, Milan.
# Fetching businesses in Duomo, Milan with offset: 0...
# Fetching businesses in Duomo, Milan with offset: 48...
# Fetching businesses in Duomo, Milan with offset: 96...
# Fetching businesses in Duomo, Milan with offset: 144...
# Fetching businesses in Duomo, Milan with offset: 192...
# Reached maximum results for Duomo, Milan.
# Fetching businesses in Ex Om - Morivione, Milan with offset: 0...
# Fetching businesses in Ex Om - Morivione, Milan with offset: 48...
# Fetching businesses in Ex Om - Morivione, Milan with offset: 96...
# Fetching businesses in Ex Om - Morivione, Milan with offset: 144...
# Fetching businesses in Ex Om - Morivione, Milan with offset: 192...
# Reached maximum results for Ex Om - Morivione, Milan.
# Fetching businesses in Farini, Milan with offset: 0...
# Fetching businesses in Farini, Milan with offset: 48...
# Fetching businesses in Farini, Milan with offset: 96...
# Fetching businesses in Farini, Milan with offset: 144...
# Fetching businesses in Farini, Milan with offset: 192...
# Reached maximum results for Farini, Milan.
# Fetching businesses in GARIBALDI REPUBBLICA, Milan with offset: 0...
# Fetching businesses in GARIBALDI REPUBBLICA, Milan with offset: 48...
# Fetching businesses in GARIBALDI REPUBBLICA, Milan with offset: 96...
# Fetching businesses in GARIBALDI REPUBBLICA, Milan with offset: 144...
# Fetching businesses in GARIBALDI REPUBBLICA, Milan with offset: 192...
# Reached maximum results for GARIBALDI REPUBBLICA, Milan.
# Fetching businesses in Gallaratese, Milan with offset: 0...
# Fetching businesses in Gallaratese, Milan with offset: 48...
# Fetching businesses in Gallaratese, Milan with offset: 96...
# Fetching businesses in Gallaratese, Milan with offset: 144...
# Fetching businesses in Gallaratese, Milan with offset: 192...
# Reached maximum results for Gallaratese, Milan.
# Fetching businesses in Ghisolfa, Milan with offset: 0...
# Fetching businesses in Ghisolfa, Milan with offset: 48...
# Fetching businesses in Ghisolfa, Milan with offset: 96...
# Fetching businesses in Ghisolfa, Milan with offset: 144...
# Fetching businesses in Ghisolfa, Milan with offset: 192...
# Reached maximum results for Ghisolfa, Milan.
# Fetching businesses in Giambellino, Milan with offset: 0...
# Fetching businesses in Giambellino, Milan with offset: 48...
# Fetching businesses in Giambellino, Milan with offset: 96...
# Fetching businesses in Giambellino, Milan with offset: 144...
# Fetching businesses in Giambellino, Milan with offset: 192...
# Reached maximum results for Giambellino, Milan.
# Fetching businesses in Giardini Porta Venezia, Milan with offset: 0...
# Fetching businesses in Giardini Porta Venezia, Milan with offset: 48...
# Fetching businesses in Giardini Porta Venezia, Milan with offset: 96...
# Fetching businesses in Giardini Porta Venezia, Milan with offset: 144...
# Fetching businesses in Giardini Porta Venezia, Milan with offset: 192...
# Reached maximum results for Giardini Porta Venezia, Milan.
# Fetching businesses in Gratosoglio - Ticinello, Milan with offset: 0...
# Fetching businesses in Gratosoglio - Ticinello, Milan with offset: 48...
# Fetching businesses in Gratosoglio - Ticinello, Milan with offset: 96...
# Fetching businesses in Gratosoglio - Ticinello, Milan with offset: 144...
# Fetching businesses in Gratosoglio - Ticinello, Milan with offset: 192...
# Reached maximum results for Gratosoglio - Ticinello, Milan.
# Fetching businesses in Greco, Milan with offset: 0...
# Fetching businesses in Greco, Milan with offset: 48...
# Fetching businesses in Greco, Milan with offset: 96...
# Fetching businesses in Greco, Milan with offset: 144...
# Fetching businesses in Greco, Milan with offset: 192...
# Reached maximum results for Greco, Milan.
# Fetching businesses in Guastalla, Milan with offset: 0...
# Fetching businesses in Guastalla, Milan with offset: 48...
# Fetching businesses in Guastalla, Milan with offset: 96...
# Fetching businesses in Guastalla, Milan with offset: 144...
# Fetching businesses in Guastalla, Milan with offset: 192...
# Reached maximum results for Guastalla, Milan.
# Fetching businesses in Isola, Milan with offset: 0...
# Fetching businesses in Isola, Milan with offset: 48...
# Fetching businesses in Isola, Milan with offset: 96...
# Fetching businesses in Isola, Milan with offset: 144...
# Fetching businesses in Isola, Milan with offset: 192...
# Reached maximum results for Isola, Milan.
# Fetching businesses in Lambrate, Milan with offset: 0...
# Fetching businesses in Lambrate, Milan with offset: 48...
# Fetching businesses in Lambrate, Milan with offset: 96...
# Fetching businesses in Lambrate, Milan with offset: 144...
# Fetching businesses in Lambrate, Milan with offset: 192...
# Reached maximum results for Lambrate, Milan.
# Fetching businesses in Lodi - Corvetto, Milan with offset: 0...
# Fetching businesses in Lodi - Corvetto, Milan with offset: 48...
# Fetching businesses in Lodi - Corvetto, Milan with offset: 96...
# Fetching businesses in Lodi - Corvetto, Milan with offset: 144...
# Fetching businesses in Lodi - Corvetto, Milan with offset: 192...
# Reached maximum results for Lodi - Corvetto, Milan.
# Fetching businesses in Lorenteggio, Milan with offset: 0...
# Fetching businesses in Lorenteggio, Milan with offset: 48...
# Fetching businesses in Lorenteggio, Milan with offset: 96...
# Fetching businesses in Lorenteggio, Milan with offset: 144...
# Fetching businesses in Lorenteggio, Milan with offset: 192...
# Reached maximum results for Lorenteggio, Milan.
# Fetching businesses in Loreto, Milan with offset: 0...
# Fetching businesses in Loreto, Milan with offset: 48...
# Fetching businesses in Loreto, Milan with offset: 96...
# Fetching businesses in Loreto, Milan with offset: 144...
# Fetching businesses in Loreto, Milan with offset: 192...
# Reached maximum results for Loreto, Milan.
# Fetching businesses in Maciachini - Maggiolina, Milan with offset: 0...
# Fetching businesses in Maciachini - Maggiolina, Milan with offset: 48...
# Fetching businesses in Maciachini - Maggiolina, Milan with offset: 96...
# Fetching businesses in Maciachini - Maggiolina, Milan with offset: 144...
# Fetching businesses in Maciachini - Maggiolina, Milan with offset: 192...
# Reached maximum results for Maciachini - Maggiolina, Milan.
# Fetching businesses in Magenta - San Vittore, Milan with offset: 0...
# Fetching businesses in Magenta - San Vittore, Milan with offset: 48...
# Fetching businesses in Magenta - San Vittore, Milan with offset: 96...
# Fetching businesses in Magenta - San Vittore, Milan with offset: 144...
# Fetching businesses in Magenta - San Vittore, Milan with offset: 192...
# Reached maximum results for Magenta - San Vittore, Milan.
# Fetching businesses in Maggiore - Musocco, Milan with offset: 0...
# Fetching businesses in Maggiore - Musocco, Milan with offset: 48...
# Fetching businesses in Maggiore - Musocco, Milan with offset: 96...
# Fetching businesses in Maggiore - Musocco, Milan with offset: 144...
# Fetching businesses in Maggiore - Musocco, Milan with offset: 192...
# Reached maximum results for Maggiore - Musocco, Milan.
# Fetching businesses in Mecenate, Milan with offset: 0...
# Fetching businesses in Mecenate, Milan with offset: 48...
# Fetching businesses in Mecenate, Milan with offset: 70...
# No more businesses returned for Mecenate, Milan.
# Fetching businesses in Muggiano, Milan with offset: 0...
# Fetching businesses in Muggiano, Milan with offset: 27...
# No more businesses returned for Muggiano, Milan.
# Fetching businesses in Navigli, Milan with offset: 0...
# Fetching businesses in Navigli, Milan with offset: 48...
# Fetching businesses in Navigli, Milan with offset: 96...
# Fetching businesses in Navigli, Milan with offset: 144...
# Fetching businesses in Navigli, Milan with offset: 192...
# Reached maximum results for Navigli, Milan.
# Fetching businesses in Niguarda - Cà Granda, Milan with offset: 0...
# Fetching businesses in Niguarda - Cà Granda, Milan with offset: 48...
# Fetching businesses in Niguarda - Cà Granda, Milan with offset: 96...
# Fetching businesses in Niguarda - Cà Granda, Milan with offset: 144...
# Fetching businesses in Niguarda - Cà Granda, Milan with offset: 192...
# Reached maximum results for Niguarda - Cà Granda, Milan.
# Fetching businesses in Ortomercato, Milan with offset: 0...
# Fetching businesses in Ortomercato, Milan with offset: 48...
# Fetching businesses in Ortomercato, Milan with offset: 96...
# Fetching businesses in Ortomercato, Milan with offset: 144...
# Fetching businesses in Ortomercato, Milan with offset: 192...
# Reached maximum results for Ortomercato, Milan.
# Fetching businesses in Padova, Milan with offset: 0...
# Fetching businesses in Padova, Milan with offset: 48...
# Fetching businesses in Padova, Milan with offset: 96...
# Fetching businesses in Padova, Milan with offset: 144...
# Fetching businesses in Padova, Milan with offset: 192...
# Reached maximum results for Padova, Milan.
# Fetching businesses in Pagano, Milan with offset: 0...
# Fetching businesses in Pagano, Milan with offset: 48...
# Fetching businesses in Pagano, Milan with offset: 96...
# Fetching businesses in Pagano, Milan with offset: 144...
# Fetching businesses in Pagano, Milan with offset: 192...
# Reached maximum results for Pagano, Milan.
# Fetching businesses in Parco Agricolo Sud, Milan with offset: 0...
# Fetching businesses in Parco Agricolo Sud, Milan with offset: 48...
# Fetching businesses in Parco Agricolo Sud, Milan with offset: 96...
# Fetching businesses in Parco Agricolo Sud, Milan with offset: 144...
# Fetching businesses in Parco Agricolo Sud, Milan with offset: 192...
# Reached maximum results for Parco Agricolo Sud, Milan.
# Fetching businesses in Parco Bosco In Città, Milan with offset: 0...
# Fetching businesses in Parco Bosco In Città, Milan with offset: 48...
# Fetching businesses in Parco Bosco In Città, Milan with offset: 96...
# Fetching businesses in Parco Bosco In Città, Milan with offset: 144...
# Fetching businesses in Parco Bosco In Città, Milan with offset: 192...
# Reached maximum results for Parco Bosco In Città, Milan.
# Fetching businesses in Parco Forlanini - Ortica, Milan with offset: 0...
# Fetching businesses in Parco Forlanini - Ortica, Milan with offset: 48...
# Fetching businesses in Parco Forlanini - Ortica, Milan with offset: 96...
# Fetching businesses in Parco Forlanini - Ortica, Milan with offset: 144...
# Fetching businesses in Parco Forlanini - Ortica, Milan with offset: 192...
# Reached maximum results for Parco Forlanini - Ortica, Milan.
# Fetching businesses in Parco Lambro - Cimiano, Milan with offset: 0...
# Fetching businesses in Parco Lambro - Cimiano, Milan with offset: 48...
# Fetching businesses in Parco Lambro - Cimiano, Milan with offset: 96...
# Fetching businesses in Parco Lambro - Cimiano, Milan with offset: 144...
# Fetching businesses in Parco Lambro - Cimiano, Milan with offset: 192...
# Reached maximum results for Parco Lambro - Cimiano, Milan.
# Fetching businesses in Parco Monluè - Ponte Lambro, Milan with offset: 0...
# Fetching businesses in Parco Monluè - Ponte Lambro, Milan with offset: 48...
# Fetching businesses in Parco Monluè - Ponte Lambro, Milan with offset: 96...
# Fetching businesses in Parco Monluè - Ponte Lambro, Milan with offset: 144...
# Fetching businesses in Parco Monluè - Ponte Lambro, Milan with offset: 192...
# Reached maximum results for Parco Monluè - Ponte Lambro, Milan.
# Fetching businesses in Parco Nord, Milan with offset: 0...
# Fetching businesses in Parco Nord, Milan with offset: 48...
# Fetching businesses in Parco Nord, Milan with offset: 96...
# Fetching businesses in Parco Nord, Milan with offset: 144...
# Fetching businesses in Parco Nord, Milan with offset: 192...
# Reached maximum results for Parco Nord, Milan.
# Fetching businesses in Parco Sempione, Milan with offset: 0...
# Fetching businesses in Parco Sempione, Milan with offset: 48...
# Fetching businesses in Parco Sempione, Milan with offset: 96...
# Fetching businesses in Parco Sempione, Milan with offset: 144...
# Fetching businesses in Parco Sempione, Milan with offset: 192...
# Reached maximum results for Parco Sempione, Milan.
# Fetching businesses in Parco dei Navigli, Milan with offset: 0...
# Fetching businesses in Parco dei Navigli, Milan with offset: 48...
# Fetching businesses in Parco dei Navigli, Milan with offset: 96...
# Fetching businesses in Parco dei Navigli, Milan with offset: 144...
# Fetching businesses in Parco dei Navigli, Milan with offset: 192...
# Reached maximum results for Parco dei Navigli, Milan.
# Fetching businesses in Porta Romana, Milan with offset: 0...
# Fetching businesses in Porta Romana, Milan with offset: 48...
# Fetching businesses in Porta Romana, Milan with offset: 96...
# Fetching businesses in Porta Romana, Milan with offset: 144...
# Fetching businesses in Porta Romana, Milan with offset: 192...
# Reached maximum results for Porta Romana, Milan.
# Fetching businesses in Portello, Milan with offset: 0...
# Fetching businesses in Portello, Milan with offset: 48...
# Fetching businesses in Portello, Milan with offset: 96...
# Fetching businesses in Portello, Milan with offset: 144...
# Fetching businesses in Portello, Milan with offset: 192...
# Reached maximum results for Portello, Milan.
# Fetching businesses in Qt 8, Milan with offset: 0...
# Fetching businesses in Qt 8, Milan with offset: 48...
# Fetching businesses in Qt 8, Milan with offset: 96...
# Fetching businesses in Qt 8, Milan with offset: 144...
# Fetching businesses in Qt 8, Milan with offset: 192...
# Reached maximum results for Qt 8, Milan.
# Fetching businesses in Quarto Cagnino, Milan with offset: 0...
# Fetching businesses in Quarto Cagnino, Milan with offset: 48...
# Fetching businesses in Quarto Cagnino, Milan with offset: 61...
# No more businesses returned for Quarto Cagnino, Milan.
# Fetching businesses in Quinto Romano, Milan with offset: 0...
# Fetching businesses in Quinto Romano, Milan with offset: 48...
# Fetching businesses in Quinto Romano, Milan with offset: 96...
# Fetching businesses in Quinto Romano, Milan with offset: 144...
# Fetching businesses in Quinto Romano, Milan with offset: 192...
# Reached maximum results for Quinto Romano, Milan.
# Fetching businesses in Quintosole, Milan with offset: 0...
# Fetching businesses in Quintosole, Milan with offset: 48...
# Fetching businesses in Quintosole, Milan with offset: 96...
# Fetching businesses in Quintosole, Milan with offset: 144...
# Fetching businesses in Quintosole, Milan with offset: 192...
# Reached maximum results for Quintosole, Milan.
# Fetching businesses in Ripamonti, Milan with offset: 0...
# Fetching businesses in Ripamonti, Milan with offset: 48...
# Fetching businesses in Ripamonti, Milan with offset: 96...
# Fetching businesses in Ripamonti, Milan with offset: 144...
# Fetching businesses in Ripamonti, Milan with offset: 192...
# Reached maximum results for Ripamonti, Milan.
# Fetching businesses in Rogoredo, Milan with offset: 0...
# Fetching businesses in Rogoredo, Milan with offset: 48...
# Fetching businesses in Rogoredo, Milan with offset: 96...
# Fetching businesses in Rogoredo, Milan with offset: 144...
# Fetching businesses in Rogoredo, Milan with offset: 192...
# Reached maximum results for Rogoredo, Milan.
# Fetching businesses in Ronchetto Sul Naviglio, Milan with offset: 0...
# Fetching businesses in Ronchetto Sul Naviglio, Milan with offset: 48...
# Fetching businesses in Ronchetto Sul Naviglio, Milan with offset: 96...
# Fetching businesses in Ronchetto Sul Naviglio, Milan with offset: 144...
# Fetching businesses in Ronchetto Sul Naviglio, Milan with offset: 192...
# Reached maximum results for Ronchetto Sul Naviglio, Milan.
# Fetching businesses in Ronchetto delle Rane, Milan with offset: 0...
# Fetching businesses in Ronchetto delle Rane, Milan with offset: 48...
# Fetching businesses in Ronchetto delle Rane, Milan with offset: 96...
# Fetching businesses in Ronchetto delle Rane, Milan with offset: 144...
# Fetching businesses in Ronchetto delle Rane, Milan with offset: 192...
# Reached maximum results for Ronchetto delle Rane, Milan.
# Fetching businesses in San Cristoforo, Milan with offset: 0...
# Fetching businesses in San Cristoforo, Milan with offset: 48...
# Fetching businesses in San Cristoforo, Milan with offset: 96...
# Fetching businesses in San Cristoforo, Milan with offset: 144...
# Fetching businesses in San Cristoforo, Milan with offset: 192...
# Reached maximum results for San Cristoforo, Milan.
# Fetching businesses in San Siro, Milan with offset: 0...
# Fetching businesses in San Siro, Milan with offset: 48...
# Fetching businesses in San Siro, Milan with offset: 96...
# Fetching businesses in San Siro, Milan with offset: 144...
# Fetching businesses in San Siro, Milan with offset: 192...
# Reached maximum results for San Siro, Milan.
# Fetching businesses in Sarpi, Milan with offset: 0...
# Fetching businesses in Sarpi, Milan with offset: 48...
# Fetching businesses in Sarpi, Milan with offset: 96...
# Fetching businesses in Sarpi, Milan with offset: 144...
# Fetching businesses in Sarpi, Milan with offset: 192...
# Reached maximum results for Sarpi, Milan.
# Fetching businesses in Scalo Romana, Milan with offset: 0...
# Fetching businesses in Scalo Romana, Milan with offset: 48...
# Fetching businesses in Scalo Romana, Milan with offset: 96...
# Fetching businesses in Scalo Romana, Milan with offset: 144...
# Fetching businesses in Scalo Romana, Milan with offset: 192...
# Reached maximum results for Scalo Romana, Milan.
# Fetching businesses in Selinunte, Milan with offset: 0...
# Fetching businesses in Selinunte, Milan with offset: 48...
# Fetching businesses in Selinunte, Milan with offset: 96...
# Fetching businesses in Selinunte, Milan with offset: 144...
# Fetching businesses in Selinunte, Milan with offset: 192...
# Reached maximum results for Selinunte, Milan.
# Fetching businesses in Stadera, Milan with offset: 0...
# Fetching businesses in Stadera, Milan with offset: 48...
# Fetching businesses in Stadera, Milan with offset: 96...
# Fetching businesses in Stadera, Milan with offset: 144...
# Fetching businesses in Stadera, Milan with offset: 192...
# Reached maximum results for Stadera, Milan.
# Fetching businesses in Stephenson, Milan with offset: 0...
# Fetching businesses in Stephenson, Milan with offset: 48...
# Fetching businesses in Stephenson, Milan with offset: 55...
# No more businesses returned for Stephenson, Milan.
# Fetching businesses in Tibaldi, Milan with offset: 0...
# Fetching businesses in Tibaldi, Milan with offset: 48...
# Fetching businesses in Tibaldi, Milan with offset: 96...
# Fetching businesses in Tibaldi, Milan with offset: 144...
# Fetching businesses in Tibaldi, Milan with offset: 192...
# Reached maximum results for Tibaldi, Milan.
# Fetching businesses in Ticinese, Milan with offset: 0...
# Fetching businesses in Ticinese, Milan with offset: 48...
# Fetching businesses in Ticinese, Milan with offset: 96...
# Fetching businesses in Ticinese, Milan with offset: 144...
# Fetching businesses in Ticinese, Milan with offset: 192...
# Reached maximum results for Ticinese, Milan.
# Fetching businesses in Tortona, Milan with offset: 0...
# Fetching businesses in Tortona, Milan with offset: 48...
# Fetching businesses in Tortona, Milan with offset: 96...
# Fetching businesses in Tortona, Milan with offset: 144...
# Fetching businesses in Tortona, Milan with offset: 192...
# Reached maximum results for Tortona, Milan.
# Fetching businesses in Tre Torri, Milan with offset: 0...
# Fetching businesses in Tre Torri, Milan with offset: 48...
# Fetching businesses in Tre Torri, Milan with offset: 96...
# Fetching businesses in Tre Torri, Milan with offset: 144...
# Fetching businesses in Tre Torri, Milan with offset: 192...
# Reached maximum results for Tre Torri, Milan.
# Fetching businesses in Trenno, Milan with offset: 0...
# Fetching businesses in Trenno, Milan with offset: 48...
# Fetching businesses in Trenno, Milan with offset: 96...
# Fetching businesses in Trenno, Milan with offset: 144...
# Fetching businesses in Trenno, Milan with offset: 192...
# Reached maximum results for Trenno, Milan.
# Fetching businesses in Triulzo Superiore, Milan with offset: 0...
# Fetching businesses in Triulzo Superiore, Milan with offset: 48...
# Fetching businesses in Triulzo Superiore, Milan with offset: 96...
# Fetching businesses in Triulzo Superiore, Milan with offset: 144...
# Fetching businesses in Triulzo Superiore, Milan with offset: 192...
# Reached maximum results for Triulzo Superiore, Milan.
# Fetching businesses in Umbria - Molise, Milan with offset: 0...
# Fetching businesses in Umbria - Molise, Milan with offset: 48...
# Fetching businesses in Umbria - Molise, Milan with offset: 96...
# Fetching businesses in Umbria - Molise, Milan with offset: 144...
# Fetching businesses in Umbria - Molise, Milan with offset: 192...
# Reached maximum results for Umbria - Molise, Milan.
# Fetching businesses in Viale Monza, Milan with offset: 0...
# Fetching businesses in Viale Monza, Milan with offset: 48...
# Fetching businesses in Viale Monza, Milan with offset: 96...
# Fetching businesses in Viale Monza, Milan with offset: 144...
# Fetching businesses in Viale Monza, Milan with offset: 192...
# Reached maximum results for Viale Monza, Milan.
# Fetching businesses in Vigentina, Milan with offset: 0...
# Fetching businesses in Vigentina, Milan with offset: 48...
# Fetching businesses in Vigentina, Milan with offset: 96...
# Fetching businesses in Vigentina, Milan with offset: 144...
# Fetching businesses in Vigentina, Milan with offset: 192...
# Reached maximum results for Vigentina, Milan.
# Fetching businesses in Villapizzone, Milan with offset: 0...
# Fetching businesses in Villapizzone, Milan with offset: 48...
# Fetching businesses in Villapizzone, Milan with offset: 96...
# Fetching businesses in Villapizzone, Milan with offset: 144...
# Fetching businesses in Villapizzone, Milan with offset: 192...
# Fetching businesses in Villapizzone, Milan with offset: 220...
# HTTP error occurred for Villapizzone, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Villapizzone%2C+Milan&term=restaurant&limit=48&offset=220
# Fetching businesses in Washington, Milan with offset: 0...
# Fetching businesses in Washington, Milan with offset: 48...
# Fetching businesses in Washington, Milan with offset: 96...
# Fetching businesses in Washington, Milan with offset: 144...
# Fetching businesses in Washington, Milan with offset: 192...
# Reached maximum results for Washington, Milan.
# Fetching businesses in XXII Marzo, Milan with offset: 0...
# Fetching businesses in XXII Marzo, Milan with offset: 48...
# Fetching businesses in XXII Marzo, Milan with offset: 96...
# Fetching businesses in XXII Marzo, Milan with offset: 144...
# Fetching businesses in XXII Marzo, Milan with offset: 192...
# Reached maximum results for XXII Marzo, Milan.
# Fetching businesses in Forze Armate, Milan with offset: 0...
# Fetching businesses in Forze Armate, Milan with offset: 48...
# Fetching businesses in Forze Armate, Milan with offset: 96...
# Fetching businesses in Forze Armate, Milan with offset: 144...
# Fetching businesses in Forze Armate, Milan with offset: 192...
# Reached maximum results for Forze Armate, Milan.
#                Fetch Location           Business Name  \
# 0  Parco delle Abbazie, Milan              Il Castigo
# 1  Parco delle Abbazie, Milan          Settembrini 18
# 2  Parco delle Abbazie, Milan                Da Oscar
# 3  Parco delle Abbazie, Milan     Osteria della Pista
# 4  Parco delle Abbazie, Milan  Salsamenteria di Parma
#
#             Business Address                    Categories  \
# 0          Piazza Scipione 7            Wine Bars, Italian
# 1         Via Settembrini 18       Italian, Seafood, Pizza
# 2      Via Lazzaro Palazzi 4  Barbeque, Seafood, Wine Bars
# 3              Via Verbano 1       Seafood, Italian, Pizza
# 4  Via San Pietro all'Orto 9                       Emilian
#
#    Average Star Rating  Review Count Price   Latitude  Longitude  \
# 0                  4.8            40    €€  45.684583   8.706904
# 1                  4.5           560    €€  45.481243   9.205606
# 2                  4.4           316    €€  45.476440   9.205910
# 3                  4.6            41    €€  45.674290   8.739960
# 4                  4.4           181    €€  45.466267   9.195122
#
#                    geometry
# 0   POINT (8.7069 45.68458)
# 1  POINT (9.20561 45.48124)
# 2  POINT (9.20591 45.47644)
# 3  POINT (8.73996 45.67429)
# 4  POINT (9.19512 45.46627)
# Total businesses collected: 18527

# %%
Restaurants
# Out:
#                    Fetch Location           Business Name  \
# 0      Parco delle Abbazie, Milan              Il Castigo
# 1      Parco delle Abbazie, Milan          Settembrini 18
# 2      Parco delle Abbazie, Milan                Da Oscar
# 3      Parco delle Abbazie, Milan     Osteria della Pista
# 4      Parco delle Abbazie, Milan  Salsamenteria di Parma
# ...                           ...                     ...
# 18522         Forze Armate, Milan              Tokyo Nomi
# 18523         Forze Armate, Milan                  Felice
# 18524         Forze Armate, Milan               Mezzaluna
# 18525         Forze Armate, Milan    Pizzeria dell'Angelo
# 18526         Forze Armate, Milan              Casa Lucia
#
#                 Business Address                     Categories  \
# 0              Piazza Scipione 7             Wine Bars, Italian
# 1             Via Settembrini 18        Italian, Seafood, Pizza
# 2          Via Lazzaro Palazzi 4   Barbeque, Seafood, Wine Bars
# 3                  Via Verbano 1        Seafood, Italian, Pizza
# 4      Via San Pietro all'Orto 9                        Emilian
# ...                          ...                            ...
# 18522             Via Novara 123  Japanese, Chinese, Sushi Bars
# 18523           Viale Certosa 97                        Chinese
# 18524           Via Marostica 29        Italian, Seafood, Pizza
# 18525             Via Belfiore 7                          Pizza
# 18526        Via Carlo Ravizza 2                        Italian
#
#        Average Star Rating  Review Count Price   Latitude  Longitude  \
# 0                      4.8            40    €€  45.684583   8.706904
# 1                      4.5           560    €€  45.481243   9.205606
# 2                      4.4           316    €€  45.476440   9.205910
# 3                      4.6            41    €€  45.674290   8.739960
# 4                      4.4           181    €€  45.466267   9.195122
# ...                    ...           ...   ...        ...        ...
# 18522                  3.0             1   N/A  45.473480   9.117590
# 18523                  4.0             3   N/A  45.493960   9.142450
# 18524                  4.0             1   N/A  45.461540   9.143417
# 18525                  4.0             5    €€  45.467230   9.158300
# 18526                  4.1            14  €€€€  45.467470   9.152720
#
#                        geometry
# 0       POINT (8.7069 45.68458)
# 1      POINT (9.20561 45.48124)
# 2      POINT (9.20591 45.47644)
# 3      POINT (8.73996 45.67429)
# 4      POINT (9.19512 45.46627)
# ...                         ...
# 18522  POINT (9.11759 45.47348)
# 18523  POINT (9.14245 45.49396)
# 18524  POINT (9.14342 45.46154)
# 18525   POINT (9.1583 45.46723)
# 18526  POINT (9.15272 45.46747)
#
# [18527 rows x 10 columns]

# %%
# Removing the dupes
Restaurants_nodup = Restaurants.drop_duplicates(subset=['Business Name','Business Address','Categories','Average Star Rating',
                                                        'Review Count','Price','geometry'])
Restaurants_nodup
# Out:
#                    Fetch Location           Business Name  \
# 0      Parco delle Abbazie, Milan              Il Castigo
# 1      Parco delle Abbazie, Milan          Settembrini 18
# 2      Parco delle Abbazie, Milan                Da Oscar
# 3      Parco delle Abbazie, Milan     Osteria della Pista
# 4      Parco delle Abbazie, Milan  Salsamenteria di Parma
# ...                           ...                     ...
# 18273           XXII Marzo, Milan           Mani In Pasta
# 18275           XXII Marzo, Milan            La Risacca 6
# 18281           XXII Marzo, Milan                Pandenus
# 18286           XXII Marzo, Milan                   Spoon
# 18423         Forze Armate, Milan         Roadhouse Grill
#
#                   Business Address  \
# 0                Piazza Scipione 7
# 1               Via Settembrini 18
# 2            Via Lazzaro Palazzi 4
# 3                    Via Verbano 1
# 4        Via San Pietro all'Orto 9
# ...                            ...
# 18273        Via Carlo Pisacane 47
# 18275                Via Marcona 6
# 18281           Corso Concordia 11
# 18286                Via Marcona 6
# 18423  Viale Cristoforo Colombo 13
#
#                                         Categories  Average Star Rating  \
# 0                               Wine Bars, Italian                  4.8
# 1                          Italian, Seafood, Pizza                  4.5
# 2                     Barbeque, Seafood, Wine Bars                  4.4
# 3                          Seafood, Italian, Pizza                  4.6
# 4                                          Emilian                  4.4
# ...                                            ...                  ...
# 18273                               Pizza, Italian                  3.7
# 18275                                      Seafood                  3.3
# 18281  Cocktail Bars, Breakfast & Brunch, Bakeries                  3.2
# 18286                         Japanese, Sushi Bars                  4.0
# 18423                        Steakhouses, Barbeque                  4.0
#
#        Review Count Price   Latitude  Longitude                  geometry
# 0                40    €€  45.684583   8.706904   POINT (8.7069 45.68458)
# 1               560    €€  45.481243   9.205606  POINT (9.20561 45.48124)
# 2               316    €€  45.476440   9.205910  POINT (9.20591 45.47644)
# 3                41    €€  45.674290   8.739960  POINT (8.73996 45.67429)
# 4               181    €€  45.466267   9.195122  POINT (9.19512 45.46627)
# ...             ...   ...        ...        ...                       ...
# 18273             6   N/A  45.472920   9.210990  POINT (9.21099 45.47292)
# 18275            16  €€€€  45.463390   9.208240  POINT (9.20824 45.46339)
# 18281            10    €€  45.468204   9.210167   POINT (9.21017 45.4682)
# 18286             1   €€€  45.463469   9.208250  POINT (9.20825 45.46347)
# 18423             2    €€  45.424919   9.067463  POINT (9.06746 45.42492)
#
# [3330 rows x 10 columns]

# %%
# Have to be the same type
print(Restaurants_nodup.crs)  # Restaurants CRS
print(gdf_combined.crs)  # Neighborhood polygons CRS
# Out:
# EPSG:4326
# EPSG:4326

# %% [markdown]
# # Spatial Join

# %%
# Perform the spatial join
joined = sjoin(Restaurants_nodup, gdf_combined, how="left", predicate="within")

# Check the result
joined
# Out:
#                    Fetch Location           Business Name  \
# 0      Parco delle Abbazie, Milan              Il Castigo
# 1      Parco delle Abbazie, Milan          Settembrini 18
# 2      Parco delle Abbazie, Milan                Da Oscar
# 3      Parco delle Abbazie, Milan     Osteria della Pista
# 4      Parco delle Abbazie, Milan  Salsamenteria di Parma
# ...                           ...                     ...
# 18273           XXII Marzo, Milan           Mani In Pasta
# 18275           XXII Marzo, Milan            La Risacca 6
# 18281           XXII Marzo, Milan                Pandenus
# 18286           XXII Marzo, Milan                   Spoon
# 18423         Forze Armate, Milan         Roadhouse Grill
#
#                   Business Address  \
# 0                Piazza Scipione 7
# 1               Via Settembrini 18
# 2            Via Lazzaro Palazzi 4
# 3                    Via Verbano 1
# 4        Via San Pietro all'Orto 9
# ...                            ...
# 18273        Via Carlo Pisacane 47
# 18275                Via Marcona 6
# 18281           Corso Concordia 11
# 18286                Via Marcona 6
# 18423  Viale Cristoforo Colombo 13
#
#                                         Categories  Average Star Rating  \
# 0                               Wine Bars, Italian                  4.8
# 1                          Italian, Seafood, Pizza                  4.5
# 2                     Barbeque, Seafood, Wine Bars                  4.4
# 3                          Seafood, Italian, Pizza                  4.6
# 4                                          Emilian                  4.4
# ...                                            ...                  ...
# 18273                               Pizza, Italian                  3.7
# 18275                                      Seafood                  3.3
# 18281  Cocktail Bars, Breakfast & Brunch, Bakeries                  3.2
# 18286                         Japanese, Sushi Bars                  4.0
# 18423                        Steakhouses, Barbeque                  4.0
#
#        Review Count Price   Latitude  Longitude                  geometry  \
# 0                40    €€  45.684583   8.706904   POINT (8.7069 45.68458)
# 1               560    €€  45.481243   9.205606  POINT (9.20561 45.48124)
# 2               316    €€  45.476440   9.205910  POINT (9.20591 45.47644)
# 3                41    €€  45.674290   8.739960  POINT (8.73996 45.67429)
# 4               181    €€  45.466267   9.195122  POINT (9.19512 45.46627)
# ...             ...   ...        ...        ...                       ...
# 18273             6   N/A  45.472920   9.210990  POINT (9.21099 45.47292)
# 18275            16  €€€€  45.463390   9.208240  POINT (9.20824 45.46339)
# 18281            10    €€  45.468204   9.210167   POINT (9.21017 45.4682)
# 18286             1   €€€  45.463469   9.208250  POINT (9.20825 45.46347)
# 18423             2    €€  45.424919   9.067463  POINT (9.06746 45.42492)
#
#        index_right            Neighborhood
# 0              NaN                     NaN
# 1             11.0  Buenos Aires - Venezia
# 2             11.0  Buenos Aires - Venezia
# 3              NaN                     NaN
# 4             21.0                   Duomo
# ...            ...                     ...
# 18273         11.0  Buenos Aires - Venezia
# 18275         83.0              XXII Marzo
# 18281         11.0  Buenos Aires - Venezia
# 18286         83.0              XXII Marzo
# 18423          NaN                     NaN
#
# [3330 rows x 12 columns]

# %%
joined[joined['Business Name']=='Tartufotto'] # all correct
# Out:
#                 Fetch Location Business Name Business Address  \
# 47  Parco delle Abbazie, Milan    Tartufotto     Via Cusani 8
#
#                      Categories  Average Star Rating  Review Count Price  \
# 47  Italian, Wine Bars, Bistros                  4.4            39   €€€
#
#      Latitude  Longitude                  geometry  index_right Neighborhood
# 47  45.468923   9.184549  POINT (9.18455 45.46892)          9.0        Brera

# %%
joined.nunique() # there is something wrong with the prices
# Out:
# Fetch Location           70
# Business Name          3110
# Business Address       3105
# Categories             1305
# Average Star Rating      37
# Review Count            113
# Price                     9
# Latitude               3161
# Longitude              3184
# geometry               3264
# index_right              83
# Neighborhood             83
# dtype: int64

# %%
joined["Price"].unique() # there seem to be prices not in euros
# Out:
# array(['€€', 'N/A', '€€€', '€', '$$', '€€€€', '$$$', '$$$$', '$'],
#       dtype=object)

# %%
joined[joined["Price"] == '$$'] # they correspond to geometries outside of the neighborhoods in Milan
# Out:
#                       Fetch Location            Business Name  \
# 31        Parco delle Abbazie, Milan    Restaurant Jägerstube
# 2031   Buenos Aires - Venezia, Milan            Parrilla Peña
# 2033   Buenos Aires - Venezia, Milan  El Preferido de Palermo
# 2038   Buenos Aires - Venezia, Milan                    Chori
# 2039   Buenos Aires - Venezia, Milan          Santos Manjares
# ...                              ...                      ...
# 2265   Buenos Aires - Venezia, Milan          Los Portugueses
# 11633       Parco dei Navigli, Milan     Ristorante Argentino
# 16909         Umbria - Molise, Milan              Al Battello
# 16939         Umbria - Molise, Milan        Locanda Locarnese
# 17080         Umbria - Molise, Milan              dü Saas Fee
#
#              Business Address                      Categories  \
# 31                       None                      Swiss Food
# 2031       Rodríguez Peña 682          Argentine, Steakhouses
# 2033   Jorge Luis Borges 2108                 Pubs, Argentine
# 2038              Thames 1653  Steakhouses, Salad, Vegetarian
# 2039             Paraguay 938          Argentine, Steakhouses
# ...                       ...                             ...
# 2265   Av. Angel Gallardo 800                      Portuguese
# 11633          Piazza Riforma                  Bistros, Pizza
# 16909          Riva dal Drèra                         Italian
# 16939             Via Bossi 1                         Italian
# 17080          Untere Gasse 3                      Swiss Food
#
#        Average Star Rating  Review Count Price   Latitude  Longitude  \
# 31                     5.0             1    $$  46.214226   7.854204
# 2031                   4.4           221    $$ -34.600975 -58.391444
# 2033                   4.1            82    $$ -34.585412 -58.425359
# 2038                   4.3           136    $$ -34.587838 -58.430244
# 2039                   4.4            62    $$ -34.597871 -58.380344
# ...                    ...           ...   ...        ...        ...
# 2265                   3.3            12    $$ -34.606311 -58.441771
# 11633                  4.3            24    $$  46.004090   8.951460
# 16909                  5.0             3    $$  45.922900   8.917160
# 16939                  4.9             7    $$  46.169083   8.794450
# 17080                  5.0             5    $$  46.106692   7.925513
#
#                           geometry  index_right Neighborhood
# 31         POINT (7.8542 46.21423)          NaN          NaN
# 2031   POINT (-58.39144 -34.60097)          NaN          NaN
# 2033   POINT (-58.42536 -34.58541)          NaN          NaN
# 2038   POINT (-58.43024 -34.58784)          NaN          NaN
# 2039   POINT (-58.38034 -34.59787)          NaN          NaN
# ...                            ...          ...          ...
# 2265   POINT (-58.44177 -34.60631)          NaN          NaN
# 11633     POINT (8.95146 46.00409)          NaN          NaN
# 16909      POINT (8.91716 45.9229)          NaN          NaN
# 16939     POINT (8.79445 46.16908)          NaN          NaN
# 17080     POINT (7.92551 46.10669)          NaN          NaN
#
# [92 rows x 12 columns]

# %%
# Remove rows where the geometry is NaN
PolyRestaurants = joined[~joined["Neighborhood"].isna()]
PolyRestaurants = PolyRestaurants.reset_index(drop=True)

# Keeping only relevant variables
PolyRestaurants = PolyRestaurants[["Business Name", "Business Address", "Categories", "Average Star Rating",
                                   "Review Count", "Price", "geometry", "Neighborhood"]]

# Saving the file
PolyRestaurants.to_file("PolyRestaurants.geojson", driver="GeoJSON")

# Print the cleaned GeoDataFrame
PolyRestaurants
# Out:
#                Business Name           Business Address  \
# 0             Settembrini 18         Via Settembrini 18
# 1                   Da Oscar      Via Lazzaro Palazzi 4
# 2     Salsamenteria di Parma  Via San Pietro all'Orto 9
# 3          Rizzo Come a Casa           Via Varesina 163
# 4                 L'Immagine            Via Varesina 61
# ...                      ...                        ...
# 2649               Cucineria        Viale Monte Nero 76
# 2650           Mani In Pasta      Via Carlo Pisacane 47
# 2651            La Risacca 6              Via Marcona 6
# 2652                Pandenus         Corso Concordia 11
# 2653                   Spoon              Via Marcona 6
#
#                                        Categories  Average Star Rating  \
# 0                         Italian, Seafood, Pizza                  4.5
# 1                    Barbeque, Seafood, Wine Bars                  4.4
# 2                                         Emilian                  4.4
# 3                                         Italian                  5.0
# 4                         Italian, Bistros, Cafes                  4.9
# ...                                           ...                  ...
# 2649                                      Italian                  3.3
# 2650                               Pizza, Italian                  3.7
# 2651                                      Seafood                  3.3
# 2652  Cocktail Bars, Breakfast & Brunch, Bakeries                  3.2
# 2653                         Japanese, Sushi Bars                  4.0
#
#       Review Count Price                  geometry            Neighborhood
# 0              560    €€  POINT (9.20561 45.48124)  Buenos Aires - Venezia
# 1              316    €€  POINT (9.20591 45.47644)  Buenos Aires - Venezia
# 2              181    €€  POINT (9.19512 45.46627)                   Duomo
# 3               10   N/A  POINT (9.13914 45.50287)            Villapizzone
# 4               97    €€  POINT (9.14548 45.49722)            Villapizzone
# ...            ...   ...                       ...                     ...
# 2649             3    €€  POINT (9.20814 45.46076)              XXII Marzo
# 2650             6   N/A  POINT (9.21099 45.47292)  Buenos Aires - Venezia
# 2651            16  €€€€  POINT (9.20824 45.46339)              XXII Marzo
# 2652            10    €€   POINT (9.21017 45.4682)  Buenos Aires - Venezia
# 2653             1   €€€  POINT (9.20825 45.46347)              XXII Marzo
#
# [2654 rows x 8 columns]

# %% [markdown]
# ### There are quite a few restaurants with no information available about their price, there is not much we can do except aknowledge the fact that the data retrieved through the Yelp API is not ideal for calculating statistics about the price of restaurants

# %%
# Rows with no price information
count_na = PolyRestaurants[PolyRestaurants['Price'] == 'N/A'].shape[0]

print(f"Number of rows with Price = 'N/A': {count_na}")
# Out:
# Number of rows with Price = 'N/A': 1063
