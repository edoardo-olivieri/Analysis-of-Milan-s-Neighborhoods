# %%
import pandas as pd
import geopandas as gpd
import requests
import time
from shapely.geometry import Point
from geopandas.tools import sjoin

# %%
# Import of the Polygons
gdf_combined = gpd.read_file("C:/Users/edoar/combined_quartieri.geojson")

# %% [markdown]
# # API di YELP

# %%
neighborhoods = [f"{name}, Milan" for name in gdf_combined["Neighborhood"].tolist()]
neighborhoods
# Out:
# ['Parco delle Abbazie, Milan',
#  'Adriano, Milan',
#  'Affori, Milan',
#  'Baggio, Milan',
#  'Bande Nere, Milan',
#  'Barona, Milan',
#  'Bicocca, Milan',
#  'Bovisasca, Milan',
#  'Bovisa, Milan',
#  'Brera, Milan',
#  'Bruzzano, Milan',
#  'Buenos Aires - Venezia, Milan',
#  'Cantalupa, Milan',
#  'Cascina Triulza - Expo, Milan',
#  'Centrale, Milan',
#  'Chiaravalle, Milan',
#  'Città Studi, Milan',
#  'Comasina, Milan',
#  'Corsica, Milan',
#  'De Angeli - Monte Rosa, Milan',
#  'Dergano, Milan',
#  'Duomo, Milan',
#  'Ex Om - Morivione, Milan',
#  'Farini, Milan',
#  'GARIBALDI REPUBBLICA, Milan',
#  'Gallaratese, Milan',
#  'Ghisolfa, Milan',
#  'Giambellino, Milan',
#  'Giardini Porta Venezia, Milan',
#  'Gratosoglio - Ticinello, Milan',
#  'Greco, Milan',
#  'Guastalla, Milan',
#  'Isola, Milan',
#  'Lambrate, Milan',
#  'Lodi - Corvetto, Milan',
#  'Lorenteggio, Milan',
#  'Loreto, Milan',
#  'Maciachini - Maggiolina, Milan',
#  'Magenta - San Vittore, Milan',
#  'Maggiore - Musocco, Milan',
#  'Mecenate, Milan',
#  'Muggiano, Milan',
#  'Navigli, Milan',
#  'Niguarda - Cà Granda, Milan',
#  'Ortomercato, Milan',
#  'Padova, Milan',
#  'Pagano, Milan',
#  'Parco Agricolo Sud, Milan',
#  'Parco Bosco In Città, Milan',
#  'Parco Forlanini - Ortica, Milan',
#  'Parco Lambro - Cimiano, Milan',
#  'Parco Monluè - Ponte Lambro, Milan',
#  'Parco Nord, Milan',
#  'Parco Sempione, Milan',
#  'Parco dei Navigli, Milan',
#  'Porta Romana, Milan',
#  'Portello, Milan',
#  'Qt 8, Milan',
#  'Quarto Cagnino, Milan',
#  'Quinto Romano, Milan',
#  'Quintosole, Milan',
#  'Ripamonti, Milan',
#  'Rogoredo, Milan',
#  'Ronchetto Sul Naviglio, Milan',
#  'Ronchetto delle Rane, Milan',
#  'San Cristoforo, Milan',
#  'San Siro, Milan',
#  'Sarpi, Milan',
#  'Scalo Romana, Milan',
#  'Selinunte, Milan',
#  'Stadera, Milan',
#  'Stephenson, Milan',
#  'Tibaldi, Milan',
#  'Ticinese, Milan',
#  'Tortona, Milan',
#  'Tre Torri, Milan',
#  'Trenno, Milan',
#  'Triulzo Superiore, Milan',
#  'Umbria - Molise, Milan',
#  'Viale Monza, Milan',
#  'Vigentina, Milan',
#  'Villapizzone, Milan',
#  'Washington, Milan',
#  'XXII Marzo, Milan',
#  'Forze Armate, Milan']

# %%
# Replace with your Yelp API key
API_KEY = "6CbFJGYPopltfBbkb00hIFGRI4XBrAsccPevTJ53ol4YIuJrF48kEylTmKvEl4-TEP8p0pEc3ydzUsatpgGI5aqSHCsysi5-yWyeJD3V-6al5x6_AcFkw23LehKEZ3Yx"
HEADERS = {"Authorization": f"Bearer {API_KEY}"}

# Constants
businesses_per_request = 48  # Maximum allowed by Yelp per request

def make_request(url, params=None):
    """
    Makes a request to the Yelp API.
    """
    response = requests.get(url, headers=HEADERS, params=params)
    response.raise_for_status()
    return response

def search_businesses(location, term="nightlife", limit=businesses_per_request, offset=0):
    """
    Searches for nightlife businesses in a given location with pagination.
    """
    url = "https://api.yelp.com/v3/businesses/search"
    params = {
        "location": location,  # Neighborhood or address
        "term": term,  # Term like "nightlife", "bar", "club"
        "limit": limit,
        "offset": offset
    }
    response = make_request(url, params=params)
    return response.json().get("businesses", [])

# Initialize data storage
data = []

try:
    for neighborhood in neighborhoods:  # Loop through each neighborhood
        offset = 0
        while True:  # Keep fetching data until no more results
            print(f"Fetching nightlife in {neighborhood} with offset: {offset}...")

            try:
                # Fetch businesses using the current offset and location
                businesses = search_businesses(location=neighborhood, term="nightlife", limit=businesses_per_request, offset=offset)

                if not businesses:
                    # No more businesses to fetch
                    print(f"No more nightlife venues returned for {neighborhood}.")
                    break

                for biz in businesses:
                    name = biz.get("name", "N/A")
                    location_info = biz.get("location", {})
                    address = location_info.get("address1", "N/A")
                    categories = biz.get("categories", [])
                    category_list = [cat.get("title", "") for cat in categories if cat.get("title")]
                    category_str = ", ".join(category_list) if category_list else "N/A"
                    rating = biz.get("rating", "N/A")
                    review_count = biz.get("review_count", "N/A")

                    # Extract coordinates
                    coordinates = biz.get("coordinates", {})
                    latitude = coordinates.get("latitude", None)
                    longitude = coordinates.get("longitude", None)

                    # Append to data
                    data.append({
                        "Fetch Location": neighborhood,
                        "Venue Name": name,
                        "Venue Address": address,
                        "Categories": category_str,
                        "Average Star Rating": rating,
                        "Review Count": review_count,
                        "Latitude": latitude,
                        "Longitude": longitude
                    })

                # Increment offset for the next batch
                offset += len(businesses)

                # Optional: Sleep to respect API rate limits
                time.sleep(0.5)

                # Break if the offset exceeds Yelp's maximum results per query
                if offset >= 240:  # Maximum 240 results per query
                    print(f"Reached maximum results for {neighborhood}.")
                    break

            except requests.HTTPError as he:
                # Log the error and skip this neighborhood
                print(f"HTTP error occurred for {neighborhood}: {he}")
                break

    # Convert the collected data into a DataFrame
    df = pd.DataFrame(data)

    # Convert DataFrame to GeoDataFrame
    df["geometry"] = df.apply(
        lambda row: Point(row["Longitude"], row["Latitude"]) if row["Longitude"] and row["Latitude"] else None,
        axis=1
    )
    Nightlife = gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:4326")

    # Print summary
    print(Nightlife.head())
    print(f"Total nightlife venues collected: {len(data)}")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Fetching nightlife in Parco delle Abbazie, Milan with offset: 0...
# Fetching nightlife in Parco delle Abbazie, Milan with offset: 48...
# Fetching nightlife in Parco delle Abbazie, Milan with offset: 96...
# Fetching nightlife in Parco delle Abbazie, Milan with offset: 144...
# Fetching nightlife in Parco delle Abbazie, Milan with offset: 192...
# Reached maximum results for Parco delle Abbazie, Milan.
# Fetching nightlife in Adriano, Milan with offset: 0...
# HTTP error occurred for Adriano, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Adriano%2C+Milan&term=nightlife&limit=48&offset=0
# Fetching nightlife in Affori, Milan with offset: 0...
# Fetching nightlife in Affori, Milan with offset: 48...
# Fetching nightlife in Affori, Milan with offset: 96...
# Fetching nightlife in Affori, Milan with offset: 144...
# Fetching nightlife in Affori, Milan with offset: 192...
# Reached maximum results for Affori, Milan.
# Fetching nightlife in Baggio, Milan with offset: 0...
# Fetching nightlife in Baggio, Milan with offset: 32...
# No more nightlife venues returned for Baggio, Milan.
# Fetching nightlife in Bande Nere, Milan with offset: 0...
# Fetching nightlife in Bande Nere, Milan with offset: 48...
# Fetching nightlife in Bande Nere, Milan with offset: 96...
# Fetching nightlife in Bande Nere, Milan with offset: 144...
# Fetching nightlife in Bande Nere, Milan with offset: 192...
# Reached maximum results for Bande Nere, Milan.
# Fetching nightlife in Barona, Milan with offset: 0...
# Fetching nightlife in Barona, Milan with offset: 48...
# Fetching nightlife in Barona, Milan with offset: 96...
# Fetching nightlife in Barona, Milan with offset: 144...
# Fetching nightlife in Barona, Milan with offset: 192...
# Reached maximum results for Barona, Milan.
# Fetching nightlife in Bicocca, Milan with offset: 0...
# Fetching nightlife in Bicocca, Milan with offset: 48...
# Fetching nightlife in Bicocca, Milan with offset: 96...
# Fetching nightlife in Bicocca, Milan with offset: 144...
# Fetching nightlife in Bicocca, Milan with offset: 192...
# Reached maximum results for Bicocca, Milan.
# Fetching nightlife in Bovisasca, Milan with offset: 0...
# Fetching nightlife in Bovisasca, Milan with offset: 48...
# Fetching nightlife in Bovisasca, Milan with offset: 96...
# Fetching nightlife in Bovisasca, Milan with offset: 144...
# Fetching nightlife in Bovisasca, Milan with offset: 192...
# Reached maximum results for Bovisasca, Milan.
# Fetching nightlife in Bovisa, Milan with offset: 0...
# Fetching nightlife in Bovisa, Milan with offset: 48...
# Fetching nightlife in Bovisa, Milan with offset: 96...
# Fetching nightlife in Bovisa, Milan with offset: 144...
# Fetching nightlife in Bovisa, Milan with offset: 185...
# No more nightlife venues returned for Bovisa, Milan.
# Fetching nightlife in Brera, Milan with offset: 0...
# Fetching nightlife in Brera, Milan with offset: 48...
# Fetching nightlife in Brera, Milan with offset: 96...
# Fetching nightlife in Brera, Milan with offset: 144...
# Fetching nightlife in Brera, Milan with offset: 192...
# Reached maximum results for Brera, Milan.
# Fetching nightlife in Bruzzano, Milan with offset: 0...
# Fetching nightlife in Bruzzano, Milan with offset: 48...
# Fetching nightlife in Bruzzano, Milan with offset: 57...
# No more nightlife venues returned for Bruzzano, Milan.
# Fetching nightlife in Buenos Aires - Venezia, Milan with offset: 0...
# Fetching nightlife in Buenos Aires - Venezia, Milan with offset: 48...
# Fetching nightlife in Buenos Aires - Venezia, Milan with offset: 96...
# Fetching nightlife in Buenos Aires - Venezia, Milan with offset: 144...
# Fetching nightlife in Buenos Aires - Venezia, Milan with offset: 192...
# Reached maximum results for Buenos Aires - Venezia, Milan.
# Fetching nightlife in Cantalupa, Milan with offset: 0...
# Fetching nightlife in Cantalupa, Milan with offset: 48...
# Fetching nightlife in Cantalupa, Milan with offset: 96...
# Fetching nightlife in Cantalupa, Milan with offset: 144...
# Fetching nightlife in Cantalupa, Milan with offset: 192...
# Reached maximum results for Cantalupa, Milan.
# Fetching nightlife in Cascina Triulza - Expo, Milan with offset: 0...
# Fetching nightlife in Cascina Triulza - Expo, Milan with offset: 48...
# Fetching nightlife in Cascina Triulza - Expo, Milan with offset: 96...
# Fetching nightlife in Cascina Triulza - Expo, Milan with offset: 144...
# Fetching nightlife in Cascina Triulza - Expo, Milan with offset: 192...
# Reached maximum results for Cascina Triulza - Expo, Milan.
# Fetching nightlife in Centrale, Milan with offset: 0...
# Fetching nightlife in Centrale, Milan with offset: 48...
# Fetching nightlife in Centrale, Milan with offset: 96...
# Fetching nightlife in Centrale, Milan with offset: 144...
# Fetching nightlife in Centrale, Milan with offset: 192...
# Reached maximum results for Centrale, Milan.
# Fetching nightlife in Chiaravalle, Milan with offset: 0...
# Fetching nightlife in Chiaravalle, Milan with offset: 48...
# Fetching nightlife in Chiaravalle, Milan with offset: 96...
# Fetching nightlife in Chiaravalle, Milan with offset: 144...
# Fetching nightlife in Chiaravalle, Milan with offset: 192...
# Reached maximum results for Chiaravalle, Milan.
# Fetching nightlife in Città Studi, Milan with offset: 0...
# Fetching nightlife in Città Studi, Milan with offset: 48...
# Fetching nightlife in Città Studi, Milan with offset: 96...
# Fetching nightlife in Città Studi, Milan with offset: 144...
# Fetching nightlife in Città Studi, Milan with offset: 192...
# Reached maximum results for Città Studi, Milan.
# Fetching nightlife in Comasina, Milan with offset: 0...
# Fetching nightlife in Comasina, Milan with offset: 12...
# No more nightlife venues returned for Comasina, Milan.
# Fetching nightlife in Corsica, Milan with offset: 0...
# Fetching nightlife in Corsica, Milan with offset: 48...
# Fetching nightlife in Corsica, Milan with offset: 96...
# Fetching nightlife in Corsica, Milan with offset: 144...
# Fetching nightlife in Corsica, Milan with offset: 146...
# No more nightlife venues returned for Corsica, Milan.
# Fetching nightlife in De Angeli - Monte Rosa, Milan with offset: 0...
# HTTP error occurred for De Angeli - Monte Rosa, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=De+Angeli+-+Monte+Rosa%2C+Milan&term=nightlife&limit=48&offset=0
# Fetching nightlife in Dergano, Milan with offset: 0...
# Fetching nightlife in Dergano, Milan with offset: 48...
# Fetching nightlife in Dergano, Milan with offset: 96...
# Fetching nightlife in Dergano, Milan with offset: 144...
# Fetching nightlife in Dergano, Milan with offset: 192...
# Fetching nightlife in Dergano, Milan with offset: 238...
# HTTP error occurred for Dergano, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Dergano%2C+Milan&term=nightlife&limit=48&offset=238
# Fetching nightlife in Duomo, Milan with offset: 0...
# Fetching nightlife in Duomo, Milan with offset: 48...
# Fetching nightlife in Duomo, Milan with offset: 96...
# Fetching nightlife in Duomo, Milan with offset: 144...
# Fetching nightlife in Duomo, Milan with offset: 192...
# Reached maximum results for Duomo, Milan.
# Fetching nightlife in Ex Om - Morivione, Milan with offset: 0...
# Fetching nightlife in Ex Om - Morivione, Milan with offset: 48...
# Fetching nightlife in Ex Om - Morivione, Milan with offset: 96...
# Fetching nightlife in Ex Om - Morivione, Milan with offset: 144...
# Fetching nightlife in Ex Om - Morivione, Milan with offset: 192...
# Reached maximum results for Ex Om - Morivione, Milan.
# Fetching nightlife in Farini, Milan with offset: 0...
# Fetching nightlife in Farini, Milan with offset: 48...
# Fetching nightlife in Farini, Milan with offset: 96...
# Fetching nightlife in Farini, Milan with offset: 144...
# Fetching nightlife in Farini, Milan with offset: 192...
# Reached maximum results for Farini, Milan.
# Fetching nightlife in GARIBALDI REPUBBLICA, Milan with offset: 0...
# Fetching nightlife in GARIBALDI REPUBBLICA, Milan with offset: 48...
# Fetching nightlife in GARIBALDI REPUBBLICA, Milan with offset: 96...
# Fetching nightlife in GARIBALDI REPUBBLICA, Milan with offset: 144...
# Fetching nightlife in GARIBALDI REPUBBLICA, Milan with offset: 192...
# Reached maximum results for GARIBALDI REPUBBLICA, Milan.
# Fetching nightlife in Gallaratese, Milan with offset: 0...
# Fetching nightlife in Gallaratese, Milan with offset: 48...
# Fetching nightlife in Gallaratese, Milan with offset: 96...
# Fetching nightlife in Gallaratese, Milan with offset: 144...
# Fetching nightlife in Gallaratese, Milan with offset: 192...
# Reached maximum results for Gallaratese, Milan.
# Fetching nightlife in Ghisolfa, Milan with offset: 0...
# Fetching nightlife in Ghisolfa, Milan with offset: 48...
# Fetching nightlife in Ghisolfa, Milan with offset: 96...
# Fetching nightlife in Ghisolfa, Milan with offset: 144...
# Fetching nightlife in Ghisolfa, Milan with offset: 192...
# Reached maximum results for Ghisolfa, Milan.
# Fetching nightlife in Giambellino, Milan with offset: 0...
# Fetching nightlife in Giambellino, Milan with offset: 48...
# Fetching nightlife in Giambellino, Milan with offset: 96...
# Fetching nightlife in Giambellino, Milan with offset: 144...
# Fetching nightlife in Giambellino, Milan with offset: 192...
# Reached maximum results for Giambellino, Milan.
# Fetching nightlife in Giardini Porta Venezia, Milan with offset: 0...
# Fetching nightlife in Giardini Porta Venezia, Milan with offset: 48...
# Fetching nightlife in Giardini Porta Venezia, Milan with offset: 96...
# Fetching nightlife in Giardini Porta Venezia, Milan with offset: 144...
# Fetching nightlife in Giardini Porta Venezia, Milan with offset: 192...
# Reached maximum results for Giardini Porta Venezia, Milan.
# Fetching nightlife in Gratosoglio - Ticinello, Milan with offset: 0...
# Fetching nightlife in Gratosoglio - Ticinello, Milan with offset: 48...
# Fetching nightlife in Gratosoglio - Ticinello, Milan with offset: 96...
# Fetching nightlife in Gratosoglio - Ticinello, Milan with offset: 144...
# Fetching nightlife in Gratosoglio - Ticinello, Milan with offset: 192...
# Fetching nightlife in Gratosoglio - Ticinello, Milan with offset: 205...
# HTTP error occurred for Gratosoglio - Ticinello, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Gratosoglio+-+Ticinello%2C+Milan&term=nightlife&limit=48&offset=205
# Fetching nightlife in Greco, Milan with offset: 0...
# Fetching nightlife in Greco, Milan with offset: 48...
# Fetching nightlife in Greco, Milan with offset: 96...
# Fetching nightlife in Greco, Milan with offset: 144...
# Fetching nightlife in Greco, Milan with offset: 192...
# Reached maximum results for Greco, Milan.
# Fetching nightlife in Guastalla, Milan with offset: 0...
# Fetching nightlife in Guastalla, Milan with offset: 48...
# Fetching nightlife in Guastalla, Milan with offset: 96...
# Fetching nightlife in Guastalla, Milan with offset: 144...
# Fetching nightlife in Guastalla, Milan with offset: 192...
# Reached maximum results for Guastalla, Milan.
# Fetching nightlife in Isola, Milan with offset: 0...
# Fetching nightlife in Isola, Milan with offset: 48...
# Fetching nightlife in Isola, Milan with offset: 96...
# Fetching nightlife in Isola, Milan with offset: 144...
# Fetching nightlife in Isola, Milan with offset: 192...
# Fetching nightlife in Isola, Milan with offset: 218...
# HTTP error occurred for Isola, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Isola%2C+Milan&term=nightlife&limit=48&offset=218
# Fetching nightlife in Lambrate, Milan with offset: 0...
# Fetching nightlife in Lambrate, Milan with offset: 48...
# Fetching nightlife in Lambrate, Milan with offset: 96...
# Fetching nightlife in Lambrate, Milan with offset: 144...
# Fetching nightlife in Lambrate, Milan with offset: 192...
# Reached maximum results for Lambrate, Milan.
# Fetching nightlife in Lodi - Corvetto, Milan with offset: 0...
# Fetching nightlife in Lodi - Corvetto, Milan with offset: 48...
# Fetching nightlife in Lodi - Corvetto, Milan with offset: 96...
# Fetching nightlife in Lodi - Corvetto, Milan with offset: 144...
# Fetching nightlife in Lodi - Corvetto, Milan with offset: 192...
# Reached maximum results for Lodi - Corvetto, Milan.
# Fetching nightlife in Lorenteggio, Milan with offset: 0...
# Fetching nightlife in Lorenteggio, Milan with offset: 48...
# Fetching nightlife in Lorenteggio, Milan with offset: 96...
# Fetching nightlife in Lorenteggio, Milan with offset: 144...
# Fetching nightlife in Lorenteggio, Milan with offset: 192...
# Reached maximum results for Lorenteggio, Milan.
# Fetching nightlife in Loreto, Milan with offset: 0...
# Fetching nightlife in Loreto, Milan with offset: 48...
# Fetching nightlife in Loreto, Milan with offset: 96...
# Fetching nightlife in Loreto, Milan with offset: 144...
# Fetching nightlife in Loreto, Milan with offset: 192...
# Reached maximum results for Loreto, Milan.
# Fetching nightlife in Maciachini - Maggiolina, Milan with offset: 0...
# Fetching nightlife in Maciachini - Maggiolina, Milan with offset: 48...
# Fetching nightlife in Maciachini - Maggiolina, Milan with offset: 96...
# Fetching nightlife in Maciachini - Maggiolina, Milan with offset: 144...
# Fetching nightlife in Maciachini - Maggiolina, Milan with offset: 192...
# Reached maximum results for Maciachini - Maggiolina, Milan.
# Fetching nightlife in Magenta - San Vittore, Milan with offset: 0...
# Fetching nightlife in Magenta - San Vittore, Milan with offset: 48...
# Fetching nightlife in Magenta - San Vittore, Milan with offset: 96...
# Fetching nightlife in Magenta - San Vittore, Milan with offset: 144...
# Fetching nightlife in Magenta - San Vittore, Milan with offset: 192...
# Reached maximum results for Magenta - San Vittore, Milan.
# Fetching nightlife in Maggiore - Musocco, Milan with offset: 0...
# Fetching nightlife in Maggiore - Musocco, Milan with offset: 48...
# Fetching nightlife in Maggiore - Musocco, Milan with offset: 96...
# Fetching nightlife in Maggiore - Musocco, Milan with offset: 144...
# Fetching nightlife in Maggiore - Musocco, Milan with offset: 192...
# Reached maximum results for Maggiore - Musocco, Milan.
# Fetching nightlife in Mecenate, Milan with offset: 0...
# Fetching nightlife in Mecenate, Milan with offset: 48...
# Fetching nightlife in Mecenate, Milan with offset: 52...
# No more nightlife venues returned for Mecenate, Milan.
# Fetching nightlife in Muggiano, Milan with offset: 0...
# Fetching nightlife in Muggiano, Milan with offset: 32...
# No more nightlife venues returned for Muggiano, Milan.
# Fetching nightlife in Navigli, Milan with offset: 0...
# Fetching nightlife in Navigli, Milan with offset: 48...
# Fetching nightlife in Navigli, Milan with offset: 96...
# Fetching nightlife in Navigli, Milan with offset: 144...
# Fetching nightlife in Navigli, Milan with offset: 192...
# Reached maximum results for Navigli, Milan.
# Fetching nightlife in Niguarda - Cà Granda, Milan with offset: 0...
# Fetching nightlife in Niguarda - Cà Granda, Milan with offset: 48...
# Fetching nightlife in Niguarda - Cà Granda, Milan with offset: 96...
# Fetching nightlife in Niguarda - Cà Granda, Milan with offset: 144...
# Fetching nightlife in Niguarda - Cà Granda, Milan with offset: 192...
# Reached maximum results for Niguarda - Cà Granda, Milan.
# Fetching nightlife in Ortomercato, Milan with offset: 0...
# Fetching nightlife in Ortomercato, Milan with offset: 48...
# Fetching nightlife in Ortomercato, Milan with offset: 96...
# Fetching nightlife in Ortomercato, Milan with offset: 144...
# Fetching nightlife in Ortomercato, Milan with offset: 192...
# Reached maximum results for Ortomercato, Milan.
# Fetching nightlife in Padova, Milan with offset: 0...
# Fetching nightlife in Padova, Milan with offset: 48...
# Fetching nightlife in Padova, Milan with offset: 96...
# Fetching nightlife in Padova, Milan with offset: 144...
# Fetching nightlife in Padova, Milan with offset: 192...
# Reached maximum results for Padova, Milan.
# Fetching nightlife in Pagano, Milan with offset: 0...
# Fetching nightlife in Pagano, Milan with offset: 48...
# Fetching nightlife in Pagano, Milan with offset: 96...
# Fetching nightlife in Pagano, Milan with offset: 144...
# Fetching nightlife in Pagano, Milan with offset: 192...
# Reached maximum results for Pagano, Milan.
# Fetching nightlife in Parco Agricolo Sud, Milan with offset: 0...
# Fetching nightlife in Parco Agricolo Sud, Milan with offset: 48...
# Fetching nightlife in Parco Agricolo Sud, Milan with offset: 96...
# Fetching nightlife in Parco Agricolo Sud, Milan with offset: 144...
# Fetching nightlife in Parco Agricolo Sud, Milan with offset: 192...
# Reached maximum results for Parco Agricolo Sud, Milan.
# Fetching nightlife in Parco Bosco In Città, Milan with offset: 0...
# Fetching nightlife in Parco Bosco In Città, Milan with offset: 48...
# Fetching nightlife in Parco Bosco In Città, Milan with offset: 96...
# Fetching nightlife in Parco Bosco In Città, Milan with offset: 144...
# Fetching nightlife in Parco Bosco In Città, Milan with offset: 192...
# Reached maximum results for Parco Bosco In Città, Milan.
# Fetching nightlife in Parco Forlanini - Ortica, Milan with offset: 0...
# Fetching nightlife in Parco Forlanini - Ortica, Milan with offset: 48...
# Fetching nightlife in Parco Forlanini - Ortica, Milan with offset: 96...
# Fetching nightlife in Parco Forlanini - Ortica, Milan with offset: 144...
# Fetching nightlife in Parco Forlanini - Ortica, Milan with offset: 192...
# Reached maximum results for Parco Forlanini - Ortica, Milan.
# Fetching nightlife in Parco Lambro - Cimiano, Milan with offset: 0...
# Fetching nightlife in Parco Lambro - Cimiano, Milan with offset: 48...
# Fetching nightlife in Parco Lambro - Cimiano, Milan with offset: 96...
# Fetching nightlife in Parco Lambro - Cimiano, Milan with offset: 144...
# Fetching nightlife in Parco Lambro - Cimiano, Milan with offset: 192...
# Reached maximum results for Parco Lambro - Cimiano, Milan.
# Fetching nightlife in Parco Monluè - Ponte Lambro, Milan with offset: 0...
# Fetching nightlife in Parco Monluè - Ponte Lambro, Milan with offset: 48...
# Fetching nightlife in Parco Monluè - Ponte Lambro, Milan with offset: 96...
# Fetching nightlife in Parco Monluè - Ponte Lambro, Milan with offset: 144...
# Fetching nightlife in Parco Monluè - Ponte Lambro, Milan with offset: 192...
# Reached maximum results for Parco Monluè - Ponte Lambro, Milan.
# Fetching nightlife in Parco Nord, Milan with offset: 0...
# Fetching nightlife in Parco Nord, Milan with offset: 48...
# Fetching nightlife in Parco Nord, Milan with offset: 96...
# Fetching nightlife in Parco Nord, Milan with offset: 144...
# Fetching nightlife in Parco Nord, Milan with offset: 192...
# Reached maximum results for Parco Nord, Milan.
# Fetching nightlife in Parco Sempione, Milan with offset: 0...
# Fetching nightlife in Parco Sempione, Milan with offset: 48...
# Fetching nightlife in Parco Sempione, Milan with offset: 96...
# Fetching nightlife in Parco Sempione, Milan with offset: 144...
# Fetching nightlife in Parco Sempione, Milan with offset: 192...
# Reached maximum results for Parco Sempione, Milan.
# Fetching nightlife in Parco dei Navigli, Milan with offset: 0...
# Fetching nightlife in Parco dei Navigli, Milan with offset: 48...
# Fetching nightlife in Parco dei Navigli, Milan with offset: 96...
# Fetching nightlife in Parco dei Navigli, Milan with offset: 144...
# Fetching nightlife in Parco dei Navigli, Milan with offset: 192...
# Reached maximum results for Parco dei Navigli, Milan.
# Fetching nightlife in Porta Romana, Milan with offset: 0...
# Fetching nightlife in Porta Romana, Milan with offset: 48...
# Fetching nightlife in Porta Romana, Milan with offset: 96...
# Fetching nightlife in Porta Romana, Milan with offset: 144...
# Fetching nightlife in Porta Romana, Milan with offset: 192...
# Reached maximum results for Porta Romana, Milan.
# Fetching nightlife in Portello, Milan with offset: 0...
# Fetching nightlife in Portello, Milan with offset: 48...
# Fetching nightlife in Portello, Milan with offset: 96...
# Fetching nightlife in Portello, Milan with offset: 144...
# Fetching nightlife in Portello, Milan with offset: 192...
# Fetching nightlife in Portello, Milan with offset: 208...
# HTTP error occurred for Portello, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Portello%2C+Milan&term=nightlife&limit=48&offset=208
# Fetching nightlife in Qt 8, Milan with offset: 0...
# Fetching nightlife in Qt 8, Milan with offset: 48...
# Fetching nightlife in Qt 8, Milan with offset: 96...
# Fetching nightlife in Qt 8, Milan with offset: 144...
# Fetching nightlife in Qt 8, Milan with offset: 187...
# No more nightlife venues returned for Qt 8, Milan.
# Fetching nightlife in Quarto Cagnino, Milan with offset: 0...
# Fetching nightlife in Quarto Cagnino, Milan with offset: 45...
# No more nightlife venues returned for Quarto Cagnino, Milan.
# Fetching nightlife in Quinto Romano, Milan with offset: 0...
# Fetching nightlife in Quinto Romano, Milan with offset: 21...
# No more nightlife venues returned for Quinto Romano, Milan.
# Fetching nightlife in Quintosole, Milan with offset: 0...
# Fetching nightlife in Quintosole, Milan with offset: 48...
# Fetching nightlife in Quintosole, Milan with offset: 96...
# Fetching nightlife in Quintosole, Milan with offset: 144...
# Fetching nightlife in Quintosole, Milan with offset: 192...
# Reached maximum results for Quintosole, Milan.
# Fetching nightlife in Ripamonti, Milan with offset: 0...
# Fetching nightlife in Ripamonti, Milan with offset: 48...
# Fetching nightlife in Ripamonti, Milan with offset: 96...
# Fetching nightlife in Ripamonti, Milan with offset: 144...
# Fetching nightlife in Ripamonti, Milan with offset: 192...
# Reached maximum results for Ripamonti, Milan.
# Fetching nightlife in Rogoredo, Milan with offset: 0...
# Fetching nightlife in Rogoredo, Milan with offset: 48...
# Fetching nightlife in Rogoredo, Milan with offset: 96...
# Fetching nightlife in Rogoredo, Milan with offset: 144...
# Fetching nightlife in Rogoredo, Milan with offset: 192...
# Reached maximum results for Rogoredo, Milan.
# Fetching nightlife in Ronchetto Sul Naviglio, Milan with offset: 0...
# Fetching nightlife in Ronchetto Sul Naviglio, Milan with offset: 48...
# Fetching nightlife in Ronchetto Sul Naviglio, Milan with offset: 96...
# Fetching nightlife in Ronchetto Sul Naviglio, Milan with offset: 144...
# Fetching nightlife in Ronchetto Sul Naviglio, Milan with offset: 192...
# Reached maximum results for Ronchetto Sul Naviglio, Milan.
# Fetching nightlife in Ronchetto delle Rane, Milan with offset: 0...
# Fetching nightlife in Ronchetto delle Rane, Milan with offset: 48...
# Fetching nightlife in Ronchetto delle Rane, Milan with offset: 96...
# Fetching nightlife in Ronchetto delle Rane, Milan with offset: 144...
# Fetching nightlife in Ronchetto delle Rane, Milan with offset: 192...
# Reached maximum results for Ronchetto delle Rane, Milan.
# Fetching nightlife in San Cristoforo, Milan with offset: 0...
# Fetching nightlife in San Cristoforo, Milan with offset: 48...
# Fetching nightlife in San Cristoforo, Milan with offset: 96...
# Fetching nightlife in San Cristoforo, Milan with offset: 144...
# Fetching nightlife in San Cristoforo, Milan with offset: 192...
# Reached maximum results for San Cristoforo, Milan.
# Fetching nightlife in San Siro, Milan with offset: 0...
# Fetching nightlife in San Siro, Milan with offset: 48...
# Fetching nightlife in San Siro, Milan with offset: 96...
# Fetching nightlife in San Siro, Milan with offset: 144...
# Fetching nightlife in San Siro, Milan with offset: 192...
# Reached maximum results for San Siro, Milan.
# Fetching nightlife in Sarpi, Milan with offset: 0...
# Fetching nightlife in Sarpi, Milan with offset: 48...
# Fetching nightlife in Sarpi, Milan with offset: 96...
# Fetching nightlife in Sarpi, Milan with offset: 144...
# Fetching nightlife in Sarpi, Milan with offset: 192...
# Reached maximum results for Sarpi, Milan.
# Fetching nightlife in Scalo Romana, Milan with offset: 0...
# Fetching nightlife in Scalo Romana, Milan with offset: 48...
# Fetching nightlife in Scalo Romana, Milan with offset: 96...
# Fetching nightlife in Scalo Romana, Milan with offset: 144...
# Fetching nightlife in Scalo Romana, Milan with offset: 192...
# Reached maximum results for Scalo Romana, Milan.
# Fetching nightlife in Selinunte, Milan with offset: 0...
# Fetching nightlife in Selinunte, Milan with offset: 48...
# Fetching nightlife in Selinunte, Milan with offset: 96...
# Fetching nightlife in Selinunte, Milan with offset: 144...
# Fetching nightlife in Selinunte, Milan with offset: 186...
# No more nightlife venues returned for Selinunte, Milan.
# Fetching nightlife in Stadera, Milan with offset: 0...
# Fetching nightlife in Stadera, Milan with offset: 48...
# Fetching nightlife in Stadera, Milan with offset: 96...
# Fetching nightlife in Stadera, Milan with offset: 144...
# Fetching nightlife in Stadera, Milan with offset: 192...
# Reached maximum results for Stadera, Milan.
# Fetching nightlife in Stephenson, Milan with offset: 0...
# Fetching nightlife in Stephenson, Milan with offset: 42...
# No more nightlife venues returned for Stephenson, Milan.
# Fetching nightlife in Tibaldi, Milan with offset: 0...
# Fetching nightlife in Tibaldi, Milan with offset: 48...
# Fetching nightlife in Tibaldi, Milan with offset: 96...
# Fetching nightlife in Tibaldi, Milan with offset: 144...
# Fetching nightlife in Tibaldi, Milan with offset: 192...
# Reached maximum results for Tibaldi, Milan.
# Fetching nightlife in Ticinese, Milan with offset: 0...
# Fetching nightlife in Ticinese, Milan with offset: 48...
# Fetching nightlife in Ticinese, Milan with offset: 96...
# Fetching nightlife in Ticinese, Milan with offset: 144...
# Fetching nightlife in Ticinese, Milan with offset: 192...
# Reached maximum results for Ticinese, Milan.
# Fetching nightlife in Tortona, Milan with offset: 0...
# Fetching nightlife in Tortona, Milan with offset: 48...
# Fetching nightlife in Tortona, Milan with offset: 96...
# Fetching nightlife in Tortona, Milan with offset: 144...
# Fetching nightlife in Tortona, Milan with offset: 192...
# Reached maximum results for Tortona, Milan.
# Fetching nightlife in Tre Torri, Milan with offset: 0...
# Fetching nightlife in Tre Torri, Milan with offset: 48...
# Fetching nightlife in Tre Torri, Milan with offset: 96...
# Fetching nightlife in Tre Torri, Milan with offset: 144...
# Fetching nightlife in Tre Torri, Milan with offset: 192...
# Reached maximum results for Tre Torri, Milan.
# Fetching nightlife in Trenno, Milan with offset: 0...
# Fetching nightlife in Trenno, Milan with offset: 48...
# Fetching nightlife in Trenno, Milan with offset: 96...
# Fetching nightlife in Trenno, Milan with offset: 144...
# Fetching nightlife in Trenno, Milan with offset: 192...
# Reached maximum results for Trenno, Milan.
# Fetching nightlife in Triulzo Superiore, Milan with offset: 0...
# Fetching nightlife in Triulzo Superiore, Milan with offset: 48...
# Fetching nightlife in Triulzo Superiore, Milan with offset: 96...
# Fetching nightlife in Triulzo Superiore, Milan with offset: 144...
# Fetching nightlife in Triulzo Superiore, Milan with offset: 192...
# Reached maximum results for Triulzo Superiore, Milan.
# Fetching nightlife in Umbria - Molise, Milan with offset: 0...
# Fetching nightlife in Umbria - Molise, Milan with offset: 48...
# Fetching nightlife in Umbria - Molise, Milan with offset: 96...
# Fetching nightlife in Umbria - Molise, Milan with offset: 144...
# Fetching nightlife in Umbria - Molise, Milan with offset: 192...
# Reached maximum results for Umbria - Molise, Milan.
# Fetching nightlife in Viale Monza, Milan with offset: 0...
# Fetching nightlife in Viale Monza, Milan with offset: 48...
# Fetching nightlife in Viale Monza, Milan with offset: 96...
# Fetching nightlife in Viale Monza, Milan with offset: 144...
# Fetching nightlife in Viale Monza, Milan with offset: 192...
# Reached maximum results for Viale Monza, Milan.
# Fetching nightlife in Vigentina, Milan with offset: 0...
# Fetching nightlife in Vigentina, Milan with offset: 48...
# Fetching nightlife in Vigentina, Milan with offset: 96...
# Fetching nightlife in Vigentina, Milan with offset: 144...
# Fetching nightlife in Vigentina, Milan with offset: 192...
# Reached maximum results for Vigentina, Milan.
# Fetching nightlife in Villapizzone, Milan with offset: 0...
# Fetching nightlife in Villapizzone, Milan with offset: 48...
# Fetching nightlife in Villapizzone, Milan with offset: 96...
# Fetching nightlife in Villapizzone, Milan with offset: 126...
# No more nightlife venues returned for Villapizzone, Milan.
# Fetching nightlife in Washington, Milan with offset: 0...
# Fetching nightlife in Washington, Milan with offset: 48...
# Fetching nightlife in Washington, Milan with offset: 96...
# Fetching nightlife in Washington, Milan with offset: 144...
# Fetching nightlife in Washington, Milan with offset: 192...
# Reached maximum results for Washington, Milan.
# Fetching nightlife in XXII Marzo, Milan with offset: 0...
# Fetching nightlife in XXII Marzo, Milan with offset: 48...
# Fetching nightlife in XXII Marzo, Milan with offset: 96...
# Fetching nightlife in XXII Marzo, Milan with offset: 144...
# Fetching nightlife in XXII Marzo, Milan with offset: 192...
# Reached maximum results for XXII Marzo, Milan.
# Fetching nightlife in Forze Armate, Milan with offset: 0...
# Fetching nightlife in Forze Armate, Milan with offset: 48...
# Fetching nightlife in Forze Armate, Milan with offset: 96...
# Fetching nightlife in Forze Armate, Milan with offset: 144...
# Fetching nightlife in Forze Armate, Milan with offset: 192...
# Reached maximum results for Forze Armate, Milan.
#                Fetch Location     Venue Name                    Venue Address  \
# 0  Parco delle Abbazie, Milan  H2O Live Club               Via Mezzomerico 18
# 1  Parco delle Abbazie, Milan            049  Piazza Martiri della Libertà 3B
# 2  Parco delle Abbazie, Milan    Twiggy Club            Via de Cristoforis  5
# 3  Parco delle Abbazie, Milan         Circle                  Via Stendhal 34
# 4  Parco delle Abbazie, Milan      Strix Bar              Via Olgiate Olona 1
#
#                           Categories  Average Star Rating  Review Count  \
# 0                        Dance Clubs                  0.0             0
# 1  Lounges, Wine Bars, Cocktail Bars                  4.7             3
# 2          Music Venues, Pubs, Cafes                  5.0             1
# 3               Lounges, Dance Clubs                  3.4             7
# 4                      Cocktail Bars                  4.0             2
#
#     Latitude  Longitude                  geometry
# 0  45.626890   8.625470  POINT (8.62547 45.62689)
# 1  45.445177   8.616799   POINT (8.6168 45.44518)
# 2  45.821506   8.831431  POINT (8.83143 45.82151)
# 3  45.453430   9.159440  POINT (9.15944 45.45343)
# 4  45.620991   8.865000    POINT (8.865 45.62099)
# Total nightlife venues collected: 17832

# %%
Nightlife
# Out:
#                    Fetch Location             Venue Name  \
# 0      Parco delle Abbazie, Milan          H2O Live Club
# 1      Parco delle Abbazie, Milan                    049
# 2      Parco delle Abbazie, Milan            Twiggy Club
# 3      Parco delle Abbazie, Milan                 Circle
# 4      Parco delle Abbazie, Milan              Strix Bar
# ...                           ...                    ...
# 17827         Forze Armate, Milan  Salumeria dello Sport
# 17828         Forze Armate, Milan             Square Bar
# 17829         Forze Armate, Milan            I Beerbanti
# 17830         Forze Armate, Milan              Akkademia
# 17831         Forze Armate, Milan            Garden Beer
#
#                          Venue Address                             Categories  \
# 0                   Via Mezzomerico 18                            Dance Clubs
# 1      Piazza Martiri della Libertà 3B      Lounges, Wine Bars, Cocktail Bars
# 2                Via de Cristoforis  5              Music Venues, Pubs, Cafes
# 3                      Via Stendhal 34                   Lounges, Dance Clubs
# 4                  Via Olgiate Olona 1                          Cocktail Bars
# ...                                ...                                    ...
# 17827                 PIazza Napoli 30  Sports Bars, Wine Bars, Cocktail Bars
# 17828    Via Michelangelo Buonarroti 5                                   Bars
# 17829                    Via Solari 52                            Pubs, Cafes
# 17830              Via Carlo Ravizza 1                    Cocktail Bars, Pubs
# 17831                   Via Novara 342                           Beer Gardens
#
#        Average Star Rating  Review Count   Latitude  Longitude  \
# 0                      0.0             0  45.626890   8.625470
# 1                      4.7             3  45.445177   8.616799
# 2                      5.0             1  45.821506   8.831431
# 3                      3.4             7  45.453430   9.159440
# 4                      4.0             2  45.620991   8.865000
# ...                    ...           ...        ...        ...
# 17827                  0.0             0  45.453099   9.152149
# 17828                  3.4            10  45.467357   9.155144
# 17829                  3.2             6  45.453810   9.157800
# 17830                  0.0             0  45.467172   9.152948
# 17831                  0.0             0  45.482237   9.093471
#
#                        geometry
# 0      POINT (8.62547 45.62689)
# 1       POINT (8.6168 45.44518)
# 2      POINT (8.83143 45.82151)
# 3      POINT (9.15944 45.45343)
# 4        POINT (8.865 45.62099)
# ...                         ...
# 17827   POINT (9.15215 45.4531)
# 17828  POINT (9.15514 45.46736)
# 17829   POINT (9.1578 45.45381)
# 17830  POINT (9.15295 45.46717)
# 17831  POINT (9.09347 45.48224)
#
# [17832 rows x 9 columns]

# %%
# Removing the dupes
Nightlife_nodup = Nightlife.drop_duplicates(subset=['Venue Name','Venue Address','Categories','Average Star Rating',
                                                        'Review Count','geometry'])
# Saving the file
Nightlife_nodup.to_file("Nightlife.geojson", driver="GeoJSON")

Nightlife_nodup
# Out:
#                    Fetch Location                         Venue Name  \
# 0      Parco delle Abbazie, Milan                      H2O Live Club
# 1      Parco delle Abbazie, Milan                                049
# 2      Parco delle Abbazie, Milan                        Twiggy Club
# 3      Parco delle Abbazie, Milan                             Circle
# 4      Parco delle Abbazie, Milan                          Strix Bar
# ...                           ...                                ...
# 17777         Forze Armate, Milan        BAR Piccolo Lord di Comisso
# 17778         Forze Armate, Milan                 Mazzonna / Antonio
# 17784         Forze Armate, Milan                 Bonavetti / Andrea
# 17790         Forze Armate, Milan  Cafe' Principe di Massa Antonella
# 17799         Forze Armate, Milan               Gelati Sfizi e Caffè
#
#                          Venue Address  \
# 0                   Via Mezzomerico 18
# 1      Piazza Martiri della Libertà 3B
# 2                Via de Cristoforis  5
# 3                      Via Stendhal 34
# 4                  Via Olgiate Olona 1
# ...                                ...
# 17777      Via Della Liberazione, 34/A
# 17778         Piazza Giovanni Xxiii, 7
# 17784        Via Sebastiano Caboto, 31
# 17790                    Via Roma, 108
# 17799                    Via Milano 25
#
#                                               Categories  Average Star Rating  \
# 0                                            Dance Clubs                  0.0
# 1                      Lounges, Wine Bars, Cocktail Bars                  4.7
# 2                              Music Venues, Pubs, Cafes                  5.0
# 3                                   Lounges, Dance Clubs                  3.4
# 4                                          Cocktail Bars                  4.0
# ...                                                  ...                  ...
# 17777                                               Bars                  0.0
# 17778                                               Bars                  0.0
# 17784                                               Bars                  0.0
# 17790                                               Bars                  0.0
# 17799  Ice Cream & Frozen Yogurt, Patisserie/Cake Sho...                  0.0
#
#        Review Count   Latitude  Longitude                  geometry
# 0                 0  45.626890   8.625470  POINT (8.62547 45.62689)
# 1                 3  45.445177   8.616799   POINT (8.6168 45.44518)
# 2                 1  45.821506   8.831431  POINT (8.83143 45.82151)
# 3                 7  45.453430   9.159440  POINT (9.15944 45.45343)
# 4                 2  45.620991   8.865000    POINT (8.865 45.62099)
# ...             ...        ...        ...                       ...
# 17777             0  45.439727   9.104614  POINT (9.10461 45.43973)
# 17778             0  45.439020   9.109670  POINT (9.10967 45.43902)
# 17784             0  45.443188   9.114465  POINT (9.11447 45.44319)
# 17790             0  45.439091   9.099020  POINT (9.09902 45.43909)
# 17799             0  45.435690   9.114930  POINT (9.11493 45.43569)
#
# [2463 rows x 9 columns]

# %%
# DEVONO ESSERE LO STESSO TIPO DI COORDINATE
print(Nightlife_nodup.crs)  # Restaurants CRS
print(gdf_combined.crs)  # Neighborhood polygons CRS
# Out:
# EPSG:4326
# EPSG:4326

# %% [markdown]
# # Join Spaziale

# %%
# Perform the spatial join
joined = sjoin(Nightlife_nodup, gdf_combined, how="left", predicate="within")

# Check the result
joined
# Out:
#                    Fetch Location                         Venue Name  \
# 0      Parco delle Abbazie, Milan                      H2O Live Club
# 1      Parco delle Abbazie, Milan                                049
# 2      Parco delle Abbazie, Milan                        Twiggy Club
# 3      Parco delle Abbazie, Milan                             Circle
# 4      Parco delle Abbazie, Milan                          Strix Bar
# ...                           ...                                ...
# 17777         Forze Armate, Milan        BAR Piccolo Lord di Comisso
# 17778         Forze Armate, Milan                 Mazzonna / Antonio
# 17784         Forze Armate, Milan                 Bonavetti / Andrea
# 17790         Forze Armate, Milan  Cafe' Principe di Massa Antonella
# 17799         Forze Armate, Milan               Gelati Sfizi e Caffè
#
#                          Venue Address  \
# 0                   Via Mezzomerico 18
# 1      Piazza Martiri della Libertà 3B
# 2                Via de Cristoforis  5
# 3                      Via Stendhal 34
# 4                  Via Olgiate Olona 1
# ...                                ...
# 17777      Via Della Liberazione, 34/A
# 17778         Piazza Giovanni Xxiii, 7
# 17784        Via Sebastiano Caboto, 31
# 17790                    Via Roma, 108
# 17799                    Via Milano 25
#
#                                               Categories  Average Star Rating  \
# 0                                            Dance Clubs                  0.0
# 1                      Lounges, Wine Bars, Cocktail Bars                  4.7
# 2                              Music Venues, Pubs, Cafes                  5.0
# 3                                   Lounges, Dance Clubs                  3.4
# 4                                          Cocktail Bars                  4.0
# ...                                                  ...                  ...
# 17777                                               Bars                  0.0
# 17778                                               Bars                  0.0
# 17784                                               Bars                  0.0
# 17790                                               Bars                  0.0
# 17799  Ice Cream & Frozen Yogurt, Patisserie/Cake Sho...                  0.0
#
#        Review Count   Latitude  Longitude                  geometry  \
# 0                 0  45.626890   8.625470  POINT (8.62547 45.62689)
# 1                 3  45.445177   8.616799   POINT (8.6168 45.44518)
# 2                 1  45.821506   8.831431  POINT (8.83143 45.82151)
# 3                 7  45.453430   9.159440  POINT (9.15944 45.45343)
# 4                 2  45.620991   8.865000    POINT (8.865 45.62099)
# ...             ...        ...        ...                       ...
# 17777             0  45.439727   9.104614  POINT (9.10461 45.43973)
# 17778             0  45.439020   9.109670  POINT (9.10967 45.43902)
# 17784             0  45.443188   9.114465  POINT (9.11447 45.44319)
# 17790             0  45.439091   9.099020  POINT (9.09902 45.43909)
# 17799             0  45.435690   9.114930  POINT (9.11493 45.43569)
#
#        index_right Neighborhood
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3             74.0      Tortona
# 4              NaN          NaN
# ...            ...          ...
# 17777          NaN          NaN
# 17778          NaN          NaN
# 17784          NaN          NaN
# 17790          NaN          NaN
# 17799          NaN          NaN
#
# [2463 rows x 11 columns]

# %%
joined[joined['Venue Name']=='Alchimia'] # giusto
# Out:
#                       Fetch Location Venue Name              Venue Address  \
# 5831  Gratosoglio - Ticinello, Milan   Alchimia  Via Francesco Brioschi 17
#
#                 Categories  Average Star Rating  Review Count   Latitude  \
# 5831  Lounges, Steakhouses                  3.9            17  45.446007
#
#       Longitude                  geometry  index_right Neighborhood
# 5831    9.18065  POINT (9.18065 45.44601)         73.0     Ticinese

# %%
joined.nunique()
# Out:
# Fetch Location           58
# Venue Name             2416
# Venue Address          2366
# Categories              730
# Average Star Rating      38
# Review Count             79
# Latitude               2297
# Longitude              2305
# geometry               2368
# index_right              77
# Neighborhood             77
# dtype: int64

# %%
# Remove rows where the geometry is NaN
PolyNightlife = joined[~joined["Neighborhood"].isna()]

# Reset the index if needed
PolyNightlife = PolyNightlife.reset_index(drop=True)

# Keeping only relevant variables
PolyNightlife = PolyNightlife[["Venue Name", "Venue Address", "Categories", "Average Star Rating",
                           "Review Count", "geometry", "Neighborhood"]]

# Saving the file
PolyNightlife.to_file("PolyNightlife.geojson", driver="GeoJSON")

# Print the cleaned GeoDataFrame
PolyNightlife
# Out:
#                  Venue Name            Venue Address  \
# 0                    Circle          Via Stendhal 34
# 1                  Alcatraz        Via Valtellina 25
# 2                 Blue Eyes  Via Luigi De Andreis 13
# 3                Maremilano     Via Fratelli Zoia 10
# 4                    Monkey      Via Napo Torriani 5
# ...                     ...                      ...
# 1830  Martin / Luigi Pietro     Viale Monte Nero, 71
# 1831              BAR White           Via Friuli, 69
# 1832        Siena / Tommaso        Viale Premuda, 10
# 1833           Caffè Italia         Viale Premuda 20
# 1834             Lab Milano          Viale Premuda 7
#
#                      Categories  Average Star Rating  Review Count  \
# 0          Lounges, Dance Clubs                  3.4             7
# 1     Music Venues, Dance Clubs                  3.8            39
# 2                   Dance Clubs                  3.0             2
# 3                     Nightlife                  5.0             1
# 4                 Cocktail Bars                  4.8            30
# ...                         ...                  ...           ...
# 1830                       Bars                  0.0             0
# 1831                       Bars                  0.0             0
# 1832                       Bars                  0.0             0
# 1833                       Bars                  3.5             2
# 1834              Cocktail Bars                  0.0             0
#
#                       geometry    Neighborhood
# 0     POINT (9.15944 45.45343)         Tortona
# 1     POINT (9.18275 45.49459)          Farini
# 2     POINT (9.23504 45.46169)         Corsica
# 3     POINT (9.10812 45.47635)  Quarto Cagnino
# 4     POINT (9.20352 45.48085)        Centrale
# ...                        ...             ...
# 1830   POINT (9.20754 45.4605)       Guastalla
# 1831  POINT (9.21479 45.45632)      XXII Marzo
# 1832   POINT (9.2077 45.46364)      XXII Marzo
# 1833  POINT (9.20757 45.46479)      XXII Marzo
# 1834  POINT (9.20716 45.46408)       Guastalla
#
# [1835 rows x 7 columns]
