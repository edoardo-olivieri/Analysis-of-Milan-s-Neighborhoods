# %%
import requests
import os
import geopandas as gpd
import pandas as pd

# %%
# Import of the Polygons
gdf_combined = gpd.read_file("C:/Users/edoar/combined_quartieri.geojson")

# %% [markdown]
# # Dataset Milano

# %%
# List of geojson file URLs from the website
geojson_urls = [
    #Dog Parks
    "https://dati.comune.milano.it/dataset/7efe1ac1-7a5f-4e33-b7ab-c24438bc9fb1/resource/99011d87-d640-43a3-9f70-20e1825d7441/download/ds52_aree_fruizione_cani.geojson",
    # Pharmacies
    "https://dati.comune.milano.it/dataset/7e18f0d3-b7f1-49b7-969d-da2c04131dd6/resource/8cc1abb8-fe10-4f50-b7b4-e673250f34c6/download/ds501_farmacie-nel-comune-di-m_dr8f-cz2h_final.geojson",
    # Playgrounds
    "https://dati.comune.milano.it/dataset/47444653-1f40-4690-8fb3-66deae6647d4/resource/5e5b89a1-20bb-4c0c-9182-a55f16af4dfb/download/ds724_aree_gioco.geojson",
    # Sport Venues
    "https://dati.comune.milano.it/dataset/c613f251-6f66-4320-8cac-6ee08d8fd2ef/resource/6811f693-ee63-41ca-9ff7-ea0464f6d600/download/ds34_impianti_sportivi_final.geojson",
    # Public Schools
    "https://dati.comune.milano.it/dataset/97c5000b-3569-4f77-a289-35f5a667867a/resource/30c25888-e857-4b8c-bb49-cabaffe9fdc8/download/ds1305_elenco_scuole_statali_as2020_21_final_.geojson",
    # Private Schools
    "https://dati.comune.milano.it/dataset/d7159f7f-6d93-4c08-93dc-36eedc47d16c/resource/b051dfed-89db-446b-9342-636ffd6c21a1/download/ds1582_elenco_scuole_paritarie_2020-21.geojson",
    # Univeristies
    "https://dati.comune.milano.it/dataset/8c3f8110-aecd-48c0-b707-52785eb5bf46/resource/0dbaf2ad-c935-4413-b33e-2664e78b66d4/download/ds94_universita__final.geojson",
    # Coworking spaces
    "https://dati.comune.milano.it/dataset/34b330d2-e34a-4d98-a327-447342001ee3/resource/e8cd794c-a194-4df8-a880-175e02426e05/download/coworking_joined_f.geojson",
    # Libraries
    "https://dati.comune.milano.it/dataset/ee08abe0-aba1-44ab-b6ad-21fcd8a45100/resource/7c399aa3-1778-446f-88d1-79c21581edc8/download/ds1306-biblioteche.geojson",
    # Suburban railway
    "https://dati.comune.milano.it/dataset/802a1d1f-4203-44c9-b9f5-dd8aa1f6bc3c/resource/7a07abfb-6a0d-458d-9a91-e6eb5b1ba703/download/sistema_ferroviario_urbano_layer_0_stazioni__final.geojson",
    # Metro stops
    "https://dati.comune.milano.it/dataset/b7344a8f-0ef5-424b-a902-f7f06e32dd67/resource/dd6a770a-b321-44f0-b58c-9725d84409bb/download/tpl_metrofermate.geojson",
    # Bus stops
    "https://dati.comune.milano.it/dataset/ac494f5d-acd3-4fd3-8cfc-ed24f5c3d923/resource/7d21bd77-3ad1-4235-9a40-8a8cdfeb65a0/download/tpl_fermate.geojson",
]

# thedirectory to save the downloaded geojson files
output_directory = "geojson_files"

# create the directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# loop through each url and download the file
for url in geojson_urls:
    try:
        print(f"Downloading {url}...")
        response = requests.get(url)
        response.raise_for_status()  #error for HTTP issues

        # Extract the file name from the URL
        file_name = url.split("/")[-1]
        output_path = os.path.join(output_directory, file_name)

        # Save the GeoJSON file
        with open(output_path, "wb") as file:
            file.write(response.content)

        print(f"Saved {file_name} to {output_directory}")

    except requests.exceptions.RequestException as e:
        print(f"Failed to download {url}: {e}")
# Out:
# Downloading https://dati.comune.milano.it/dataset/7efe1ac1-7a5f-4e33-b7ab-c24438bc9fb1/resource/99011d87-d640-43a3-9f70-20e1825d7441/download/ds52_aree_fruizione_cani.geojson...
# Saved ds52_aree_fruizione_cani.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/7e18f0d3-b7f1-49b7-969d-da2c04131dd6/resource/8cc1abb8-fe10-4f50-b7b4-e673250f34c6/download/ds501_farmacie-nel-comune-di-m_dr8f-cz2h_final.geojson...
# Saved ds501_farmacie-nel-comune-di-m_dr8f-cz2h_final.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/47444653-1f40-4690-8fb3-66deae6647d4/resource/5e5b89a1-20bb-4c0c-9182-a55f16af4dfb/download/ds724_aree_gioco.geojson...
# Saved ds724_aree_gioco.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/c613f251-6f66-4320-8cac-6ee08d8fd2ef/resource/6811f693-ee63-41ca-9ff7-ea0464f6d600/download/ds34_impianti_sportivi_final.geojson...
# Saved ds34_impianti_sportivi_final.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/97c5000b-3569-4f77-a289-35f5a667867a/resource/30c25888-e857-4b8c-bb49-cabaffe9fdc8/download/ds1305_elenco_scuole_statali_as2020_21_final_.geojson...
# Saved ds1305_elenco_scuole_statali_as2020_21_final_.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/d7159f7f-6d93-4c08-93dc-36eedc47d16c/resource/b051dfed-89db-446b-9342-636ffd6c21a1/download/ds1582_elenco_scuole_paritarie_2020-21.geojson...
# Saved ds1582_elenco_scuole_paritarie_2020-21.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/8c3f8110-aecd-48c0-b707-52785eb5bf46/resource/0dbaf2ad-c935-4413-b33e-2664e78b66d4/download/ds94_universita__final.geojson...
# Saved ds94_universita__final.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/34b330d2-e34a-4d98-a327-447342001ee3/resource/e8cd794c-a194-4df8-a880-175e02426e05/download/coworking_joined_f.geojson...
# Saved coworking_joined_f.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/ee08abe0-aba1-44ab-b6ad-21fcd8a45100/resource/7c399aa3-1778-446f-88d1-79c21581edc8/download/ds1306-biblioteche.geojson...
# Saved ds1306-biblioteche.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/802a1d1f-4203-44c9-b9f5-dd8aa1f6bc3c/resource/7a07abfb-6a0d-458d-9a91-e6eb5b1ba703/download/sistema_ferroviario_urbano_layer_0_stazioni__final.geojson...
# Saved sistema_ferroviario_urbano_layer_0_stazioni__final.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/b7344a8f-0ef5-424b-a902-f7f06e32dd67/resource/dd6a770a-b321-44f0-b58c-9725d84409bb/download/tpl_metrofermate.geojson...
# Saved tpl_metrofermate.geojson to geojson_files
# Downloading https://dati.comune.milano.it/dataset/ac494f5d-acd3-4fd3-8cfc-ed24f5c3d923/resource/7d21bd77-3ad1-4235-9a40-8a8cdfeb65a0/download/tpl_fermate.geojson...
# Saved tpl_fermate.geojson to geojson_files

# %% [markdown]
# ## Dog Parks

# %%
# Load the GeoDataFrame
dog_parks = gpd.read_file("geojson_files/ds52_aree_fruizione_cani.geojson") # Dog park multipolygons

# ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != dog_parks.crs:
    dog_parks = dog_parks.to_crs(gdf_combined.crs)

# Perform the spatial join
# 'within' ensures dog park is inside the neighborhood polygon
PolyDogParks = gpd.sjoin(dog_parks, gdf_combined, how="left", predicate="within")
PolyDogParks = PolyDogParks[~PolyDogParks["Neighborhood"].isna()]

PolyDogParks
# Out:
#     id_area  municipio area  \
# 0     1_043          1  043
# 1     1_308          1  308
# 2     1_213          1  213
# 3     1_092          1  092
# 4     1_239          1  239
# ..      ...        ...  ...
# 418   9_036          9  036
# 419   9_556          9  556
# 420   9_159          9  159
# 421   9_095          9  095
# 422   9_154          9  154
#
#                                               località  obj_id   codice  \
# 0                                          via Ronzoni  132009  S327554
# 1                              giardino Renata Tebaldi   25318  S327554
# 2                             giardino Malgeri Alfredo  176223  S327554
# 3                              giardino Roberto Bazlen  114785  S327554
# 4                                viale Beatrice d'Este   52831  S327554
# ..                                                 ...     ...      ...
# 418                              giardino Wanda Osiris   25440  S327554
# 419                              vie Catone - Maffucci  175468  S327554
# 420  vie Bovisasca - Modignani - Assietta " Pioppet...  122423  S327554
# 421                                    piazzale Lugano   25501  S327554
# 422                       vie Della Senna - Fontanelli   25349  S327554
#
#       descrizione_codice   data_ini      area_mq     perim_m  \
# 0    Area fruizione cani 2017-02-27   573.687432  165.347310
# 1    Area fruizione cani 2006-03-15   353.238550   80.318583
# 2    Area fruizione cani 2024-05-18   182.406688   54.439780
# 3    Area fruizione cani 2013-05-06    70.918852   41.837688
# 4    Area fruizione cani 2011-04-15   914.706264  189.052021
# ..                   ...        ...          ...         ...
# 418  Area fruizione cani 2003-06-18  2016.530150  211.347870
# 419  Area fruizione cani 2024-01-08   467.273674   87.661082
# 420  Area fruizione cani 2015-06-13  1158.441243  147.915796
# 421  Area fruizione cani 2003-06-18   741.116750  108.191502
# 422  Area fruizione cani 2013-05-10   559.757824  112.884133
#
#                                               geometry  index_right  \
# 0    MULTIPOLYGON (((9.17668 45.45472, 9.17651 45.4...         73.0
# 1    MULTIPOLYGON (((9.16711 45.46935, 9.16712 45.4...         38.0
# 2    MULTIPOLYGON (((9.1904 45.48045, 9.19052 45.48...          9.0
# 3    MULTIPOLYGON (((9.19838 45.45439, 9.19843 45.4...         80.0
# 4    MULTIPOLYGON (((9.1887 45.452, 9.18872 45.4520...         80.0
# ..                                                 ...          ...
# 418  MULTIPOLYGON (((9.19559 45.50327, 9.19555 45.5...         37.0
# 419  MULTIPOLYGON (((9.17171 45.49748, 9.17203 45.4...          8.0
# 420  MULTIPOLYGON (((9.15614 45.51811, 9.15639 45.5...          7.0
# 421  MULTIPOLYGON (((9.16533 45.49802, 9.16533 45.4...         23.0
# 422  MULTIPOLYGON (((9.17352 45.52518, 9.17358 45.5...         10.0
#
#                 Neighborhood
# 0                   Ticinese
# 1      Magenta - San Vittore
# 2                      Brera
# 3                  Vigentina
# 4                  Vigentina
# ..                       ...
# 418  Maciachini - Maggiolina
# 419                   Bovisa
# 420                Bovisasca
# 421                   Farini
# 422                 Bruzzano
#
# [396 rows x 13 columns]

# %% [markdown]
# ### Although there are two duplicates, they both have been maintained in the dataframe since they extend across two different neighborhoods, so technically both neighborhoods have that dog park in their geometries

# %%
# Find duplicates based on the geometry
duplicates = PolyDogParks[PolyDogParks.duplicated(subset=['geometry'], keep=False)]

duplicates
# Out:
#     id_area  municipio area      località  obj_id   codice  \
# 165   5_227          5  227  via Manduria   25305  S327554
# 165   5_227          5  227  via Manduria   25305  S327554
#
#       descrizione_codice   data_ini   area_mq     perim_m  \
# 165  Area fruizione cani 2005-11-22  516.8207  115.037699
# 165  Area fruizione cani 2005-11-22  516.8207  115.037699
#
#                                               geometry  index_right  \
# 165  MULTIPOLYGON (((9.18075 45.40212, 9.18069 45.4...          0.0
# 165  MULTIPOLYGON (((9.18075 45.40212, 9.18069 45.4...         64.0
#
#              Neighborhood
# 165   Parco delle Abbazie
# 165  Ronchetto delle Rane

# %%
# Keeping only relevant variables
PolyDogParks = PolyDogParks[["località", "area_mq", "perim_m", "obj_id",
                           "municipio", "geometry", "Neighborhood"]]

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolyDogParks[PolyDogParks.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [località, area_mq, perim_m, obj_id, municipio, geometry, Neighborhood]
# Index: []

# %% [markdown]
# ### Overall the cleaned dataframe is of a good quality

# %%
# Saving the file
PolyDogParks.to_file("PolyDogParks.geojson", driver="GeoJSON")

# %% [markdown]
# ## Pharmacies

# %%
# Load the GeoDataFrame
pharmacies = gpd.read_file("geojson_files/ds501_farmacie-nel-comune-di-m_dr8f-cz2h_final.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != pharmacies.crs:
    pharmacies = pharmacies.to_crs(gdf_combined.crs)

# Perform the spatial join
PolyPharmacy = gpd.sjoin(pharmacies, gdf_combined, how="left", predicate="within")
PolyPharmacy = PolyPharmacy[~PolyPharmacy["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolyPharmacy
# Out:
#     CODICE_FARMACIA                       DESCRIZIONE_FARMACIA  PARTITA_IVA  \
# 0            MI1854                                    TOLSTOJ  09287610969
# 1            MI1018                               A.F.M. N. 83  13195220150
# 2            MI1820                                 NOVARA SRL  08267990961
# 3            MI0013                                PONTESEVESO  01533800155
# 4            MI1979                                SALGARI SRL  12094200966
# ..              ...                                        ...          ...
# 418          MI2016  TRIPHARMA SAS DI MANELLI MARIA LUISA & C.  12968820964
# 419          MI1830                                   OLMI SNC  08716030963
# 420          MI1666                              FERRARINI SNC  04026870966
# 421          MI0684                               A.F.M. N. 28  13195220150
# 422          MI2004                    DR.SSA DANIELA MATTALIA  12618270966
#
#                         INDIRIZZO  COMUNE FRAZIONE    CAP PROVINCIA  \
# 0           VIA LEONE TOLSTOI, 17  MILANO     None  20146        MI
# 1                VIALE MONZA, 226  MILANO     None  20128        MI
# 2                   VIA NOVARA,90  MILANO     None  20153        MI
# 3    VIA GIOVANNI SCHIAPARELLI, 4  MILANO     None  20125        MI
# 4        VIA ALBERTO CARONCINI, 6  MILANO     None  20137        MI
# ..                            ...     ...      ...    ...       ...
# 418       VIA GUGLIELMO SILVA, 39  MILANO     None  20149        MI
# 419         VIA DELLE BETULLE, 10  MILANO     None  20152        MI
# 420     PIAZZA CINQUE GIORNATE, 6  MILANO     None  20129        MI
# 421              VIA TEODOSIO, 74  MILANO     None  20131        MI
# 422    VIA GIORGIO WASHINGTON, 98  MILANO     None  20146        MI
#
#     CODICE_ISTAT MUNICIPIO ID_NIL                                       NIL  \
# 0          15146         6     49                               GIAMBELLINO
# 1          15146         2     16                          GORLA - PRECOTTO
# 2          15146         7     60                        STADIO - IPPODROMI
# 3          15146         2     10          STAZIONE CENTRALE - PONTE SEVESO
# 4          15146         4     28              UMBRIA - MOLISE - CALVAIRATE
# ..           ...       ...    ...                                       ...
# 418        15146         8     58                    DE ANGELI - MONTE ROSA
# 419        15146         7     55  BAGGIO - Q.RE DEGLI OLMI - Q.RE VALSESIA
# 420        15146         1      4                                 GUASTALLA
# 421        15146         3     20                 LORETO - CASORETTO - NOLO
# 422        15146         6     51                             PORTA MAGENTA
#
#      LONGITUDINE  LATITUDINE                       Location  \
# 0       9.150814   45.451086  (45.4510863058, 9.1508142972)
# 1       9.225081   45.513064  (45.5130644867, 9.2250814797)
# 2       9.119702   45.472478      (45.47247759, 9.11970245)
# 3       9.205393   45.489574  (45.4895744126, 9.2053929759)
# 4       9.219724   45.449769  (45.4497685868, 9.2197240187)
# ..           ...         ...                            ...
# 418     9.147192   45.478255    (45.47825482, 9.1471918901)
# 419     9.083453   45.453203   (45.4532030878, 9.083452613)
# 420     9.207182   45.461711  (45.4617107033, 9.2071820093)
# 421     9.230088   45.488214  (45.4882144069, 9.2300875714)
# 422     9.154375   45.456084  (45.4560840155, 9.1543749297)
#
#                      geometry  index_right            Neighborhood
# 0    POINT (9.15081 45.45109)         27.0             Giambellino
# 1    POINT (9.22508 45.51306)         79.0             Viale Monza
# 2     POINT (9.1197 45.47248)         66.0                San Siro
# 3    POINT (9.20539 45.48957)         14.0                Centrale
# 4    POINT (9.21972 45.44977)         78.0         Umbria - Molise
# ..                        ...          ...                     ...
# 418  POINT (9.14719 45.47825)         19.0  De Angeli - Monte Rosa
# 419   POINT (9.08345 45.4532)          3.0                  Baggio
# 420  POINT (9.20718 45.46171)         31.0               Guastalla
# 421  POINT (9.23009 45.48821)         36.0                  Loreto
# 422  POINT (9.15437 45.45608)         82.0              Washington
#
# [413 rows x 18 columns]

# %% [markdown]
# ### There are no duplicates

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolyPharmacy[PolyPharmacy.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates
# Out:
# Empty GeoDataFrame
# Columns: [CODICE_FARMACIA, DESCRIZIONE_FARMACIA, PARTITA_IVA, INDIRIZZO, COMUNE, FRAZIONE, CAP, PROVINCIA, CODICE_ISTAT, MUNICIPIO, ID_NIL, NIL, LONGITUDINE, LATITUDINE, Location, geometry, index_right, Neighborhood]
# Index: []

# %%
# Keeping only relevant variables
PolyPharmacy = PolyPharmacy[["CODICE_FARMACIA", "DESCRIZIONE_FARMACIA", "MUNICIPIO", "INDIRIZZO",
                             "geometry", "Neighborhood"]]

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolyPharmacy[PolyPharmacy.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [CODICE_FARMACIA, DESCRIZIONE_FARMACIA, MUNICIPIO, INDIRIZZO, geometry, Neighborhood]
# Index: []

# %%
# Saving the file
PolyPharmacy.to_file("PolyPharmacy.geojson", driver="GeoJSON")

# %% [markdown]
# ## Play Grounds

# %%
# Load the GeoDataFrame
playgrounds = gpd.read_file("geojson_files/ds724_aree_gioco.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != playgrounds.crs:
    playgrounds = playgrounds.to_crs(gdf_combined.crs)

# Perform the spatial join
PolyPlaygrounds = gpd.sjoin(playgrounds, gdf_combined, how="left", predicate="within")
PolyPlaygrounds = PolyPlaygrounds[~PolyPlaygrounds["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolyPlaygrounds
# Out:
#     id_area  municipio area  \
# 0     1_170          1  170
# 1     1_232          1  232
# 2     1_172          1  172
# 3     1_172          1  172
# 4     1_092          1  092
# ..      ...        ...  ...
# 978   9_359          9  359
# 979   9_159          9  159
# 980   9_159          9  159
# 981   9_095          9  095
# 982   9_154          9  154
#
#                                               località  obj_id   codice  \
# 0                       corso di Porta Vigentina n. 15   45165  S327552
# 1                                 rotonda della Besana   28387  S327552
# 2                                   via Crivelli n. 21  139581  S327552
# 3                                   via Crivelli n. 21   45169  S327552
# 4                              giardino Roberto Bazlen   28223  S327552
# ..                                                 ...     ...      ...
# 978                                  via Palletta n. 6   45243  S327552
# 979  vie Bovisasca - Modignani - Assietta " Pioppet...   44849  S327552
# 980  vie Bovisasca - Modignani - Assietta " Pioppet...   28436  S327552
# 981                                    piazzale Lugano   28381  S327552
# 982                       vie Della Senna - Fontanelli   28437  S327552
#
#     descrizione_codice   data_ini     area_mq     perim_m  \
# 0           Area Gioco 2007-10-09  543.961185  125.762038
# 1           Area Gioco 2003-08-29   95.929250   35.964448
# 2           Area Gioco 2018-09-03  223.818797   59.464232
# 3           Area Gioco 2008-05-21  644.966050  110.463586
# 4           Area Gioco 2007-05-01  797.496000  107.612642
# ..                 ...        ...         ...         ...
# 978         Area Gioco        NaT    3.125667    6.275213
# 979         Area Gioco 2003-06-18  514.141738   90.853619
# 980         Area Gioco 2003-06-18  150.691583   55.893729
# 981         Area Gioco 2003-06-18  432.007550   79.638202
# 982         Area Gioco 2003-10-13  341.168150   88.111494
#
#                                               geometry  index_right  \
# 0    MULTIPOLYGON (((9.19641 45.45388, 9.19641 45.4...         80.0
# 1    MULTIPOLYGON (((9.20546 45.45946, 9.20546 45.4...         31.0
# 2    MULTIPOLYGON (((9.19548 45.45371, 9.19548 45.4...         80.0
# 3    MULTIPOLYGON (((9.19538 45.45333, 9.19541 45.4...         80.0
# 4    MULTIPOLYGON (((9.19704 45.45427, 9.19695 45.4...         80.0
# ..                                                 ...          ...
# 978  MULTIPOLYGON (((9.1918 45.51028, 9.1918 45.510...         43.0
# 979  MULTIPOLYGON (((9.1563 45.51734, 9.15657 45.51...          7.0
# 980  MULTIPOLYGON (((9.15261 45.52002, 9.15259 45.5...          7.0
# 981  MULTIPOLYGON (((9.16535 45.49788, 9.16535 45.4...         23.0
# 982  MULTIPOLYGON (((9.17319 45.52481, 9.17317 45.5...         10.0
#
#              Neighborhood
# 0               Vigentina
# 1               Guastalla
# 2               Vigentina
# 3               Vigentina
# 4               Vigentina
# ..                    ...
# 978  Niguarda - Cà Granda
# 979             Bovisasca
# 980             Bovisasca
# 981                Farini
# 982              Bruzzano
#
# [939 rows x 13 columns]

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolyPlaygrounds[PolyPlaygrounds.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates
# Out:
#     id_area  municipio area      località  obj_id   codice descrizione_codice  \
# 355   5_227          5  227  via Manduria   43897  S327552         Area Gioco
# 355   5_227          5  227  via Manduria   43897  S327552         Area Gioco
#
#       data_ini    area_mq   perim_m  \
# 355 2008-07-11  406.40085  79.29013
# 355 2008-07-11  406.40085  79.29013
#
#                                               geometry  index_right  \
# 355  MULTIPOLYGON (((9.18094 45.40278, 9.18118 45.4...          0.0
# 355  MULTIPOLYGON (((9.18094 45.40278, 9.18118 45.4...         64.0
#
#              Neighborhood
# 355   Parco delle Abbazie
# 355  Ronchetto delle Rane

# %%
# Keeping only relevant variables
PolyPlaygrounds = PolyPlaygrounds[["località", "area_mq", "perim_m", "obj_id",
                                   "municipio", "geometry", "Neighborhood"]]

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolyPlaygrounds[PolyPlaygrounds.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [località, area_mq, perim_m, obj_id, municipio, geometry, Neighborhood]
# Index: []

# %%
# Saving the file
PolyPlaygrounds.to_file("PolyPlaygrounds.geojson", driver="GeoJSON")

# %% [markdown]
# ## Sport Venues

# %%
# Load the GeoDataFrame
sport_venues = gpd.read_file("geojson_files/ds34_impianti_sportivi_final.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != sport_venues.crs:
    sport_venues = sport_venues.to_crs(gdf_combined.crs)

# Perform the spatial join
PolySportVenues = gpd.sjoin(sport_venues, gdf_combined, how="left", predicate="within")
PolySportVenues = PolySportVenues[~PolySportVenues["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolySportVenues
# Out:
#              FAX                            Nome                    Indirizzo  \
# 0           None                  NON ATTRIBUITO         VIA USSI STEFANO   4
# 1           None                   S.S. BAGGIO 2    VIA OLIVIERI ALESSIO   11
# 2     0239210739                  LIDO DI MILANO       PLE LOTTO LORENZO   15
# 3           None  COOP. AGRISPORT SEZIONE CALCIO         VIA DEL RICORDO   58
# 4           None  SOCIETA GINNASTICA MILANO 2000  VIA MARTIGNONI ADELE   1  A
# ...          ...                             ...                          ...
# 1036        None  A.S.D. PICCOLA SCUOLA DI CIRCO                VIA CENISIO 2
# 1037        None             A.S.D. RUGBY MILANO               VIA LICATA  41
# 1038        None             A.S.D. RUGBY MILANO               VIA LICATA  41
# 1039  0248713719  AREA EX PALAZZETTO DELLO SPORT      VIA DEI PICCOLOMINI SNC
# 1040        None       FEDERAZIONE ITALIANA GOLF     VIA CORELLI ARCANGELO 71
#
#      Zona               info                 URL   TELEFONO1 ID_NIL  \
# 0       9    CENTRO SPORTIVO                None        None     13
# 1       7        CALCIO A 11                None   024599310     56
# 2       8          MINI GOLF  www.milanosport.it  0239266100     66
# 3       2    CENTRO SPORTIVO                None  0227207742     17
# 4       2    CENTRO SPORTIVO                None    02603288     12
# ...   ...                ...                 ...         ...    ...
# 1036    8  ATTIVITA CIRCENSE                None        None     70
# 1037    3        CALCIO A 11                None        None     18
# 1038    3              RUGBY                None        None     18
# 1039    7         PARCHEGGIO     www.sansiro.net  0248713713     60
# 1040    3               GOLF                None        None     24
#
#                                   NIL                              Location  \
# 0                     GRECO - SEGNANO  (45.5071015469858, 9.20835578748649)
# 1                        FORZE ARMATE  (45.4655714935197, 9.11156409171595)
# 2                                QT 8  (45.4805639255761, 9.14194021229098)
# 3                             ADRIANO  (45.5093199390653, 9.23794027433961)
# 4             MACIACHINI - MAGGIOLINA   (45.492566239195, 9.19613835069693)
# ...                               ...                                   ...
# 1036                         GHISOLFA   (45.4876030737289, 9.1732839281514)
# 1037  CIMIANO - ROTTOLE - Q.RE FELTRE  (45.4986815761724, 9.25111177885147)
# 1038  CIMIANO - ROTTOLE - Q.RE FELTRE  (45.4986815797783, 9.25111177630766)
# 1039               STADIO - IPPODROMI  (45.4781768596385, 9.12081301575318)
# 1040       PARCO FORLANINI - CAVRIANO  (45.4710322728757, 9.25603373738114)
#
#       LONG_X_4326  LAT_Y_4326                  geometry  index_right  \
# 0        9.208356   45.507102   POINT (9.20836 45.5071)         30.0
# 1        9.111564   45.465571  POINT (9.11156 45.46557)         84.0
# 2        9.141940   45.480564  POINT (9.14194 45.48056)         57.0
# 3        9.237940   45.509320  POINT (9.23794 45.50932)          1.0
# 4        9.196138   45.492566  POINT (9.19614 45.49257)         37.0
# ...           ...         ...                       ...          ...
# 1036     9.173284   45.487603   POINT (9.17328 45.4876)         26.0
# 1037     9.251112   45.498682  POINT (9.25111 45.49868)         50.0
# 1038     9.251112   45.498682  POINT (9.25111 45.49868)         50.0
# 1039     9.120813   45.478177  POINT (9.12081 45.47818)         66.0
# 1040     9.256034   45.471032  POINT (9.25603 45.47103)         49.0
#
#                   Neighborhood
# 0                        Greco
# 1                 Forze Armate
# 2                         Qt 8
# 3                      Adriano
# 4      Maciachini - Maggiolina
# ...                        ...
# 1036                  Ghisolfa
# 1037    Parco Lambro - Cimiano
# 1038    Parco Lambro - Cimiano
# 1039                  San Siro
# 1040  Parco Forlanini - Ortica
#
# [998 rows x 15 columns]

# %%
# Find duplicates based on the 'geometry' column
duplicates1 = PolySportVenues[PolySportVenues.duplicated(subset=['info','geometry'], keep=False)]

# Inspect the duplicate rows
duplicates1.sort_values('LONG_X_4326')
# Out:
#              FAX                                               Nome  \
# 816         None                     PISTA DI ALLENAMENTO DI TRENNO
# 815         None                      PISTA ALLENAMENTO DELLA MAURA
# 1030        None          FIN FEDERAZIONE ITALIANA NUOTO LAMPUGNANO
# 493         None          FIN FEDERAZIONE ITALIANA NUOTO LAMPUGNANO
# 241         None                                U.S. TRIESTINA 1946
# 932         None                                U.S. TRIESTINA 1946
# 21          None                                     EMILIO COLOMBO
# 478         None                                     EMILIO COLOMBO
# 475         None                                     EMILIO COLOMBO
# 13    0248376073                                   MILANO SPORT SPA
# 408   0248376073                                   MILANO SPORT SPA
# 921         None                                         XXV APRILE
# 193   0239262162                                         XXV APRILE
# 1013        None                  FEDERAZIONE ITALIANA GIOCO CALCIO
# 1015        None                  FEDERAZIONE ITALIANA GIOCO CALCIO
# 543         None                                     MATER AMABILIS
# 541         None                                     MATER AMABILIS
# 235   0226147471                            AIKIDO DI FUJIMOTO YOJI
# 850   0226147471                            AIKIDO DI FUJIMOTO YOJI
# 851   0248017658         ICOS ASSOCIAZIONE SPORTIVA DILETTANTISTICA
# 236   0248017658         ICOS ASSOCIAZIONE SPORTIVA DILETTANTISTICA
# 269    026460485                          HOCKEY CLUB MILANO 24 SRL
# 819         None  ASSOCIAZIONE SPORTIVA DILETTANTISTICA QUANTA S...
# 768         None  ASSOCIAZIONE SPORTIVA DILETTANTISTICA QUANTA S...
# 771         None  ASSOCIAZIONE SPORTIVA DILETTANTISTICA QUANTA S...
# 763         None                            CAMPO LIBERO VIA SPEZIA
# 764         None                            CAMPO LIBERO VIA SPEZIA
# 759   0269540375                                   MILANO SPORT SPA
# 1031  0269540375                                   MILANO SPORT SPA
# 494         None                                     GIUSEPPE CAIMI
# 59          None                     CENTRO BALNEARE GIUSEPPE CAIMI
# 887         None                                    BICOCCA VILLAGE
# 888   0287389823              HUMANKINESIS RIABILITAZIONE INTEGRATA
# 292   0287389823              HUMANKINESIS RIABILITAZIONE INTEGRATA
# 291         None                                    BICOCCA VILLAGE
# 872         None                                       CORPO Y LAMA
# 873   0289057116                                       ACTIVITY SRL
# 284   0289057116                                       ACTIVITY SRL
# 283         None                                       CORPO Y LAMA
# 308         None                                A.S.D. RUGBY MILANO
# 1037        None                                A.S.D. RUGBY MILANO
#
#                          Indirizzo Zona              info  \
# 816             VIA IPPODROMO  134    7    SPORT EQUESTRE
# 815             VIA IPPODROMO  134    7    SPORT EQUESTRE
# 1030           VIA LAMPUGNANO   76    8             NUOTO
# 493            VIA LAMPUGNANO   76    8             NUOTO
# 241    VIA FLEMING ALESSANDRO   13    7       CALCIO A 11
# 932    VIA FLEMING ALESSANDRO   13    7       CALCIO A 11
# 21         VIA DEL CARDELLINO   15    6   CENTRO SPORTIVO
# 478        VIA DEL CARDELLINO   15    6   CENTRO SPORTIVO
# 475        VIA DEL CARDELLINO   15    6   CENTRO SPORTIVO
# 13          VIA DEL CARDELLINO   3    6             NUOTO
# 408         VIA DEL CARDELLINO   3    6             NUOTO
# 921      VIA CIMABUE GIOVANNI   24    8   CENTRO SPORTIVO
# 193      VIA CIMABUE GIOVANNI   24    8   CENTRO SPORTIVO
# 1013         VIA LAGO DI NEMI   29    6       CALCIO A 11
# 1015         VIA LAGO DI NEMI   29    6       CALCIO A 11
# 543       VIA PREVIATI GAETANO   8    7       CALCIO A 11
# 541       VIA PREVIATI GAETANO   8    7       CALCIO A 11
# 235       VIA PIRANDELLO LUIGI   4    7        GINNASTICA
# 850       VIA PIRANDELLO LUIGI   4    7  FITNESS MACCHINE
# 851       VIA PIRANDELLO LUIGI   4    7  FITNESS MACCHINE
# 236       VIA PIRANDELLO LUIGI   4    7        GINNASTICA
# 269              VIA ASSIETTA   19    9  FITNESS MACCHINE
# 819              VIA ASSIETTA   19    9             NUOTO
# 768              VIA ASSIETTA   19    9             NUOTO
# 771              VIA ASSIETTA   19    9  FITNESS MACCHINE
# 763                     VIA SPEZIA    6     PALLACANESTRO
# 764                     VIA SPEZIA    6     PALLACANESTRO
# 759        VIA SANT' ABBONDIO   12    5             NUOTO
# 1031       VIA SANT' ABBONDIO   12    5             NUOTO
# 494           VIA BOTTA CARLO   18    4             NUOTO
# 59            VIA BOTTA CARLO   18    4             NUOTO
# 887                VLE SARCA   336    9  FITNESS MACCHINE
# 888                VLE SARCA   336    9  FITNESS MACCHINE
# 292                VLE SARCA   336    9        GINNASTICA
# 291                VLE SARCA   336    9        GINNASTICA
# 872   VIA EUSTACHI BARTOLOMEO   22    3  FITNESS MACCHINE
# 873   VIA EUSTACHI BARTOLOMEO   22    3  FITNESS MACCHINE
# 284   VIA EUSTACHI BARTOLOMEO   22    3        GINNASTICA
# 283   VIA EUSTACHI BARTOLOMEO   22    3        GINNASTICA
# 308                VIA LICATA   41    3       CALCIO A 11
# 1037                VIA LICATA  41    3       CALCIO A 11
#
#                                   URL            TELEFONO1 ID_NIL  \
# 816                              None                 None     60
# 815                              None                 None     60
# 1030                             None            023088390     65
# 493                              None            023088390     65
# 241                              None           0240090479     56
# 932                              None           0240090479     56
# 21                               None             02410976     53
# 478                              None                 None     53
# 475                              None                 None     53
# 13                 www.milanosport.it             02417948     53
# 408                www.milanosport.it             02417948     53
# 921       www.badminton-lombardia.com           0233000871     66
# 193                www.milanosport.it           0239262162     66
# 1013  www.centrosportivobettinelli.it           0236530766     46
# 1015  www.centrosportivobettinelli.it           0236530766     46
# 543                              None                 None     58
# 541                              None                 None     58
# 235                              None            022896939     51
# 850                              None            022896939     51
# 851                              None  02462551 _ 02462851     51
# 236                              None  02462551 _ 02462851     51
# 269                      www.hcm24.it            026621611     81
# 819             www.quantavillage.com            026621611     81
# 768             www.quantavillage.com            026621611     81
# 771             www.quantavillage.com            026621611     81
# 763                              None                 None     45
# 764                              None                 None     45
# 759                www.milanosport.it            028466861     42
# 1031               www.milanosport.it            028466861     42
# 494                www.milanosport.it                 None     27
# 59                 www.milanosport.it                 None     27
# 887                              None           0266101276     15
# 888                              None           0287389820     15
# 292                              None           0287389820     15
# 291                              None           0266101276     15
# 872                              None           0289057116     21
# 873                              None                 None     21
# 284                              None           0289057116     21
# 283                              None           0289057116     21
# 308                              None                 None     18
# 1037                             None                 None     18
#
#                                                     NIL  \
# 816                                  STADIO - IPPODROMI
# 815                                  STADIO - IPPODROMI
# 1030  Q.RE GALLARATESE - Q.RE SAN LEONARDO - LAMPUGNANO
# 493   Q.RE GALLARATESE - Q.RE SAN LEONARDO - LAMPUGNANO
# 241                                        FORZE ARMATE
# 932                                        FORZE ARMATE
# 21                                          LORENTEGGIO
# 478                                         LORENTEGGIO
# 475                                         LORENTEGGIO
# 13                                          LORENTEGGIO
# 408                                         LORENTEGGIO
# 921                                                QT 8
# 193                                                QT 8
# 1013                                             BARONA
# 1015                                             BARONA
# 543                              DE ANGELI - MONTE ROSA
# 541                              DE ANGELI - MONTE ROSA
# 235                                       PORTA MAGENTA
# 850                                       PORTA MAGENTA
# 851                                       PORTA MAGENTA
# 236                                       PORTA MAGENTA
# 269                                           BOVISASCA
# 819                                           BOVISASCA
# 768                                           BOVISASCA
# 771                                           BOVISASCA
# 763                           MONCUCCO - SAN CRISTOFORO
# 764                           MONCUCCO - SAN CRISTOFORO
# 759   STADERA - CHIESA ROSSA - Q.RE TORRETTA - CONCA...
# 1031  STADERA - CHIESA ROSSA - Q.RE TORRETTA - CONCA...
# 494                                          PTA ROMANA
# 59                                           PTA ROMANA
# 887                                             BICOCCA
# 888                                             BICOCCA
# 292                                             BICOCCA
# 291                                             BICOCCA
# 872       BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE
# 873       BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE
# 284       BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE
# 283       BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE
# 308                     CIMIANO - ROTTOLE - Q.RE FELTRE
# 1037                    CIMIANO - ROTTOLE - Q.RE FELTRE
#
#                                   Location  LONG_X_4326  LAT_Y_4326  \
# 816   (45.4845996617231, 9.11348119612238)     9.113481   45.484600
# 815   (45.4845996617231, 9.11348119612238)     9.113481   45.484600
# 1030  (45.4906906592273, 9.11513731383607)     9.115137   45.490691
# 493   (45.4906906592273, 9.11513731383607)     9.115137   45.490691
# 241   (45.4684543338854, 9.12000353479145)     9.120004   45.468454
# 932   (45.4684543338854, 9.12000353479145)     9.120004   45.468454
# 21    (45.4503203790094, 9.12235445586481)     9.122354   45.450320
# 478   (45.4503203790094, 9.12235445586481)     9.122354   45.450320
# 475   (45.4503203790094, 9.12235445586481)     9.122354   45.450320
# 13     (45.448274461699, 9.12372636565381)     9.123726   45.448274
# 408    (45.448274461699, 9.12372636565381)     9.123726   45.448274
# 921   (45.4887443102695, 9.13850295664949)     9.138503   45.488744
# 193   (45.4887443102695, 9.13850295664949)     9.138503   45.488744
# 1013  (45.4352683735448, 9.14898813475619)     9.148988   45.435268
# 1015  (45.4352683735448, 9.14898813475619)     9.148988   45.435268
# 543   (45.4727519812597, 9.15073659628999)     9.150737   45.472752
# 541   (45.4727519812597, 9.15073659628999)     9.150737   45.472752
# 235   (45.4633375717354, 9.15647462082493)     9.156475   45.463338
# 850   (45.4633375717354, 9.15647462082493)     9.156475   45.463338
# 851   (45.4633375717354, 9.15647462082493)     9.156475   45.463338
# 236   (45.4633375717354, 9.15647462082493)     9.156475   45.463338
# 269   (45.5180879112439, 9.16339824021147)     9.163398   45.518088
# 819   (45.5180879112439, 9.16339824021147)     9.163398   45.518088
# 768   (45.5180879112439, 9.16339824021147)     9.163398   45.518088
# 771   (45.5180879112439, 9.16339824021147)     9.163398   45.518088
# 763   (45.4384492158624, 9.17048513831682)     9.170485   45.438449
# 764   (45.4384492158624, 9.17048513831682)     9.170485   45.438449
# 759     (45.4251200775834, 9.173163699451)     9.173164   45.425120
# 1031    (45.4251200775834, 9.173163699451)     9.173164   45.425120
# 494   (45.4537151582026, 9.20492066457257)     9.204921   45.453715
# 59    (45.4537151582026, 9.20492066457257)     9.204921   45.453715
# 887   (45.5249492324006, 9.21419606496775)     9.214196   45.524949
# 888   (45.5249492324006, 9.21419606496775)     9.214196   45.524949
# 292   (45.5249492324006, 9.21419606496775)     9.214196   45.524949
# 291   (45.5249492324006, 9.21419606496775)     9.214196   45.524949
# 872   (45.4758257736987, 9.21519576591448)     9.215196   45.475826
# 873   (45.4758257736987, 9.21519576591448)     9.215196   45.475826
# 284   (45.4758257736987, 9.21519576591448)     9.215196   45.475826
# 283   (45.4758257736987, 9.21519576591448)     9.215196   45.475826
# 308   (45.4986815761724, 9.25111177885147)     9.251112   45.498682
# 1037  (45.4986815761724, 9.25111177885147)     9.251112   45.498682
#
#                       geometry  index_right            Neighborhood
# 816    POINT (9.11348 45.4846)         66.0                San Siro
# 815    POINT (9.11348 45.4846)         66.0                San Siro
# 1030  POINT (9.11514 45.49069)         25.0             Gallaratese
# 493   POINT (9.11514 45.49069)         25.0             Gallaratese
# 241      POINT (9.12 45.46845)         84.0            Forze Armate
# 932      POINT (9.12 45.46845)         84.0            Forze Armate
# 21    POINT (9.12235 45.45032)         35.0             Lorenteggio
# 478   POINT (9.12235 45.45032)         35.0             Lorenteggio
# 475   POINT (9.12235 45.45032)         35.0             Lorenteggio
# 13    POINT (9.12373 45.44827)         35.0             Lorenteggio
# 408   POINT (9.12373 45.44827)         35.0             Lorenteggio
# 921    POINT (9.1385 45.48874)         57.0                    Qt 8
# 193    POINT (9.1385 45.48874)         57.0                    Qt 8
# 1013  POINT (9.14899 45.43527)          5.0                  Barona
# 1015  POINT (9.14899 45.43527)          5.0                  Barona
# 543   POINT (9.15074 45.47275)         19.0  De Angeli - Monte Rosa
# 541   POINT (9.15074 45.47275)         19.0  De Angeli - Monte Rosa
# 235   POINT (9.15647 45.46334)         82.0              Washington
# 850   POINT (9.15647 45.46334)         82.0              Washington
# 851   POINT (9.15647 45.46334)         82.0              Washington
# 236   POINT (9.15647 45.46334)         82.0              Washington
# 269    POINT (9.1634 45.51809)          7.0               Bovisasca
# 819    POINT (9.1634 45.51809)          7.0               Bovisasca
# 768    POINT (9.1634 45.51809)          7.0               Bovisasca
# 771    POINT (9.1634 45.51809)          7.0               Bovisasca
# 763   POINT (9.17049 45.43845)         65.0          San Cristoforo
# 764   POINT (9.17049 45.43845)         65.0          San Cristoforo
# 759   POINT (9.17316 45.42512)         70.0                 Stadera
# 1031  POINT (9.17316 45.42512)         70.0                 Stadera
# 494   POINT (9.20492 45.45372)         55.0            Porta Romana
# 59    POINT (9.20492 45.45372)         55.0            Porta Romana
# 887    POINT (9.2142 45.52495)          6.0                 Bicocca
# 888    POINT (9.2142 45.52495)          6.0                 Bicocca
# 292    POINT (9.2142 45.52495)          6.0                 Bicocca
# 291    POINT (9.2142 45.52495)          6.0                 Bicocca
# 872    POINT (9.2152 45.47583)         11.0  Buenos Aires - Venezia
# 873    POINT (9.2152 45.47583)         11.0  Buenos Aires - Venezia
# 284    POINT (9.2152 45.47583)         11.0  Buenos Aires - Venezia
# 283    POINT (9.2152 45.47583)         11.0  Buenos Aires - Venezia
# 308   POINT (9.25111 45.49868)         50.0  Parco Lambro - Cimiano
# 1037  POINT (9.25111 45.49868)         50.0  Parco Lambro - Cimiano

# %%
# Removing the dupes
PolySportVenues = PolySportVenues.drop_duplicates(subset=['info','geometry'])
PolySportVenues
# Out:
#              FAX                            Nome                    Indirizzo  \
# 0           None                  NON ATTRIBUITO         VIA USSI STEFANO   4
# 1           None                   S.S. BAGGIO 2    VIA OLIVIERI ALESSIO   11
# 2     0239210739                  LIDO DI MILANO       PLE LOTTO LORENZO   15
# 3           None  COOP. AGRISPORT SEZIONE CALCIO         VIA DEL RICORDO   58
# 4           None  SOCIETA GINNASTICA MILANO 2000  VIA MARTIGNONI ADELE   1  A
# ...          ...                             ...                          ...
# 1035  0262345191               PALESTRA MASCAGNI       VIA MASCAGNI PIETRO  6
# 1036        None  A.S.D. PICCOLA SCUOLA DI CIRCO                VIA CENISIO 2
# 1038        None             A.S.D. RUGBY MILANO               VIA LICATA  41
# 1039  0248713719  AREA EX PALAZZETTO DELLO SPORT      VIA DEI PICCOLOMINI SNC
# 1040        None       FEDERAZIONE ITALIANA GOLF     VIA CORELLI ARCANGELO 71
#
#      Zona               info                 URL   TELEFONO1 ID_NIL  \
# 0       9    CENTRO SPORTIVO                None        None     13
# 1       7        CALCIO A 11                None   024599310     56
# 2       8          MINI GOLF  www.milanosport.it  0239266100     66
# 3       2    CENTRO SPORTIVO                None  0227207742     17
# 4       2    CENTRO SPORTIVO                None    02603288     12
# ...   ...                ...                 ...         ...    ...
# 1035    1           PALESTRA  www.milanosport.it     0262345      4
# 1036    8  ATTIVITA CIRCENSE                None        None     70
# 1038    3              RUGBY                None        None     18
# 1039    7         PARCHEGGIO     www.sansiro.net  0248713713     60
# 1040    3               GOLF                None        None     24
#
#                                   NIL                              Location  \
# 0                     GRECO - SEGNANO  (45.5071015469858, 9.20835578748649)
# 1                        FORZE ARMATE  (45.4655714935197, 9.11156409171595)
# 2                                QT 8  (45.4805639255761, 9.14194021229098)
# 3                             ADRIANO  (45.5093199390653, 9.23794027433961)
# 4             MACIACHINI - MAGGIOLINA   (45.492566239195, 9.19613835069693)
# ...                               ...                                   ...
# 1035                        GUASTALLA  (45.4658020924376, 9.20136672218329)
# 1036                         GHISOLFA   (45.4876030737289, 9.1732839281514)
# 1038  CIMIANO - ROTTOLE - Q.RE FELTRE  (45.4986815797783, 9.25111177630766)
# 1039               STADIO - IPPODROMI  (45.4781768596385, 9.12081301575318)
# 1040       PARCO FORLANINI - CAVRIANO  (45.4710322728757, 9.25603373738114)
#
#       LONG_X_4326  LAT_Y_4326                  geometry  index_right  \
# 0        9.208356   45.507102   POINT (9.20836 45.5071)         30.0
# 1        9.111564   45.465571  POINT (9.11156 45.46557)         84.0
# 2        9.141940   45.480564  POINT (9.14194 45.48056)         57.0
# 3        9.237940   45.509320  POINT (9.23794 45.50932)          1.0
# 4        9.196138   45.492566  POINT (9.19614 45.49257)         37.0
# ...           ...         ...                       ...          ...
# 1035     9.201367   45.465802   POINT (9.20137 45.4658)         31.0
# 1036     9.173284   45.487603   POINT (9.17328 45.4876)         26.0
# 1038     9.251112   45.498682  POINT (9.25111 45.49868)         50.0
# 1039     9.120813   45.478177  POINT (9.12081 45.47818)         66.0
# 1040     9.256034   45.471032  POINT (9.25603 45.47103)         49.0
#
#                   Neighborhood
# 0                        Greco
# 1                 Forze Armate
# 2                         Qt 8
# 3                      Adriano
# 4      Maciachini - Maggiolina
# ...                        ...
# 1035                 Guastalla
# 1036                  Ghisolfa
# 1038    Parco Lambro - Cimiano
# 1039                  San Siro
# 1040  Parco Forlanini - Ortica
#
# [977 rows x 15 columns]

# %%
# Find duplicates based on the 'geometry' column
duplicates2 = PolySportVenues[PolySportVenues.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates2.sort_values(by = 'LONG_X_4326')
# Out:
#             FAX              Nome                    Indirizzo Zona  \
# 112        None  SANTA MARCELLINA      VIA MOSCA ANTONIO   185    7
# 482        None  SANTA MARCELLINA      VIA MOSCA ANTONIO   185    7
# 480        None  SANTA MARCELLINA      VIA MOSCA ANTONIO   185    7
# 481        None  SANTA MARCELLINA      VIA MOSCA ANTONIO   185    7
# 966        None     G.S. MUGGIANO            VIA MUGGIANO   14    7
# ..          ...               ...                          ...  ...
# 438  0270200295       MARIO SAINI  VIA CORELLI ARCANGELO   136    3
# 444  0270200295       MARIO SAINI  VIA CORELLI ARCANGELO   136    3
# 435  0270200295       MARIO SAINI  VIA CORELLI ARCANGELO   136    3
# 436  0270200295       MARIO SAINI  VIA CORELLI ARCANGELO   136    3
# 445  0270200295       MARIO SAINI  VIA CORELLI ARCANGELO   136    3
#
#                 info                           URL  TELEFONO1 ID_NIL  \
# 112  CENTRO SPORTIVO                          None       None     54
# 482           TENNIS                          None       None     54
# 480      CALCIO A 11                          None       None     54
# 481    PALLACANESTRO                          None       None     54
# 966       CALCIO A 7  ww.grupposportivomuggiano.it       None     54
# ..               ...                           ...        ...    ...
# 438            NUOTO            www.milanosport.it  027561280     24
# 444            RUGBY            www.milanosport.it  027561280     24
# 435       CALCIO A 5            www.milanosport.it  027561280     24
# 436       GINNASTICA            www.milanosport.it  027561280     24
# 445          SCHERMA            www.milanosport.it  027561280     24
#
#                             NIL                              Location  \
# 112                    MUGGIANO  (45.4510450947062, 9.07018691135817)
# 482                    MUGGIANO  (45.4510450947062, 9.07018691135817)
# 480                    MUGGIANO  (45.4510450947062, 9.07018691135817)
# 481                    MUGGIANO  (45.4510450947062, 9.07018691135817)
# 966                    MUGGIANO  (45.4481443742503, 9.07037129658034)
# ..                          ...                                   ...
# 438  PARCO FORLANINI - CAVRIANO  (45.4699676940051, 9.26340502898979)
# 444  PARCO FORLANINI - CAVRIANO  (45.4699676940051, 9.26340502898979)
# 435  PARCO FORLANINI - CAVRIANO  (45.4699676940051, 9.26340502898979)
# 436  PARCO FORLANINI - CAVRIANO  (45.4699676940051, 9.26340502898979)
# 445  PARCO FORLANINI - CAVRIANO  (45.4699676940051, 9.26340502898979)
#
#      LONG_X_4326  LAT_Y_4326                  geometry  index_right  \
# 112     9.070187   45.451045  POINT (9.07019 45.45105)         41.0
# 482     9.070187   45.451045  POINT (9.07019 45.45105)         41.0
# 480     9.070187   45.451045  POINT (9.07019 45.45105)         41.0
# 481     9.070187   45.451045  POINT (9.07019 45.45105)         41.0
# 966     9.070371   45.448144  POINT (9.07037 45.44814)         41.0
# ..           ...         ...                       ...          ...
# 438     9.263405   45.469968  POINT (9.26341 45.46997)         49.0
# 444     9.263405   45.469968  POINT (9.26341 45.46997)         49.0
# 435     9.263405   45.469968  POINT (9.26341 45.46997)         49.0
# 436     9.263405   45.469968  POINT (9.26341 45.46997)         49.0
# 445     9.263405   45.469968  POINT (9.26341 45.46997)         49.0
#
#                  Neighborhood
# 112                  Muggiano
# 482                  Muggiano
# 480                  Muggiano
# 481                  Muggiano
# 966                  Muggiano
# ..                        ...
# 438  Parco Forlanini - Ortica
# 444  Parco Forlanini - Ortica
# 435  Parco Forlanini - Ortica
# 436  Parco Forlanini - Ortica
# 445  Parco Forlanini - Ortica
#
# [928 rows x 15 columns]

# %%
PolySportVenues['info'].unique()
# Out:
# array(['CENTRO SPORTIVO', 'CALCIO A 11', 'MINI GOLF', 'ATLETICA',
#        'PISCINA', 'NUOTO', 'PALESTRA', 'PALLACANESTRO', 'TENNIS',
#        'GINNASTICA', 'CALCIO A 5', 'BOCCIODROMO', 'CENTRO BALNEARE',
#        'BODY BUILDING', 'BASEBALL', 'FITNESS MACCHINE', 'CALCIO A 7',
#        'GINNASTICA ATTREZZISTICA', 'TENNIS TAVOLO', 'PALLAVOLO', 'BOXE',
#        'SCHERMA', 'PALLAMANO', 'ATTIVITA SUBACQUEA', 'BEACH VOLLEY',
#        'HOCKEY IN LINE', 'PATTINAGGIO A ROTELLE',
#        'PATTINAGGIO SU GHIACCIO', 'ROLLER BLADE', 'RUGBY', 'SCI DI FONDO',
#        'SOFTBALL', "TIRO CON L'ARCO", 'TUFFI', 'FOOTBALL AMERICANO',
#        'SQUASH', 'CANOTTAGGIO', 'BRIDGE', 'BOCCE', 'PALLANUOTO', 'HOCKEY',
#        'SPORT EQUESTRE', 'DANZA', 'GOLF', 'TIRO A SEGNO', 'CALCIO',
#        'BADMINTON', 'BALLO', 'BMX', 'CICLISMO', 'FITNESS',
#        'BILIARDO-BOCCETTE', 'WINSURF', 'ATTIVITA CIRCENSE', 'PARCHEGGIO'],
#       dtype=object)

# %%
# Group by 'geometry' and check if "CENTRO SPORTIVO" appears
has_centro_sportivo = (
    PolySportVenues.groupby("geometry")["info"]
       .apply(lambda infos: "CENTRO SPORTIVO" in infos.values)
)

# True  -> That geometry has at least one row with info = "CENTRO SPORTIVO"
# False -> That geometry does NOT have any row with info = "CENTRO SPORTIVO"

missing_centro_sportivo = has_centro_sportivo[~has_centro_sportivo]
print(missing_centro_sportivo)
# Out:
# geometry
# POINT (9.12373 45.44827)    False
# POINT (9.12219 45.44701)    False
# POINT (9.15029 45.45089)    False
# POINT (9.16548 45.45686)    False
# POINT (9.16021 45.46101)    False
#                             ...
# POINT (9.19409 45.43687)    False
# POINT (9.20918 45.44905)    False
# POINT (9.21353 45.44354)    False
# POINT (9.18353 45.43266)    False
# POINT (9.17316 45.42512)    False
# Name: info, Length: 124, dtype: bool

# %%
only_one_centro_sportivo = (
    PolySportVenues.groupby("geometry")["info"]
       .apply(lambda group_info: len(group_info) == 1 and group_info.iloc[0] == "CENTRO SPORTIVO")
)

# True means that geometry has exactly one row and it is "CENTRO SPORTIVO"
# False otherwise.

geoms_only_one_centro = only_one_centro_sportivo[only_one_centro_sportivo].index
print(geoms_only_one_centro)
# Out:
# Index([ POINT (9.13050541386769 45.455718774036),
#        POINT (9.11136807777138 45.4582460489244),
#        POINT (9.20835578748649 45.5071015469858),
#        POINT (9.22909319309963 45.4476095042998),
#        POINT (9.19055665156447 45.4473595824136),
#         POINT (9.16774499725052 45.445597424879),
#        POINT (9.18790696740882 45.4319819313502)],
#       dtype='geometry', name='geometry')

# %%
group_sizes = PolySportVenues.groupby("geometry")["info"].transform("size")


#    - Keep if geometry size == 1 (single-entry group)
#    - OR keep if geometry size > 1 AND info != CENTRO SPORTIVO (multi-entry group)
condition = (group_sizes == 1) | ((group_sizes > 1) & (PolySportVenues["info"] != "CENTRO SPORTIVO"))

# filter the original GeoDataFrame
PolySportVenues = PolySportVenues[condition]
PolySportVenues.sort_values('LONG_X_4326')
# Out:
#             FAX              Nome                    Indirizzo Zona  \
# 482        None  SANTA MARCELLINA      VIA MOSCA ANTONIO   185    7
# 480        None  SANTA MARCELLINA      VIA MOSCA ANTONIO   185    7
# 481        None  SANTA MARCELLINA      VIA MOSCA ANTONIO   185    7
# 966        None     G.S. MUGGIANO            VIA MUGGIANO   14    7
# 967        None     G.S. MUGGIANO            VIA MUGGIANO   14    7
# ..          ...               ...                          ...  ...
# 435  0270200295       MARIO SAINI  VIA CORELLI ARCANGELO   136    3
# 434  0270200295       MARIO SAINI  VIA CORELLI ARCANGELO   136    3
# 433  0270200295       MARIO SAINI  VIA CORELLI ARCANGELO   136    3
# 441  0270200295       MARIO SAINI  VIA CORELLI ARCANGELO   136    3
# 450  0270200295       MARIO SAINI  VIA CORELLI ARCANGELO   136    3
#
#                       info                           URL  TELEFONO1 ID_NIL  \
# 482                 TENNIS                          None       None     54
# 480            CALCIO A 11                          None       None     54
# 481          PALLACANESTRO                          None       None     54
# 966             CALCIO A 7  ww.grupposportivomuggiano.it       None     54
# 967            CALCIO A 11  ww.grupposportivomuggiano.it       None     54
# ..                     ...                           ...        ...    ...
# 435             CALCIO A 5            www.milanosport.it  027561280     24
# 434            CALCIO A 11            www.milanosport.it  027561280     24
# 433           BEACH VOLLEY            www.milanosport.it  027561280     24
# 441  PATTINAGGIO A ROTELLE            www.milanosport.it  027561280     24
# 450                  TUFFI            www.milanosport.it  027561280     24
#
#                             NIL                              Location  \
# 482                    MUGGIANO  (45.4510450947062, 9.07018691135817)
# 480                    MUGGIANO  (45.4510450947062, 9.07018691135817)
# 481                    MUGGIANO  (45.4510450947062, 9.07018691135817)
# 966                    MUGGIANO  (45.4481443742503, 9.07037129658034)
# 967                    MUGGIANO  (45.4481443742503, 9.07037129658034)
# ..                          ...                                   ...
# 435  PARCO FORLANINI - CAVRIANO  (45.4699676940051, 9.26340502898979)
# 434  PARCO FORLANINI - CAVRIANO  (45.4699676940051, 9.26340502898979)
# 433  PARCO FORLANINI - CAVRIANO  (45.4699676940051, 9.26340502898979)
# 441  PARCO FORLANINI - CAVRIANO  (45.4699676940051, 9.26340502898979)
# 450  PARCO FORLANINI - CAVRIANO  (45.4699676940051, 9.26340502898979)
#
#      LONG_X_4326  LAT_Y_4326                  geometry  index_right  \
# 482     9.070187   45.451045  POINT (9.07019 45.45105)         41.0
# 480     9.070187   45.451045  POINT (9.07019 45.45105)         41.0
# 481     9.070187   45.451045  POINT (9.07019 45.45105)         41.0
# 966     9.070371   45.448144  POINT (9.07037 45.44814)         41.0
# 967     9.070371   45.448144  POINT (9.07037 45.44814)         41.0
# ..           ...         ...                       ...          ...
# 435     9.263405   45.469968  POINT (9.26341 45.46997)         49.0
# 434     9.263405   45.469968  POINT (9.26341 45.46997)         49.0
# 433     9.263405   45.469968  POINT (9.26341 45.46997)         49.0
# 441     9.263405   45.469968  POINT (9.26341 45.46997)         49.0
# 450     9.263405   45.469968  POINT (9.26341 45.46997)         49.0
#
#                  Neighborhood
# 482                  Muggiano
# 480                  Muggiano
# 481                  Muggiano
# 966                  Muggiano
# 967                  Muggiano
# ..                        ...
# 435  Parco Forlanini - Ortica
# 434  Parco Forlanini - Ortica
# 433  Parco Forlanini - Ortica
# 441  Parco Forlanini - Ortica
# 450  Parco Forlanini - Ortica
#
# [766 rows x 15 columns]

# %%
# Update 'info' column
PolySportVenues["info"] = PolySportVenues["info"].replace({
    "CALCIO A 5": "CALCIO",
    "CALCIO A 7": "CALCIO",
    "CALCIO A 11": "CALCIO",
    "NUOTO": "PISCINA",
    "FITNESS MACCHINE": "FITNESS"
})

# Remove duplicates of CALCIO, PISCINA and FITNESS
PolySportVenues = PolySportVenues.drop_duplicates(subset=['info','geometry'])

# Remove rows where info == "PARCHEGGIO"
PolySportVenues = PolySportVenues[PolySportVenues["info"] != "PARCHEGGIO"].copy()

PolySportVenues
# Out:
#                                Nome                  Indirizzo  \
# 0                    NON ATTRIBUITO       VIA USSI STEFANO   4
# 1                     S.S. BAGGIO 2  VIA OLIVIERI ALESSIO   11
# 2                    LIDO DI MILANO     PLE LOTTO LORENZO   15
# 3          PRO PATRIA MILANO S.R.L.            VLE SARCA   205
# 4                    NON ATTRIBUITO      VIA DEGLI ANEMONI   8
# ..                              ...                        ...
# 683                     TURNO SETTE     VIA VALLA LORENZO  SNC
# 684               PALESTRA MASCAGNI     VIA MASCAGNI PIETRO  6
# 685  A.S.D. PICCOLA SCUOLA DI CIRCO              VIA CENISIO 2
# 686             A.S.D. RUGBY MILANO             VIA LICATA  41
# 687       FEDERAZIONE ITALIANA GOLF   VIA CORELLI ARCANGELO 71
#
#                   info                  geometry              Neighborhood
# 0      CENTRO SPORTIVO   POINT (9.20836 45.5071)                     Greco
# 1               CALCIO  POINT (9.11156 45.46557)              Forze Armate
# 2            MINI GOLF  POINT (9.14194 45.48056)                      Qt 8
# 3             ATLETICA   POINT (9.21025 45.5188)                   Bicocca
# 4      CENTRO SPORTIVO  POINT (9.13051 45.45572)               Lorenteggio
# ..                 ...                       ...                       ...
# 683    CENTRO SPORTIVO  POINT (9.18791 45.43198)                   Stadera
# 684           PALESTRA   POINT (9.20137 45.4658)                 Guastalla
# 685  ATTIVITA CIRCENSE   POINT (9.17328 45.4876)                  Ghisolfa
# 686              RUGBY  POINT (9.25111 45.49868)    Parco Lambro - Cimiano
# 687               GOLF  POINT (9.25603 45.47103)  Parco Forlanini - Ortica
#
# [688 rows x 5 columns]

# %%
# Keeping only relevant variables
PolySportVenues = PolySportVenues[["Nome", "Indirizzo", "info",
                             "geometry", "Neighborhood"]].reset_index(drop=True)

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolySportVenues[PolySportVenues.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [Nome, Indirizzo, info, geometry, Neighborhood]
# Index: []

# %%
# Saving the file
PolySportVenues.to_file("PolySportVenues.geojson", driver="GeoJSON")

# %% [markdown]
# ## Public Schools

# %%
# Load the GeoDataFrame
publicschools = gpd.read_file("geojson_files/ds1305_elenco_scuole_statali_as2020_21_final_.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != publicschools.crs:
    publicschools = publicschools.to_crs(gdf_combined.crs)

# Perform the spatial join
PolyPublicSchools = gpd.sjoin(publicschools, gdf_combined, how="left", predicate="within")
PolyPublicSchools = PolyPublicSchools[~PolyPublicSchools["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolyPublicSchools
# Out:
#     ANNOSCOLASTICO AREAGEOGRAFICA CODICEISTITUTORIFERIMENTO  \
# 0           202021     NORD OVEST                MIPC20000G
# 1           202021     NORD OVEST                MIIC8BB008
# 2           202021     NORD OVEST                MIIC8BB008
# 3           202021     NORD OVEST                MIIC8D3009
# 4           202021     NORD OVEST                MIIC8BD00X
# ..             ...            ...                       ...
# 467         202021     NORD OVEST                MIIC8CF006
# 468         202021     NORD OVEST                MIIC8CF006
# 469         202021     NORD OVEST                MIIC8CF006
# 470         202021     NORD OVEST                MIIC8CF006
# 471         202021     NORD OVEST                MIIC8CF006
#
#     DENOMINAZIONEISTITUTORIFERIMENTO CODICESCUOLA  \
# 0                         TITO LIVIO   MIPC20000G
# 1                  IC A. DIAZ/MILANO   MIEE8BB02B
# 2                  IC A. DIAZ/MILANO   MIEE8BB01A
# 3              I.C. A. SCARPA MILANO   MIEE8D302C
# 4    MILANO SPIGA ROSSARICASTIGLIONI   MIMM8BD011
# ..                               ...          ...
# 467              IC C. CANTU'/MILANO   MIAA8CF013
# 468              IC C. CANTU'/MILANO   MIEE8CF018
# 469              IC C. CANTU'/MILANO   MIIC8CF006
# 470              IC C. CANTU'/MILANO   MIMM8CF017
# 471              IC C. CANTU'/MILANO   MIEE8CF029
#
#                        DENOMINAZIONESCUOLA     INDIRIZZOSCUOLA  \
# 0                               TITO LIVIO         VIA CIRCO 4
# 1                              E.DE MARCHI  VIA SANT'ORSOLA 15
# 2                          A.DIAZ - MILANO   VIA CROCEFISSO 15
# 3    FONDAZIONE IRCCS-IST. NAZ. DEI TUMORI      VIA VENEZIAN 1
# 4            ICS MILANO SPIGA (PARINI SMS)    VIA S.SPIRITO 21
# ..                                     ...                 ...
# 467                        VIA DORA BALTEA  VIA DORA BALTEA 24
# 468                      C.CANTU' - MILANO  VIA DEI BRASCHI 12
# 469                    IC C. CANTU'/MILANO  VIA DEI BRASCHI 12
# 470                                   SABA     VIA DEL VOLGA 3
# 471                             ANNA FRANK  VIA DORA BALTEA 16
#
#     DESCRIZIONECARATTERISTICASCUOLA DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA  \
# 0                           NORMALE                            LICEO CLASSICO
# 1                           NORMALE                           SCUOLA PRIMARIA
# 2                           NORMALE                           SCUOLA PRIMARIA
# 3              C/O IST. OSPEDALIERO                           SCUOLA PRIMARIA
# 4                           NORMALE                        SCUOLA PRIMO GRADO
# ..                              ...                                       ...
# 467                         NORMALE                           SCUOLA INFANZIA
# 468                         NORMALE                           SCUOLA PRIMARIA
# 469                         NORMALE                      ISTITUTO COMPRENSIVO
# 470                         NORMALE                        SCUOLA PRIMO GRADO
# 471                         NORMALE                           SCUOLA PRIMARIA
#
#     INDICAZIONESEDEDIRETTIVO  ...    CAP MUNICIPIO ID_NIL       NIL  \
# 0                         SI  ...  20123         1      1     DUOMO
# 1                         NO  ...  20123         1      1     DUOMO
# 2                         NO  ...  20122         1      1     DUOMO
# 3                         NO  ...  20121         1      1     DUOMO
# 4                         NO  ...  20121         1      1     DUOMO
# ..                       ...  ...    ...       ...    ...       ...
# 467                       NO  ...  20161         9     83  BRUZZANO
# 468                       NO  ...  20161         9     83  BRUZZANO
# 469                       SI  ...  20161         9     83  BRUZZANO
# 470                       NO  ...  20161         9     83  BRUZZANO
# 471                       NO  ...  20161         9     83  BRUZZANO
#
#                                     Location LONG_X_4326 LAT_Y_4326  \
# 0     (45.46163700000005, 9.180742500000065)    9.180743  45.461637
# 1     (45.46259100000003, 9.180513000000076)    9.180513  45.462591
# 2     (45.45694800000007, 9.185886000000039)    9.185886  45.456948
# 3     (45.46728000000007, 9.197793000000047)    9.197793  45.467280
# 4    (45.470574000000056, 9.195606000000055)    9.195606  45.470574
# ..                                       ...         ...        ...
# 467   (45.52858800000007, 9.167278500000066)    9.167279  45.528588
# 468   (45.52641900000003, 9.176679000000036)    9.176679  45.526419
# 469   (45.52641900000003, 9.176679000000036)    9.176679  45.526419
# 470   (45.52551900000003, 9.172372500000051)    9.172373  45.525519
# 471   (45.52794000000006, 9.168223500000067)    9.168224  45.527940
#
#                      geometry index_right Neighborhood
# 0    POINT (9.18074 45.46164)        21.0        Duomo
# 1    POINT (9.18051 45.46259)        21.0        Duomo
# 2    POINT (9.18589 45.45695)        21.0        Duomo
# 3    POINT (9.19779 45.46728)        21.0        Duomo
# 4    POINT (9.19561 45.47057)        21.0        Duomo
# ..                        ...         ...          ...
# 467  POINT (9.16728 45.52859)        10.0     Bruzzano
# 468  POINT (9.17668 45.52642)        10.0     Bruzzano
# 469  POINT (9.17668 45.52642)        10.0     Bruzzano
# 470  POINT (9.17237 45.52552)        10.0     Bruzzano
# 471  POINT (9.16822 45.52794)        10.0     Bruzzano
#
# [460 rows x 25 columns]

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolyPublicSchools[PolyPublicSchools.duplicated(subset=['geometry'], keep= False)]

# Inspect the duplicate rows
duplicates
# Out:
#     ANNOSCOLASTICO AREAGEOGRAFICA CODICEISTITUTORIFERIMENTO  \
# 4           202021     NORD OVEST                MIIC8BD00X
# 5           202021     NORD OVEST                MIIC8BD00X
# 9           202021     NORD OVEST                MIIC814009
# 14          202021     NORD OVEST                MIIC814009
# 18          202021     NORD OVEST                MIPC110009
# ..             ...            ...                       ...
# 463         202021     NORD OVEST                MIIS038002
# 464         202021     NORD OVEST                MIIS03600A
# 465         202021     NORD OVEST                MIIS03600A
# 468         202021     NORD OVEST                MIIC8CF006
# 469         202021     NORD OVEST                MIIC8CF006
#
#            DENOMINAZIONEISTITUTORIFERIMENTO CODICESCUOLA  \
# 4           MILANO SPIGA ROSSARICASTIGLIONI   MIMM8BD011
# 5           MILANO SPIGA ROSSARICASTIGLIONI   MIIC8BD00X
# 9                       IC CAVALIERI/MILANO   MIEE81402C
# 14                      IC CAVALIERI/MILANO   MIMM81402B
# 18   E.SETTI CARRARO DALLA CHIESA C/O EDUC.   MIPC110009
# ..                                      ...          ...
# 463                 GIUSEPPE LUIGI LAGRANGE   MITF03801E
# 464                VILFREDO FEDERICO PARETO   MITD03601L
# 465                VILFREDO FEDERICO PARETO   MIRA03601A
# 468                     IC C. CANTU'/MILANO   MIEE8CF018
# 469                     IC C. CANTU'/MILANO   MIIC8CF006
#
#                         DENOMINAZIONESCUOLA          INDIRIZZOSCUOLA  \
# 4             ICS MILANO SPIGA (PARINI SMS)         VIA S.SPIRITO 21
# 5           MILANO SPIGA ROSSARICASTIGLIONI        VIA S. SPIRITO 21
# 9     AZ. OSP. FATEBENEFRATELLI E OFTALMICO  CORSO DI PORTA NUOVA 23
# 14           OSPEDALE FATEBENEFRATELLI - MI     CORSO PORTA NUOVA 23
# 18   E.SETTI CARRARO DALLA CHIESA C/O EDUC.    VIA DELLA PASSIONE 12
# ..                                      ...                      ...
# 463                 GIUSEPPE LUIGI LAGRANGE    VIA LITTA MODIGNANI65
# 464                VILFREDO FEDERICO PARETO   VIA LITTA MODIGNANI 55
# 465         I.P.A.A. (SEZ.AS.) V. F. PARETO   VIA LITTA MODIGNANI 55
# 468                       C.CANTU' - MILANO       VIA DEI BRASCHI 12
# 469                     IC C. CANTU'/MILANO       VIA DEI BRASCHI 12
#
#     DESCRIZIONECARATTERISTICASCUOLA DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA  \
# 4                           NORMALE                        SCUOLA PRIMO GRADO
# 5                           NORMALE                      ISTITUTO COMPRENSIVO
# 9              C/O IST. OSPEDALIERO                           SCUOLA PRIMARIA
# 14             C/O IST. OSPEDALIERO                        SCUOLA PRIMO GRADO
# 18                ANN. A EDUCANDATO                            LICEO CLASSICO
# ..                              ...                                       ...
# 463                         NORMALE              ISTITUTO TECNICO INDUSTRIALE
# 464                         NORMALE              ISTITUTO TECNICO COMMERCIALE
# 465                         NORMALE   IST PROF PER L'AGRICOLTURA E L'AMBIENTE
# 468                         NORMALE                           SCUOLA PRIMARIA
# 469                         NORMALE                      ISTITUTO COMPRENSIVO
#
#     INDICAZIONESEDEDIRETTIVO  ...    CAP MUNICIPIO ID_NIL        NIL  \
# 4                         NO  ...  20121         1      1      DUOMO
# 5                         SI  ...  20121         1      1      DUOMO
# 9                         NO  ...  20121         1      2      BRERA
# 14                        NO  ...  20121         1      2      BRERA
# 18                        NO  ...  20122         1      4  GUASTALLA
# ..                       ...  ...    ...       ...    ...        ...
# 463                       NO  ...  20161         9     81  BOVISASCA
# 464                       NO  ...  20161         9     81  BOVISASCA
# 465                       NO  ...  20161         9     81  BOVISASCA
# 468                       NO  ...  20161         9     83   BRUZZANO
# 469                       SI  ...  20161         9     83   BRUZZANO
#
#                                     Location LONG_X_4326 LAT_Y_4326  \
# 4    (45.470574000000056, 9.195606000000055)    9.195606  45.470574
# 5    (45.470574000000056, 9.195606000000055)    9.195606  45.470574
# 9     (45.478575000000035, 9.19216350000005)    9.192163  45.478575
# 14    (45.478575000000035, 9.19216350000005)    9.192163  45.478575
# 18    (45.46498500000007, 9.202140000000043)    9.202140  45.464985
# ..                                       ...         ...        ...
# 463    (45.52202700000004, 9.15642900000006)    9.156429  45.522027
# 464   (45.52285500000005, 9.160749000000067)    9.160749  45.522855
# 465   (45.52285500000005, 9.160749000000067)    9.160749  45.522855
# 468   (45.52641900000003, 9.176679000000036)    9.176679  45.526419
# 469   (45.52641900000003, 9.176679000000036)    9.176679  45.526419
#
#                      geometry index_right Neighborhood
# 4    POINT (9.19561 45.47057)        21.0        Duomo
# 5    POINT (9.19561 45.47057)        21.0        Duomo
# 9    POINT (9.19216 45.47858)         9.0        Brera
# 14   POINT (9.19216 45.47858)         9.0        Brera
# 18   POINT (9.20214 45.46498)        31.0    Guastalla
# ..                        ...         ...          ...
# 463  POINT (9.15643 45.52203)         7.0    Bovisasca
# 464  POINT (9.16075 45.52286)         7.0    Bovisasca
# 465  POINT (9.16075 45.52286)         7.0    Bovisasca
# 468  POINT (9.17668 45.52642)        10.0     Bruzzano
# 469  POINT (9.17668 45.52642)        10.0     Bruzzano
#
# [265 rows x 25 columns]

# %%
# There are schools with more than one grade
PolyPublicSchools[PolyPublicSchools['DENOMINAZIONEISTITUTORIFERIMENTO']=='MILANO SPIGA ROSSARICASTIGLIONI']
# Out:
#    ANNOSCOLASTICO AREAGEOGRAFICA CODICEISTITUTORIFERIMENTO  \
# 4          202021     NORD OVEST                MIIC8BD00X
# 5          202021     NORD OVEST                MIIC8BD00X
# 6          202021     NORD OVEST                MIIC8BD00X
# 12         202021     NORD OVEST                MIIC8BD00X
#
#    DENOMINAZIONEISTITUTORIFERIMENTO CODICESCUOLA  \
# 4   MILANO SPIGA ROSSARICASTIGLIONI   MIMM8BD011
# 5   MILANO SPIGA ROSSARICASTIGLIONI   MIIC8BD00X
# 6   MILANO SPIGA ROSSARICASTIGLIONI   MIEE8BD012
# 12  MILANO SPIGA ROSSARICASTIGLIONI   MIEE8BD023
#
#                 DENOMINAZIONESCUOLA            INDIRIZZOSCUOLA  \
# 4     ICS MILANO SPIGA (PARINI SMS)           VIA S.SPIRITO 21
# 5   MILANO SPIGA ROSSARICASTIGLIONI          VIA S. SPIRITO 21
# 6            ICS MILANO SPIGA SPIGA         VIA DELLA SPIGA 29
# 12   IC MILANO SPIGA A. DA GIUSSANO  BASTIONI DI PORTA NUOVA 4
#
#    DESCRIZIONECARATTERISTICASCUOLA DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA  \
# 4                          NORMALE                        SCUOLA PRIMO GRADO
# 5                          NORMALE                      ISTITUTO COMPRENSIVO
# 6                          NORMALE                           SCUOLA PRIMARIA
# 12                         NORMALE                           SCUOLA PRIMARIA
#
#    INDICAZIONESEDEDIRETTIVO  ...    CAP MUNICIPIO ID_NIL    NIL  \
# 4                        NO  ...  20121         1      1  DUOMO
# 5                        SI  ...  20121         1      1  DUOMO
# 6                        NO  ...  20121         1      1  DUOMO
# 12                       NO  ...  20121         1      2  BRERA
#
#                                    Location LONG_X_4326 LAT_Y_4326  \
# 4   (45.470574000000056, 9.195606000000055)    9.195606  45.470574
# 5   (45.470574000000056, 9.195606000000055)    9.195606  45.470574
# 6   (45.471123000000034, 9.195651000000055)    9.195651  45.471123
# 12    (45.48002400000007, 9.19118700000007)    9.191187  45.480024
#
#                     geometry index_right Neighborhood
# 4   POINT (9.19561 45.47057)        21.0        Duomo
# 5   POINT (9.19561 45.47057)        21.0        Duomo
# 6   POINT (9.19565 45.47112)        21.0        Duomo
# 12  POINT (9.19119 45.48002)         9.0        Brera
#
# [4 rows x 25 columns]

# %%
# Keeping only relevant variables
PolyPublicSchools = PolyPublicSchools[["DENOMINAZIONESCUOLA", "INDIRIZZOSCUOLA", "DESCRIZIONECARATTERISTICASCUOLA",
                                       "DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA", "MUNICIPIO",
                                       "geometry", "Neighborhood"]]

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolyPublicSchools[PolyPublicSchools.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [DENOMINAZIONESCUOLA, INDIRIZZOSCUOLA, DESCRIZIONECARATTERISTICASCUOLA, DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA, MUNICIPIO, geometry, Neighborhood]
# Index: []

# %% [markdown]
# ## Private Schools

# %%
# Load the GeoDataFrame
privateschools = gpd.read_file("geojson_files/ds1582_elenco_scuole_paritarie_2020-21.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != privateschools.crs:
    privateschools = privateschools.to_crs(gdf_combined.crs)

# Perform the spatial join
PolyPrivateSchools = gpd.sjoin(privateschools, gdf_combined, how="left", predicate="within")
PolyPrivateSchools = PolyPrivateSchools[~PolyPrivateSchools["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolyPrivateSchools
# Out:
#     ANNOSCOLASTICO CODICESCUOLA AREAGEOGRAFICA  \
# 0          2020-21   MI1AEN500Q     NORD OVEST
# 1          2020-21   MI1A03600L     NORD OVEST
# 3          2020-21   MIPS16500L     NORD OVEST
# 4          2020-21   MI1M06000L     NORD OVEST
# 5          2020-21   MI1A09300R     NORD OVEST
# ..             ...          ...            ...
# 456        2020-21   MI1A020003     NORD OVEST
# 457        2020-21   MIPLVI500L     NORD OVEST
# 458        2020-21   MI1A240002     NORD OVEST
# 459        2020-21   MI1A088009     NORD OVEST
# 460        2020-21   MI1E06500E     NORD OVEST
#
#                                DENOMINAZIONESCUOLA     INDIRIZZOSCUOLA  \
# 0                   SCUOLA DELL'INFANZIA DE CURTIS     VIA DE CURTIS 7
# 1       SCUOLA DELL'INFANZIA COMUNALE VIA CESARI42        VIA CESARI42
# 3                    LICEO SCIENTIFICO S. AMBROGIO       V.COPERNICO 9
# 4    SCUOLA SECONDARIA DI 1Â° GR. ISTITUTO GONZAGA       V.VITRUVIO 41
# 5        SCUOLA DELL'INFANZIA COMUNALE VIA MILESI2         VIA MILESI2
# ..                                             ...                 ...
# 456   SCUOLA DELL'INFANZIA COMUNALE VIA BEZZECCA16      VIA BEZZECCA16
# 457                LICEO LINGUISTICO SCUOLA EUROPA      VIALE MAJNO 39
# 458            SCUOLA DELL'INFANZIA "BUON PASTORE"  VIA SAN VITTORE 29
# 459    SCUOLA DELL'INFANZIA COMUNALE VIA MASSAUA15       VIA MASSAUA15
# 460               SCUOLA ELEM.PAR."REGINA CARMELI"       VIA MONVISO33
#
#     CODICECOMUNESCUOLA DESCRIZIONECOMUNE  \
# 0                 F205            MILANO
# 1                 F205            MILANO
# 3                 F205            MILANO
# 4                 F205            MILANO
# 5                 F205            MILANO
# ..                 ...               ...
# 456               F205            MILANO
# 457               F205            MILANO
# 458               F205            MILANO
# 459               F205            MILANO
# 460               F205            MILANO
#
#     DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA      INDIRIZZOEMAILSCUOLA  \
# 0                 SCUOLA INFANZIA NON STATALE  ED.UE11@comune.milano.it
# 1                 SCUOLA INFANZIA NON STATALE           Non Disponibile
# 3       SCUOLA SEC. SECONDO GRADO NON STATALE           Non Disponibile
# 4         SCUOLA SEC. PRIMO GRADO NON STATALE           Non Disponibile
# 5                 SCUOLA INFANZIA NON STATALE           Non Disponibile
# ..                                        ...                       ...
# 456               SCUOLA INFANZIA NON STATALE  ED.UE22@comune.milano.it
# 457     SCUOLA SEC. SECONDO GRADO NON STATALE      info@scuolaeuropa.it
# 458               SCUOLA INFANZIA NON STATALE    ist.buonpastore@tin.it
# 459               SCUOLA INFANZIA NON STATALE           Non Disponibile
# 460               SCUOLA PRIMARIA NON STATALE           Non Disponibile
#
#                         INDIRIZZOPECSCUOLA  ...    CAP MUNICIPIO ID_NIL  \
# 0                          Non Disponibile  ...  20128         2     17
# 1         ED.INFANZIAUE74@COMUNE.MILANO.IT  ...  20162         9     14
# 3                          Non Disponibile  ...  20125         2     10
# 4    ISTITUTOGONZAGA@PEC.GONZAGA-MILANO.IT  ...  20124         2     10
# 5                          Non Disponibile  ...  20152         7     56
# ..                                     ...  ...    ...       ...    ...
# 456                        Non Disponibile  ...  20135         4     26
# 457                        Non Disponibile  ...  20122         1      4
# 458                        Non Disponibile  ...  20123         1      7
# 459                        Non Disponibile  ...  20146         7     52
# 460                        Non Disponibile  ...  20154         8     69
#
#                                                    NIL  \
# 0                                              ADRIANO
# 1    NIGUARDA - CA' GRANDA - PRATO CENTENARO - Q.RE...
# 3                     STAZIONE CENTRALE - PONTE SEVESO
# 4                     STAZIONE CENTRALE - PONTE SEVESO
# 5                                         FORZE ARMATE
# ..                                                 ...
# 456                                         XXII MARZO
# 457                                          GUASTALLA
# 458                               MAGENTA - S. VITTORE
# 459                                         BANDE NERE
# 460                                              SARPI
#
#                                     Location LONG_X_4326  LAT_Y_4326  \
# 0     (45.51610500000004, 9.241659000000027)    9.241659   45.516105
# 1    (45.519363000000055, 9.185922000000062)    9.185922   45.519363
# 3     (45.48806100000007, 9.201118500000064)    9.201119   45.488061
# 4    (45.482589000000075, 9.206046000000072)    9.206046   45.482589
# 5     (45.45990000000006, 9.103392000000042)    9.103392   45.459900
# ..                                       ...         ...         ...
# 456   (45.46074600000003, 9.212449500000048)    9.212449   45.460746
# 457   (45.47240100000005, 9.205083000000059)    9.205083   45.472401
# 458   (45.46344600000003, 9.169632000000036)    9.169632   45.463446
# 459  (45.460503000000074, 9.147406500000045)    9.147407   45.460503
# 460    (45.48595500000005, 9.17022600000007)    9.170226   45.485955
#
#                      geometry index_right           Neighborhood
# 0     POINT (9.24166 45.5161)         1.0                Adriano
# 1    POINT (9.18592 45.51936)        43.0   Niguarda - Cà Granda
# 3    POINT (9.20112 45.48806)        14.0               Centrale
# 4    POINT (9.20605 45.48259)        14.0               Centrale
# 5     POINT (9.10339 45.4599)        84.0           Forze Armate
# ..                        ...         ...                    ...
# 456  POINT (9.21245 45.46075)        83.0             XXII Marzo
# 457   POINT (9.20508 45.4724)        31.0              Guastalla
# 458  POINT (9.16963 45.46345)        38.0  Magenta - San Vittore
# 459   POINT (9.14741 45.4605)         4.0             Bande Nere
# 460  POINT (9.17023 45.48596)        67.0                  Sarpi
#
# [450 rows x 21 columns]

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolyPrivateSchools[PolyPrivateSchools.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates.sort_values(by='LONG_X_4326')
# Out:
#     ANNOSCOLASTICO CODICESCUOLA AREAGEOGRAFICA  \
# 216        2020-21   MI1M104005     NORD OVEST
# 301        2020-21   MI1A231007     NORD OVEST
# 326        2020-21   MI1E02600X     NORD OVEST
# 413        2020-21   MI1A17800G     NORD OVEST
# 325        2020-21   MI1E01300T     NORD OVEST
# ..             ...          ...            ...
# 437        2020-21   MIPS295009     NORD OVEST
# 72         2020-21   MIPC06500L     NORD OVEST
# 205        2020-21   MI1M07300P     NORD OVEST
# 257        2020-21   MIPC25500Q     NORD OVEST
# 256        2020-21   MIPSR85009     NORD OVEST
#
#                                    DENOMINAZIONESCUOLA   INDIRIZZOSCUOLA  \
# 216          SCUOLA SECONDARIA DI 1Â° GR. MADRE BUCCHI       VIA PALMI25
# 301     SCUOLA DELL'INFANZIA PARROCCHIALE MADRE BUCCHI       VIA PALMI25
# 326                   SCUOLA ELEM. PAR. "MADRE BUCCHI"      VIA PALMI 25
# 413  SCUOLA DELL'INFANZIA "CASA DEI BAMBINI SCUOLA ...       VIA AROSIO3
# 325  SCUOLA ELEM.PAR."CASA DEI BAMBINI SCUOLA MONTE...    VIA AROSIO N.3
# ..                                                 ...               ...
# 437           LICEO SCIENTIFICO FONDAZIONE SACRO CUORE     VIA ROMBON 78
# 72               LICEO CLASSICO FONDAZIONE SACRO CUORE     VIA ROMBON 78
# 205  SCUOLA SECONDARIA DI 1Â° GR. FONDAZIONE SACRO ...      VIA ROMBON78
# 257                        LICEO CLASSICO SAN RAFFAELE  VIA OLGETTINA 46
# 256                                       SAN RAFFAELE  VIA OLGETTINA 46
#
#     CODICECOMUNESCUOLA DESCRIZIONECOMUNE  \
# 216               F205            MILANO
# 301               F205            MILANO
# 326               F205            MILANO
# 413               F205            MILANO
# 325               F205            MILANO
# ..                 ...               ...
# 437               F205            MILANO
# 72                F205            MILANO
# 205               F205            MILANO
# 257               F205            MILANO
# 256               F205            MILANO
#
#     DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA           INDIRIZZOEMAILSCUOLA  \
# 216       SCUOLA SEC. PRIMO GRADO NON STATALE                Non Disponibile
# 301               SCUOLA INFANZIA NON STATALE                Non Disponibile
# 326               SCUOLA PRIMARIA NON STATALE                Non Disponibile
# 413               SCUOLA INFANZIA NON STATALE                Non Disponibile
# 325               SCUOLA PRIMARIA NON STATALE                Non Disponibile
# ..                                        ...                            ...
# 437     SCUOLA SEC. SECONDO GRADO NON STATALE                Non Disponibile
# 72      SCUOLA SEC. SECONDO GRADO NON STATALE                Non Disponibile
# 205       SCUOLA SEC. PRIMO GRADO NON STATALE                Non Disponibile
# 257     SCUOLA SEC. SECONDO GRADO NON STATALE  direzione@liceosanraffaele.it
# 256     SCUOLA SEC. SECONDO GRADO NON STATALE  DIREZIONE@LICEOSANRAFFAELE.IT
#
#                         INDIRIZZOPECSCUOLA  ...    CAP MUNICIPIO ID_NIL  \
# 216  SEGRETERIA@PEC.ISTITUTOMADREBUCCHI.IT  ...  20152         7     56
# 301   CERTIFICATA@PEC.SCUOLAMONTESSORI.COM  ...  20152         7     56
# 326  SEGRETERIA@PEC.ISTITUTOMADREBUCCHI.IT  ...  20152         7     56
# 413   casadeibambinimontessori@lamiapec.it  ...  20148         7     60
# 325   casadeibambinimontessori@lamiapec.it  ...  20148         7     60
# ..                                     ...  ...    ...       ...    ...
# 437         FONDAZIONESACROCUORE@EDUPEC.IT  ...  20134         3     23
# 72          FONDAZIONESACROCUORE@EDUPEC.IT  ...  20134         3     23
# 205         FONDAZIONESACROCUORE@EDUPEC.IT  ...  20134         3     23
# 257                        Non Disponibile  ...  20132         3     18
# 256                        Non Disponibile  ...  20132         3     18
#
#                                  NIL                                Location  \
# 216                     FORZE ARMATE  (45.45851400000004, 9.098316000000068)
# 301                     FORZE ARMATE  (45.45851400000004, 9.098316000000068)
# 326                     FORZE ARMATE  (45.45851400000004, 9.098316000000068)
# 413               STADIO - IPPODROMI  (45.47332800000004, 9.124870500000043)
# 325               STADIO - IPPODROMI  (45.47332800000004, 9.124870500000043)
# ..                               ...                                     ...
# 437                LAMBRATE - ORTICA  (45.48618000000005, 9.252153000000021)
# 72                 LAMBRATE - ORTICA  (45.48618000000005, 9.252153000000021)
# 205                LAMBRATE - ORTICA  (45.48618000000005, 9.252153000000021)
# 257  CIMIANO - ROTTOLE - Q.RE FELTRE  (45.50873400000006, 9.266647500000033)
# 256  CIMIANO - ROTTOLE - Q.RE FELTRE  (45.50873400000006, 9.266647500000033)
#
#     LONG_X_4326  LAT_Y_4326                  geometry index_right  \
# 216    9.098316   45.458514  POINT (9.09832 45.45851)        84.0
# 301    9.098316   45.458514  POINT (9.09832 45.45851)        84.0
# 326    9.098316   45.458514  POINT (9.09832 45.45851)        84.0
# 413    9.124871   45.473328  POINT (9.12487 45.47333)        66.0
# 325    9.124871   45.473328  POINT (9.12487 45.47333)        66.0
# ..          ...         ...                       ...         ...
# 437    9.252153   45.486180  POINT (9.25215 45.48618)        33.0
# 72     9.252153   45.486180  POINT (9.25215 45.48618)        33.0
# 205    9.252153   45.486180  POINT (9.25215 45.48618)        33.0
# 257    9.266647   45.508734  POINT (9.26665 45.50873)        50.0
# 256    9.266647   45.508734  POINT (9.26665 45.50873)        50.0
#
#                Neighborhood
# 216            Forze Armate
# 301            Forze Armate
# 326            Forze Armate
# 413                San Siro
# 325                San Siro
# ..                      ...
# 437                Lambrate
# 72                 Lambrate
# 205                Lambrate
# 257  Parco Lambro - Cimiano
# 256  Parco Lambro - Cimiano
#
# [229 rows x 21 columns]

# %%
# There are schools with different school tracks for the same schools
PolyPrivateSchools[PolyPrivateSchools['INDIRIZZOSCUOLA']=='V.COPERNICO 9'][['DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA','DENOMINAZIONESCUOLA']]
# Out:
#     DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA            DENOMINAZIONESCUOLA
# 3       SCUOLA SEC. SECONDO GRADO NON STATALE  LICEO SCIENTIFICO S. AMBROGIO
# 451     SCUOLA SEC. SECONDO GRADO NON STATALE     LICEO CLASSICO S. AMBROGIO

# %%
# Keeping only relevant variables
PolyPrivateSchools = PolyPrivateSchools[["DENOMINAZIONESCUOLA", "INDIRIZZOSCUOLA",
                                       "DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA", "MUNICIPIO",
                                       "geometry", "Neighborhood"]].copy()
PolyPrivateSchools["DESCRIZIONECARATTERISTICASCUOLA"] = "PARITARIA"

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolyPrivateSchools[PolyPrivateSchools.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [DENOMINAZIONESCUOLA, INDIRIZZOSCUOLA, DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA, MUNICIPIO, geometry, Neighborhood, DESCRIZIONECARATTERISTICASCUOLA]
# Index: []

# %% [markdown]
# ## Concat Public and Private Schools

# %%
PolyPrivateSchools = PolyPrivateSchools[[
    "DENOMINAZIONESCUOLA", "INDIRIZZOSCUOLA", "DESCRIZIONECARATTERISTICASCUOLA",
    "DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA", "MUNICIPIO",
    "geometry", "Neighborhood"
]]

PolyPublicSchools = PolyPublicSchools[[
    "DENOMINAZIONESCUOLA", "INDIRIZZOSCUOLA", "DESCRIZIONECARATTERISTICASCUOLA",
    "DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA", "MUNICIPIO",
    "geometry", "Neighborhood"
]]

# Combine the two GeoDataFrames
PolySchools = gpd.GeoDataFrame(pd.concat([PolyPrivateSchools, PolyPublicSchools], ignore_index=True))

# Inspect the combined GeoDataFrame
print(PolySchools.head())
print(f"Total rows: {len(PolySchools)}")

# Saving the file
PolySchools.to_file("PolySchools.geojson", driver="GeoJSON")
# Out:
#                              DENOMINAZIONESCUOLA  INDIRIZZOSCUOLA  \
# 0                 SCUOLA DELL'INFANZIA DE CURTIS  VIA DE CURTIS 7
# 1     SCUOLA DELL'INFANZIA COMUNALE VIA CESARI42     VIA CESARI42
# 2                  LICEO SCIENTIFICO S. AMBROGIO    V.COPERNICO 9
# 3  SCUOLA SECONDARIA DI 1Â° GR. ISTITUTO GONZAGA    V.VITRUVIO 41
# 4      SCUOLA DELL'INFANZIA COMUNALE VIA MILESI2      VIA MILESI2
#
#   DESCRIZIONECARATTERISTICASCUOLA DESCRIZIONETIPOLOGIAGRADOISTRUZIONESCUOLA  \
# 0                       PARITARIA               SCUOLA INFANZIA NON STATALE
# 1                       PARITARIA               SCUOLA INFANZIA NON STATALE
# 2                       PARITARIA     SCUOLA SEC. SECONDO GRADO NON STATALE
# 3                       PARITARIA       SCUOLA SEC. PRIMO GRADO NON STATALE
# 4                       PARITARIA               SCUOLA INFANZIA NON STATALE
#
#   MUNICIPIO                  geometry          Neighborhood
# 0         2   POINT (9.24166 45.5161)               Adriano
# 1         9  POINT (9.18592 45.51936)  Niguarda - Cà Granda
# 2         2  POINT (9.20112 45.48806)              Centrale
# 3         2  POINT (9.20605 45.48259)              Centrale
# 4         7   POINT (9.10339 45.4599)          Forze Armate
# Total rows: 910

# %% [markdown]
# ## Universities

# %%
# Load the GeoDataFrame
universities = gpd.read_file("geojson_files/ds94_universita__final.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != universities.crs:
    universities = universities.to_crs(gdf_combined.crs)

# Perform the spatial join
PolyUniversity = gpd.sjoin(universities, gdf_combined, how="left", predicate="within")
PolyUniversity = PolyUniversity[~PolyUniversity["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolyUniversity
# Out:
#     COD_VIA CIVICO BARRATO              X              Y  \
# 0      1523      3    None  1514766.63459   5039559.3158
# 1      4012      1    None   1515116.2967  5033570.58859
# 2      2177     42    None  1517013.18358  5036277.91279
# 3      2177     42    None  1517013.18358  5036277.91279
# 4       530      1    None  1514606.84139  5034224.99129
# ..      ...    ...     ...            ...            ...
# 706     122     28    None  1514697.15561  5035450.18718
# 707     122     28    None  1514697.15561  5035450.18718
# 708     122     28    None  1514697.15561  5035450.18718
# 709     122     28    None  1514697.15561  5035450.18718
# 710     332      5    None    1515155.604   5034263.5117
#
#                              DENOMINAZ   CATEGORIA    TIPOLOGIA    SOTTOTIPO  \
# 0    UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 1    UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 2    UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 3    UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 4    UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# ..                                 ...         ...          ...          ...
# 706   ACCADEMIA DI BELLE ARTI DI BRERA  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 707   ACCADEMIA DI BELLE ARTI DI BRERA  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 708   ACCADEMIA DI BELLE ARTI DI BRERA  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 709   ACCADEMIA DI BELLE ARTI DI BRERA  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 710  UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
#
#     PROPRIETA  ...          T_SEDE MUNICIPIO ID_NIL  \
# 0    PUBBLICA  ...     EX ISTITUTO         9     14
# 1    PUBBLICA  ...     EX ISTITUTO         1      5
# 2    PUBBLICA  ...  SEDE DIDATTICA         3     21
# 3    PUBBLICA  ...     EX ISTITUTO         3     21
# 4    PUBBLICA  ...  SEDE DIDATTICA         1      1
# ..        ...  ...             ...       ...    ...
# 706  PUBBLICA  ...  SEDE DIDATTICA         1      2
# 707  PUBBLICA  ...  SEDE DIDATTICA         1      2
# 708  PUBBLICA  ...  SEDE DIDATTICA         1      2
# 709  PUBBLICA  ...  SEDE DIDATTICA         1      2
# 710  PUBBLICA  ...              nn         1      1
#
#                                                    NIL  \
# 0    NIGUARDA - CA' GRANDA - PRATO CENTENARO - Q.RE...
# 1                     PORTA VIGENTINA - PORTA LODOVICA
# 2        BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE
# 3        BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE
# 4                                                DUOMO
# ..                                                 ...
# 706                                              BRERA
# 707                                              BRERA
# 708                                              BRERA
# 709                                              BRERA
# 710                                              DUOMO
#
#                                  Location LONG_X_4326 LAT_Y_4326  \
# 0    (45.5092296526866, 9.18868084450537)    9.188681  45.509230
# 1    (45.4553179955712, 9.19297324638358)    9.192973  45.455318
# 2    (45.4796430022321, 9.21732651188301)    9.217327  45.479643
# 3    (45.4796430022321, 9.21732651188301)    9.217327  45.479643
# 4    (45.4612190660429, 9.18647705815211)    9.186477  45.461219
# ..                                    ...         ...        ...
# 706  (45.4722451291283, 9.18766875739009)    9.187669  45.472245
# 707  (45.4722451291283, 9.18766875739009)    9.187669  45.472245
# 708  (45.4722451291283, 9.18766875739009)    9.187669  45.472245
# 709  (45.4722451291283, 9.18766875739009)    9.187669  45.472245
# 710  (45.4615541336369, 9.19349725268074)    9.193497  45.461554
#
#                      geometry index_right            Neighborhood
# 0    POINT (9.18868 45.50923)        43.0    Niguarda - Cà Granda
# 1    POINT (9.19297 45.45532)        80.0               Vigentina
# 2    POINT (9.21733 45.47964)        11.0  Buenos Aires - Venezia
# 3    POINT (9.21733 45.47964)        11.0  Buenos Aires - Venezia
# 4    POINT (9.18648 45.46122)        21.0                   Duomo
# ..                        ...         ...                     ...
# 706  POINT (9.18767 45.47225)         9.0                   Brera
# 707  POINT (9.18767 45.47225)         9.0                   Brera
# 708  POINT (9.18767 45.47225)         9.0                   Brera
# 709  POINT (9.18767 45.47225)         9.0                   Brera
# 710   POINT (9.1935 45.46155)        21.0                   Duomo
#
# [705 rows x 28 columns]

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolyUniversity[PolyUniversity.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates.sort_values(by = 'X')
# Out:
#     COD_VIA CIVICO BARRATO              X              Y  \
# 262    6575     66    None  1509973.54799  5035564.35701
# 261    6575     66    None  1509973.54799  5035564.35701
# 31     6575     66    None  1509973.54799  5035564.35701
# 690    5291     19    None    1511866.328    5032420.898
# 691    5291     19    None    1511866.328    5032420.898
# ..      ...    ...     ...            ...            ...
# 617    2530     58    None  1520932.72524  5039319.11175
# 616    2530     58    None  1520932.72524  5039319.11175
# 615    2530     58    None  1520932.72524  5039319.11175
# 622    2530     58    None  1520932.72524  5039319.11175
# 620    2530     58    None  1520932.72524  5039319.11175
#
#                              DENOMINAZ   CATEGORIA    TIPOLOGIA    SOTTOTIPO  \
# 262  UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 261  UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 31   UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 690                      SAE INSTITUTE  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 691                      SAE INSTITUTE  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# ..                                 ...         ...          ...          ...
# 617           VITA-SALUTE SAN RAFFAELE  ISTRUZIONE         None         None
# 616           VITA-SALUTE SAN RAFFAELE  ISTRUZIONE         None         None
# 615           VITA-SALUTE SAN RAFFAELE  ISTRUZIONE         None         None
# 622           VITA-SALUTE SAN RAFFAELE  ISTRUZIONE         None         None
# 620           VITA-SALUTE SAN RAFFAELE  ISTRUZIONE         None         None
#
#     PROPRIETA  ...          T_SEDE MUNICIPIO ID_NIL  \
# 262  PUBBLICA  ...  SEDE DIDATTICA         7     60
# 261  PUBBLICA  ...  SEDE DIDATTICA         7     60
# 31   PUBBLICA  ...  SEDE DIDATTICA         7     60
# 690   PRIVATA  ...        ISTITUTO         6     45
# 691   PRIVATA  ...      SEDE CORSO         6     45
# ..        ...  ...             ...       ...    ...
# 617   PRIVATA  ...  SEDE DIDATTICA         3     18
# 616   PRIVATA  ...        FACOLTA'         3     18
# 615   PRIVATA  ...        FACOLTA'         3     18
# 622   PRIVATA  ...  SEDE DIDATTICA         3     18
# 620   PRIVATA  ...  SEDE DIDATTICA         3     18
#
#                                  NIL                              Location  \
# 262               STADIO - IPPODROMI  (45.4733558900766, 9.12724128805707)
# 261               STADIO - IPPODROMI  (45.4733558900766, 9.12724128805707)
# 31                STADIO - IPPODROMI  (45.4733558900766, 9.12724128805707)
# 690        MONCUCCO - SAN CRISTOFORO  (45.4450321504593, 9.15138079547624)
# 691        MONCUCCO - SAN CRISTOFORO  (45.4450321504593, 9.15138079547624)
# ..                               ...                                   ...
# 617  CIMIANO - ROTTOLE - Q.RE FELTRE  (45.5069101894498, 9.26760542541493)
# 616  CIMIANO - ROTTOLE - Q.RE FELTRE  (45.5069101894498, 9.26760542541493)
# 615  CIMIANO - ROTTOLE - Q.RE FELTRE  (45.5069101894498, 9.26760542541493)
# 622  CIMIANO - ROTTOLE - Q.RE FELTRE  (45.5069101894498, 9.26760542541493)
# 620  CIMIANO - ROTTOLE - Q.RE FELTRE  (45.5069101894498, 9.26760542541493)
#
#     LONG_X_4326 LAT_Y_4326                  geometry index_right  \
# 262    9.127241  45.473356  POINT (9.12724 45.47336)        66.0
# 261    9.127241  45.473356  POINT (9.12724 45.47336)        66.0
# 31     9.127241  45.473356  POINT (9.12724 45.47336)        66.0
# 690    9.151381  45.445032  POINT (9.15138 45.44503)        65.0
# 691    9.151381  45.445032  POINT (9.15138 45.44503)        65.0
# ..          ...        ...                       ...         ...
# 617    9.267605  45.506910  POINT (9.26761 45.50691)        50.0
# 616    9.267605  45.506910  POINT (9.26761 45.50691)        50.0
# 615    9.267605  45.506910  POINT (9.26761 45.50691)        50.0
# 622    9.267605  45.506910  POINT (9.26761 45.50691)        50.0
# 620    9.267605  45.506910  POINT (9.26761 45.50691)        50.0
#
#                Neighborhood
# 262                San Siro
# 261                San Siro
# 31                 San Siro
# 690          San Cristoforo
# 691          San Cristoforo
# ..                      ...
# 617  Parco Lambro - Cimiano
# 616  Parco Lambro - Cimiano
# 615  Parco Lambro - Cimiano
# 622  Parco Lambro - Cimiano
# 620  Parco Lambro - Cimiano
#
# [617 rows x 28 columns]

# %%
# There is one row for each faculty of the university
PolyUniversity[PolyUniversity['X']=='1509973.54799'][['DENOMINAZ','FACOLTA','T_LAUREA']]
# Out:
#                              DENOMINAZ   FACOLTA                  T_LAUREA
# 31   UNIVERSITA' DEGLI STUDI DI MILANO  MEDICINA  EDUCAZIONE PROFESSIONALE
# 261  UNIVERSITA' DEGLI STUDI DI MILANO  MEDICINA      MEDICINA E CHIRURGIA
# 262  UNIVERSITA' DEGLI STUDI DI MILANO  MEDICINA           INFERMERIESTICA

# %%
# Removing the dupes, but keeping the different faculties
PolyUniversity = PolyUniversity.drop_duplicates(subset=['DENOMINAZ','FACOLTA','geometry'])
PolyUniversity
# Out:
#     COD_VIA CIVICO BARRATO              X              Y  \
# 0      1523      3    None  1514766.63459   5039559.3158
# 1      4012      1    None   1515116.2967  5033570.58859
# 2      2177     42    None  1517013.18358  5036277.91279
# 4       530      1    None  1514606.84139  5034224.99129
# 5       530      1    None  1514609.14441  5034224.81499
# ..      ...    ...     ...            ...            ...
# 680    3072      4    None  1516395.58579   5034265.4612
# 687    3072      4    None  1516395.58579   5034265.4612
# 690    5291     19    None    1511866.328    5032420.898
# 693     122     28    None  1514697.15561  5035450.18718
# 710     332      5    None    1515155.604   5034263.5117
#
#                              DENOMINAZ   CATEGORIA    TIPOLOGIA    SOTTOTIPO  \
# 0    UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 1    UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 2    UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 4    UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 5    UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# ..                                 ...         ...          ...          ...
# 680        IED ISTITUTO EUROPEO DESIGN  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 687        IED ISTITUTO EUROPEO DESIGN  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 690                      SAE INSTITUTE  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 693   ACCADEMIA DI BELLE ARTI DI BRERA  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
# 710  UNIVERSITA' DEGLI STUDI DI MILANO  ISTRUZIONE  UNIVERSITA'  UNIVERSITA'
#
#     PROPRIETA  ...          T_SEDE MUNICIPIO ID_NIL  \
# 0    PUBBLICA  ...     EX ISTITUTO         9     14
# 1    PUBBLICA  ...     EX ISTITUTO         1      5
# 2    PUBBLICA  ...  SEDE DIDATTICA         3     21
# 4    PUBBLICA  ...  SEDE DIDATTICA         1      1
# 5    PUBBLICA  ...  SEDE DIDATTICA         1      1
# ..        ...  ...             ...       ...    ...
# 680   PRIVATA  ...  SEDE DIDATTICA         4     26
# 687   PRIVATA  ...  SEDE DIDATTICA         4     26
# 690   PRIVATA  ...        ISTITUTO         6     45
# 693  PUBBLICA  ...       ACCADEMIA         1      2
# 710  PUBBLICA  ...              nn         1      1
#
#                                                    NIL  \
# 0    NIGUARDA - CA' GRANDA - PRATO CENTENARO - Q.RE...
# 1                     PORTA VIGENTINA - PORTA LODOVICA
# 2        BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE
# 4                                                DUOMO
# 5                                                DUOMO
# ..                                                 ...
# 680                                         XXII MARZO
# 687                                         XXII MARZO
# 690                          MONCUCCO - SAN CRISTOFORO
# 693                                              BRERA
# 710                                              DUOMO
#
#                                  Location LONG_X_4326 LAT_Y_4326  \
# 0    (45.5092296526866, 9.18868084450537)    9.188681  45.509230
# 1    (45.4553179955712, 9.19297324638358)    9.192973  45.455318
# 2    (45.4796430022321, 9.21732651188301)    9.217327  45.479643
# 4    (45.4612190660429, 9.18647705815211)    9.186477  45.461219
# 5    (45.4612174312071, 9.18650650998961)    9.186507  45.461217
# ..                                    ...         ...        ...
# 680  (45.4615437598319, 9.20935752663003)    9.209358  45.461544
# 687  (45.4615437598319, 9.20935752663003)    9.209358  45.461544
# 690  (45.4450321504593, 9.15138079547624)    9.151381  45.445032
# 693  (45.4722451291283, 9.18766875739009)    9.187669  45.472245
# 710  (45.4615541336369, 9.19349725268074)    9.193497  45.461554
#
#                      geometry index_right            Neighborhood
# 0    POINT (9.18868 45.50923)        43.0    Niguarda - Cà Granda
# 1    POINT (9.19297 45.45532)        80.0               Vigentina
# 2    POINT (9.21733 45.47964)        11.0  Buenos Aires - Venezia
# 4    POINT (9.18648 45.46122)        21.0                   Duomo
# 5    POINT (9.18651 45.46122)        21.0                   Duomo
# ..                        ...         ...                     ...
# 680  POINT (9.20936 45.46154)        83.0              XXII Marzo
# 687  POINT (9.20936 45.46154)        83.0              XXII Marzo
# 690  POINT (9.15138 45.44503)        65.0          San Cristoforo
# 693  POINT (9.18767 45.47225)         9.0                   Brera
# 710   POINT (9.1935 45.46155)        21.0                   Duomo
#
# [222 rows x 28 columns]

# %%
# Keeping only relevant variables
PolyUniversity = PolyUniversity[["DENOMINAZ", "MUNICIPIO", "INDIRIZZO", "FACOLTA", "PROPRIETA",
                             "geometry", "Neighborhood"]].reset_index(drop=True)

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolyUniversity[PolyUniversity.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [DENOMINAZ, MUNICIPIO, INDIRIZZO, FACOLTA, PROPRIETA, geometry, Neighborhood]
# Index: []

# %%
# Saving the file
PolyUniversity.to_file("PolyUniversity.geojson", driver="GeoJSON")

# %% [markdown]
# ## Coworking spaces

# %%
# Load the GeoDataFrame
coworking = gpd.read_file("geojson_files/coworking_joined_f.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != coworking.crs:
    coworking = coworking.to_crs(gdf_combined.crs)

# Perform the spatial join
PolyCoworking = gpd.sjoin(coworking, gdf_combined, how="left", predicate="within")
PolyCoworking = PolyCoworking[~PolyCoworking["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolyCoworking
# Out:
#                        SPAZIO         TIPOLOGIA  \
# 0       A&B STAZIONE CENTRALE  SPAZIO COWORKING
# 1    A&B PIAZZA ABBIATEGRASSO  SPAZIO COWORKING
# 2            AVANZI COWORKING  SPAZIO COWORKING
# 3      OHWORKING MILANO ISOLA  SPAZIO COWORKING
# 4              CAMPO TEATRALE  SPAZIO COWORKING
# ..                        ...               ...
# 105                       M36  SPAZIO COWORKING
# 106                       M45  SPAZIO COWORKING
# 107          UPSIDE COWORKING  SPAZIO COWORKING
# 108      OFFICEFORYOU NOTO 10  SPAZIO COWORKING
# 109         CHANGES COWORKING  SPAZIO COWORKING
#
#                                 Sede                      E_MAIL  \
# 0                 Via Sammartini, 33        sammartini@abserv.it
# 1                      Via Valla, 16             valla@abserv.it
# 2                   Via Ampere, 61/A        coworking@avanzi.org
# 3              Via Medardo Rosso, 18          info@ohworking.com
# 4                 Via Casoretto, 41a  coworking@campoteatrale.it
# ..                               ...                         ...
# 105                     Via Meda, 36              info@meda36.it
# 106                     Via Meda, 45              info@meda45.it
# 107  Via Marco Fabio Quintiliano, 24   upsidecoworking@gmail.com
# 108                     Via Noto, 10        info@officeforyou.it
# 109        Via Bernardo Quaranta, 45   info@changescoworking.com
#
#        TELEFONO_1 TELEFONO_2                             WEB      Aperto da  \
# 0     02 83991190       None                   www.abserv.it     marzo 2015
# 1       02 847421       None                   www.abserv.it   gennaio 2018
# 2       02 305160       None   https://avanzi.org/coworking/     marzo 2011
# 3     02 97377020       None                   ohworking.com     marzo 2020
# 4     02 26113133       None  www.campoteatrale.it/coworking   ottobre 2001
# ..            ...        ...                             ...            ...
# 105    3930059260       None            www.creativitybox.it  novembre 2099
# 106   02 36524276       None             www.coworkmilano.it    maggio 2021
# 107   02 66667710       None         www.upsidecoworking.com    agosto 2021
# 108   02 49421229       None    https://www.officeforyou.it/   gennaio 2021
# 109  02 4958 4615       None        www.changescoworking.com    giugno 2021
#
#                                     Orario di apertura Numero postazioni  ...  \
# 0                                  Tutti i giorni, h24       10 (100 mq)  ...
# 1                                  Tutti i giorni, h24       10 (200 mq)  ...
# 2                    Da lunedì a venerdì 09.00 - 18.00     120 (1000 mq)  ...
# 3    Da lunedì a venerdì 09.00 -18.00. Sabato e dom...       20 (250 mq)  ...
# 4                      Da lunedì a venerdì 9.00- 19.00       16 (622 mq)  ...
# ..                                                 ...               ...  ...
# 105                 Dal lunedì al venerdì, 9.00- 19.00        18 (160mq)  ...
# 106                 Dal lunedì al venerdì, 9.00- 19.00        35 (450mq)  ...
# 107                                Tutti i giorni, h24        10 (148mq)  ...
# 108                                Tutti i giorni, h24        52 (420mq)  ...
# 109                 Dal Lunedì al venerdì, 9.00- 18.00        95 (900mq)  ...
#
#        CAP MUNICIPIO ID_NIL  \
# 0    20125         2     10
# 1    20141         5     42
# 2    20131         3     22
# 3    20159         9     11
# 4    20131         3     20
# ..     ...       ...    ...
# 105  20141         5     43
# 106  20141         5     43
# 107  20138         4     30
# 108  20141         5     38
# 109  20139         5     36
#
#                                                    NIL  \
# 0                     STAZIONE CENTRALE - PONTE SEVESO
# 1    STADERA - CHIESA ROSSA - Q.RE TORRETTA - CONCA...
# 2                                         CITTA' STUDI
# 3                                                ISOLA
# 4                            LORETO - CASORETTO - NOLO
# ..                                                 ...
# 105                                            TIBALDI
# 106                                            TIBALDI
# 107              TALIEDO - MORSENCHIO - Q.RE FORLANINI
# 108                            VIGENTINO - Q.RE FATIMA
# 109                                       SCALO ROMANA
#
#                                     Location LONG_X_4326 LAT_Y_4326  \
# 0    (45.490085099999995, 9.206211999999999)    9.206212  45.490085
# 1                    (45.4343426, 9.1852725)    9.185272  45.434343
# 2                    (45.4839086, 9.2262693)    9.226269  45.483909
# 3                    (45.4897117, 9.1851459)    9.185146  45.489712
# 4            (45.489377499999996, 9.2314013)    9.231401  45.489378
# ..                                       ...         ...        ...
# 105                  (45.4416028, 9.1782342)    9.178234  45.441603
# 106          (45.4400386, 9.179542399999999)    9.179542  45.440039
# 107          (45.450351999999995, 9.2450297)    9.245030  45.450352
# 108                  (45.4304638, 9.1995392)    9.199539  45.430464
# 109          (45.436738299999995, 9.2063618)    9.206362  45.436738
#
#                      geometry index_right  Neighborhood
# 0    POINT (9.20621 45.49009)        14.0      Centrale
# 1    POINT (9.18527 45.43434)        70.0       Stadera
# 2    POINT (9.22627 45.48391)        16.0   Città Studi
# 3    POINT (9.18515 45.48971)        32.0         Isola
# 4     POINT (9.2314 45.48938)        36.0        Loreto
# ..                        ...         ...           ...
# 105   POINT (9.17823 45.4416)        72.0       Tibaldi
# 106  POINT (9.17954 45.44004)        72.0       Tibaldi
# 107  POINT (9.24503 45.45035)        40.0      Mecenate
# 108  POINT (9.19954 45.43046)        61.0     Ripamonti
# 109  POINT (9.20636 45.43674)        68.0  Scalo Romana
#
# [108 rows x 24 columns]

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolyCoworking[PolyCoworking.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates # not real duplicates
# Out:
#                     SPAZIO         TIPOLOGIA                      Sede  \
# 29      POLIHUB S.c.a.r.l.  SPAZIO COWORKING        Via C. Durando, 39
# 36       TECHINNOVA S.P.A.  SPAZIO COWORKING      Via G. Durando, 38/a
# 50               BEPRIME24  SPAZIO COWORKING  Via Santa Maria Valle, 3
# 81  REGUS MILANO CARROBBIO  SPAZIO COWORKING      Via S.Maria Valle, 3
#
#                       E_MAIL    TELEFONO_1  TELEFONO_2  \
# 29      polihub@legalmail.it  02 9177 3000        None
# 36  segreteria@techinnova.eu   02 36706284        None
# 50            info@doriko.it    3485194511  3494901549
# 81     info.italia@regus.com          None        None
#
#                                                   WEB    Aperto da  \
# 29                                     www.polihub.it  aprile 2013
# 36                             https://techinnova.eu/   marzo 2015
# 50                                   www.beprime24.it  luglio 2020
# 81  https://www.regus.com/it-it/italy/milan/via-sa...  luglio 2008
#
#                                    Orario di apertura Numero postazioni  ...  \
# 29                                Tutti i giorni, h24      10 ( 390 mq)  ...
# 36                  Dal lunedì al venerdì, 9.00-18.00       24 (400 mq)  ...
# 50  Fulltime: tutti i giorni, h 24. NetworkingPro:...       50 (350 mq)  ...
# 81  Da lunedì a venerdì, 9.00 -18.00. Tutti i gior...     240 (1447 mq)  ...
#
#       CAP MUNICIPIO ID_NIL     NIL                         Location  \
# 29  20158         9     77  BOVISA          (45.5066147, 9.1635609)
# 36  20158         9     77  BOVISA          (45.5066147, 9.1635609)
# 50  20123         1      1   DUOMO  (45.460157699999996, 9.1842233)
# 81  20123         1      1   DUOMO  (45.460157699999996, 9.1842233)
#
#    LONG_X_4326 LAT_Y_4326                  geometry index_right  Neighborhood
# 29    9.163561  45.506615  POINT (9.16356 45.50661)         8.0        Bovisa
# 36    9.163561  45.506615  POINT (9.16356 45.50661)         8.0        Bovisa
# 50    9.184223  45.460158  POINT (9.18422 45.46016)        21.0         Duomo
# 81    9.184223  45.460158  POINT (9.18422 45.46016)        21.0         Duomo
#
# [4 rows x 24 columns]

# %%
# Keeping only relevant variables
PolyCoworking = PolyCoworking[["SPAZIO", "MUNICIPIO", "Sede", "Orario di apertura", "Numero postazioni",
                             "geometry", "Neighborhood"]]

# %% [markdown]
# ### There are four entries with no info about the opening hour, slightly lowering the quality of the data

# %%
# Rows with NaN
nan_rows = PolyCoworking[PolyCoworking.isna().any(axis=1)]

nan_rows
# Out:
#                           SPAZIO MUNICIPIO                              Sede  \
# 7   CONLAB - SPAZIO DI COWORKING         1                Via S. Vittore, 43
# 8                      CO-SOCIAL         5                    Via U. Dini, 7
# 27         MARE CULTURALE URBANO         7                   Via Gabetti, 15
# 47               COWO BICOCCA 16         9  Viale Sarca n. 336/F Edificio 16
#
#    Orario di apertura Numero postazioni                  geometry  \
# 7                None        16 (260mq)  POINT (9.16812 45.46392)
# 8                None        10 (250mq)  POINT (9.17987 45.42924)
# 27               None        15 (150mq)  POINT (9.12263 45.46818)
# 47               None       20 (250 mq)  POINT (9.21911 45.52308)
#
#              Neighborhood
# 7   Magenta - San Vittore
# 8                 Stadera
# 27           Forze Armate
# 47                Bicocca

# %%
# Saving the file
PolyCoworking.to_file("PolyCoworking.geojson", driver="GeoJSON")

# %% [markdown]
# ## Libraries

# %%
# Load the GeoDataFrame
libraries = gpd.read_file("geojson_files/ds1306-biblioteche.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != libraries.crs:
    libraries = libraries.to_crs(gdf_combined.crs)

# Perform the spatial join
PolyLibraries = gpd.sjoin(libraries, gdf_combined, how="left", predicate="within")
PolyLibraries = PolyLibraries[~PolyLibraries["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolyLibraries
# Out:
#                                    Biblioteche - Sede  \
# 0                                            Accursio
# 1                                              Affori
# 2                Baggio (sede provv. P.zza Stovani 3)
# 3                                           Bibliobus
# 4   Biblioteca Crescenzago (sede provv. P.le Gover...
# 5                                          Calvairate
# 6                                        Cassina Anna
# 7                                        Chiesa Rossa
# 8                                      Dergano Bovisa
# 9                                      Fra Cristoforo
# 10                                        Gallaratese
# 11                                              Harar
# 12                                        Lorenteggio
# 13                                           Niguarda
# 14                                              Oglio
# 15                                          Vigentina
# 16                                     Parco Sempione
# 18                                      Sant'Ambrogio
# 19                                            Sicilia
# 20                                            Sormani
# 21                                            Tibaldi
# 22                                  Valvassori Peroni
# 23                                            Venezia
# 24                                       Villapizzone
# 25                                               Zara
#
#                                  Indirizzo    CAP                 telefono  \
# 0                      Piazzale Accursio 5  20151              02 88464300
# 1                          Viale Affori 21  20161  0288462522 - 0288462526
# 2              sede provv. P.zza Stovani 3  20153              02 88465804
# 3                          Via Bezzecca 18  20135               3357762410
# 4   sede provv. P.le Governo Provvisorio 9  20123              02 88465808
# 5                    Via Ciceri Visconti 1  20137              02 88465801
# 6                      Via Sant'Arnaldo 17  20161            02 884.65800
# 7                 Via San Domenico Savio 3  20142              02 88465991
# 8                        Via Baldinucci 76  20158              02 88465807
# 9                     Via Fra Cristoforo 6  20142              02 88465806
# 10                        Via Quarenghi 21  20151              02 88464270
# 11                           Via Albenga 2  20153              02 88465810
# 12                            Via Odazio 9  20147              02 88465811
# 13                         Via Passerini 5  20162              02 88462542
# 14                            Via Oglio 18  20139            02 884.62971
# 15             Corso di Porta Vigentina 15  20122              02 88465798
# 16                         Viale Cervantes  20121              02 88465812
# 18                      Via San Paolino 18  20142              02 88465814
# 19                            Via Sacco 14  20146              02 88465863
# 20              Corso di Porta Vittoria 6   20122                800880066
# 21                       Viale Tibaldi 41   20136              02 88462920
# 22                Via Valvassori Peroni 56  20133              02 88465095
# 23                          Via Frisi 2/4   20129              02 88465799
# 24                 Via Ferrario Grugnola 3  20156              02 88465815
# 25                          Viale Zara 100  20125             02 884.62823
#
#                                                 Orari  \
# 0   lunedi: chiuso, martedi e giovedi: 9.30-14.30,...
# 1   lunedi: chiuso, martedi e giovedi:14.00-19.00,...
# 2   lunedi: chiuso, martedi e giovedi:9.00-13.30, ...
# 3          Dal lunedi al sabato dalle 9.00 alle 12.30
# 4   lunedi: chiuso, martedi:9.30-14.30, mercoledi ...
# 5                                                n.d.
# 6   lunedi: chiuso, martedi e giovedi:9.30-14.30, ...
# 7    lunedi:chiusa, dal martedi al sabato:10.30-19.00
# 8   lunedi: chiuso, martedi e giovedi: 9.30-14.30,...
# 9   lunedi:14.30-19.00, dal martedi al venerdi:9.0...
# 10  lunedi:chiusa, martedi  e mercoledi:14.00-19.0...
# 11  lunedi:chiusa, martedi:chiuso, mercoledi:14.00...
# 12  lunedi: chiuso, martedi e giovedi:14.00-19.00,...
# 13  lunedi: chiuso, martedi e mercoledÃ¬:14.00-19....
# 14  lunedi: chiuso, martedi e giovedi: 9.30-14.30,...
# 15  lunedi: chiuso, martedi e mercoledi:14.00-19.0...
# 16  lunedi: chiuso, martedi e giovedi: 9.30-14.30,...
# 18  lunedi: chiuso, martedi e giovedi: 9.30-14.30,...
# 19  lunedi:chiuso, dal martedi al venerdi:9.30-14....
# 20  lunedi:chiuso, dal martedi al venerdi:10.30-19...
# 21  lunedi: chiuso, martedi e mercoledi:14.00-19.0...
# 22  lunedi:chiuso, dal martedi al venerdi:10.30-19...
# 23  lunedi: chiuso, martedi e giovedi: 9.30-14.30,...
# 24                                             chiusa
# 25                                             chiusa
#
#                                     E-mail  \
# 0        c.biblioaccursio@comune.milano.it
# 1          c.biblioaffori@comune.milano.it
# 2          c.bibliobaggio@comune.milano.it
# 3             c.bibliobus@comune.milano.it
# 4     c.bibliocrescenzago@comune.milano.it
# 5      c.bibliocalvairate@comune.milano.it
# 6     c.bibliocassinaanna@comune.milano.it
# 7     c.bibliochiesarossa@comune.milano.it
# 8    c.bibliosantambrogio@comune.milano.it
# 9   c.bibliofracristoforo@comune.milano.it
# 10    c.bibliogallaratese@comune.milano.it
# 11          c.biblioharar@comune.milano.it
# 12    c.bibliolorenteggio@comune.milano.it
# 13       c.biblioniguarda@comune.milano.it
# 14          c.bibliooglio@comune.milano.it
# 15      c.bibliovigentina@comune.milano.it
# 16          c.biblioparco@comune.milano.it
# 18   c.bibliosantambrogio@comune.milano.it
# 19        c.bibliosicilia@comune.milano.it
# 20       c.bibliocentrale@comune.milano.it
# 21        c.bibliotibaldi@comune.milano.it
# 22     c.bibliovalvassori@comune.milano.it
# 23        c.bibliovenezia@comune.milano.it
# 24   c.bibliovillapizzone@comune.milano.it
# 25           c.bibliozara@comune.milano.it
#
#                            Mezzi pubblici  \
# 0     bus 48, 57, 69, 90, 91 / tram 14, 1
# 1                                    n.d.
# 2                                    n.d.
# 3                                    n.d.
# 4   bus 44, 51, 53, 56, 75 / M2 (Cimiano)
# 5                                    n.d.
# 6                                    n.d.
# 7                                    n.d.
# 8                                    n.d.
# 9                                    n.d.
# 10                                   n.d.
# 11                                   n.d.
# 12                                   n.d.
# 13                                   n.d.
# 14                                   n.d.
# 15                                   n.d.
# 16                                   n.d.
# 18                                   n.d.
# 19                                   n.d.
# 20                                   n.d.
# 21                                   n.d.
# 22                                   n.d.
# 23                                   n.d.
# 24                                   n.d.
# 25                                   n.d.
#
#                                                  Note MUNICIPIO ID_NIL  \
# 0                 Ritiro prenotazioni su appuntamento         8     71
# 1                 Ritiro prenotazioni su appuntamento         9     80
# 2   per ritirare le prenotazioni o accedere agli s...         7     55
# 3   sara' possibile ritirare i libri prenotati pri...         4     26
# 4                 Ritiro prenotazioni su appuntamento         2     19
# 5                 Ritiro prenotazioni su appuntamento         4     28
# 6   Possibilita' di restituire i documenti presso ...         9     83
# 7   restituire i libri e i multimediali in un cont...         5     42
# 8   Puoi ritirarli solo su appuntamento concordand...         9     77
# 9   per la restituzione, Ã¨ necessario recarsi in ...         5     42
# 10           E' sempre aperto il box restituzione h24         8     65
# 11  scegliere i documenti a scaffale, per un tempo...         7     60
# 12  ritiro prenotazioni e accesso agli scaffali su...         6     49
# 13  E' possibile prenotare online  libri e multime...         9     14
# 14  Restituzione all'ingresso senza prenotazione q...         4     35
# 15                Ritiro prenotazioni su appuntamento         1      5
# 16  Prima di venire in biblioteca dovrai fissare u...         1      8
# 18  Per prenotare ora puoi usare lÃapp gratuita A...         6     46
# 19                Ritiro prenotazioni su appuntamento         7     51
# 20  Per accedere agli spazi e ai servizi della bib...         1      4
# 21      La biblioteca Ã¨ aperta solo su appuntamento.         5      6
# 22  Accesso agli scaffali e ritiro prenotazioni so...         3     22
# 23  accesso solo su appuntamento - sala studio e p...         3     21
# 24  La biblioteca rimane chiusa al pubblico. Altre...         8     71
# 25  La biblioteca rimane chiusa al pubblico. Altre...         2     12
#
#                                                   NIL                Location  \
# 0                 VILLAPIZZONE - CAGNOLA - BOLDINASCO    (45.491398, 9.14615)
# 1                                              AFFORI   (45.516629, 9.167394)
# 2            BAGGIO - Q.RE DEGLI OLMI - Q.RE VALSESIA   (45.463178, 9.091209)
# 3                                          XXII MARZO   (45.460661, 9.213189)
# 4                        PADOVA - TURRO - CRESCENZAGO    (45.49825, 9.225293)
# 5                        UMBRIA - MOLISE - CALVAIRATE    (45.455762, 9.22065)
# 6                                            BRUZZANO   (45.524983, 9.177166)
# 7   STADERA - CHIESA ROSSA - Q.RE TORRETTA - CONCA...    (45.43043, 9.174036)
# 8                                              BOVISA   (45.503666, 9.168445)
# 9   STADERA - CHIESA ROSSA - Q.RE TORRETTA - CONCA...   (45.436191, 9.171878)
# 10  Q.RE GALLARATESE - Q.RE SAN LEONARDO - LAMPUGNANO   (45.496527, 9.115198)
# 11                                 STADIO - IPPODROMI   (45.473901, 9.119611)
# 12                                        GIAMBELLINO    (45.447564, 9.13441)
# 13  NIGUARDA - CA' GRANDA - PRATO CENTENARO - Q.RE...    (45.51531, 9.193187)
# 14                                    LODI - CORVETTO    (45.440521, 9.21846)
# 15                   PORTA VIGENTINA - PORTA LODOVICA   (45.454212, 9.196174)
# 16                                     PARCO SEMPIONE   (45.474486, 9.175011)
# 18                                             BARONA    (45.431247, 9.16323)
# 19                                      PORTA MAGENTA    (45.46506, 9.152063)
# 20                                          GUASTALLA  (45.4621641, 9.198145)
# 21                PORTA TICINESE - CONCA DEL NAVIGLIO   (45.444886, 9.183084)
# 22                                       CITTA' STUDI   (45.479483, 9.237198)
# 23      BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE    (45.474884, 9.20841)
# 24                VILLAPIZZONE - CAGNOLA - BOLDINASCO   (45.499305, 9.147549)
# 25                            MACIACHINI - MAGGIOLINA   (45.497314, 9.195927)
#
#         long        lat                  geometry  index_right  \
# 0   9.146150  45.491398   POINT (9.14615 45.4914)         81.0
# 1   9.167394  45.516629  POINT (9.16739 45.51663)          2.0
# 2   9.091209  45.463178  POINT (9.09121 45.46318)          3.0
# 3   9.213189  45.460661  POINT (9.21319 45.46066)         83.0
# 4   9.225293  45.498250  POINT (9.22529 45.49825)         45.0
# 5   9.220650  45.455762  POINT (9.22065 45.45576)         78.0
# 6   9.177166  45.524983  POINT (9.17717 45.52498)         10.0
# 7   9.174036  45.430430  POINT (9.17404 45.43043)         70.0
# 8   9.168445  45.503666  POINT (9.16844 45.50367)          8.0
# 9   9.171878  45.436191  POINT (9.17188 45.43619)         70.0
# 10  9.115198  45.496527   POINT (9.1152 45.49653)         25.0
# 11  9.119611  45.473901   POINT (9.11961 45.4739)         66.0
# 12  9.134410  45.447564  POINT (9.13441 45.44756)         27.0
# 13  9.193187  45.515310  POINT (9.19319 45.51531)         43.0
# 14  9.218460  45.440521  POINT (9.21846 45.44052)         34.0
# 15  9.196174  45.454212  POINT (9.19617 45.45421)         80.0
# 16  9.175011  45.474486  POINT (9.17501 45.47449)         53.0
# 18  9.163230  45.431247  POINT (9.16323 45.43125)          5.0
# 19  9.152063  45.465060  POINT (9.15206 45.46506)         82.0
# 20  9.198145  45.462164  POINT (9.19814 45.46216)         31.0
# 21  9.183084  45.444886  POINT (9.18308 45.44489)         73.0
# 22  9.237198  45.479483   POINT (9.2372 45.47948)         16.0
# 23  9.208410  45.474884  POINT (9.20841 45.47488)         11.0
# 24  9.147549  45.499305   POINT (9.14755 45.4993)         81.0
# 25  9.195927  45.497314  POINT (9.19593 45.49731)         37.0
#
#                Neighborhood
# 0              Villapizzone
# 1                    Affori
# 2                    Baggio
# 3                XXII Marzo
# 4                    Padova
# 5           Umbria - Molise
# 6                  Bruzzano
# 7                   Stadera
# 8                    Bovisa
# 9                   Stadera
# 10              Gallaratese
# 11                 San Siro
# 12              Giambellino
# 13     Niguarda - Cà Granda
# 14          Lodi - Corvetto
# 15                Vigentina
# 16           Parco Sempione
# 18                   Barona
# 19               Washington
# 20                Guastalla
# 21                 Ticinese
# 22              Città Studi
# 23   Buenos Aires - Venezia
# 24             Villapizzone
# 25  Maciachini - Maggiolina

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolyLibraries[PolyLibraries.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates
# Out:
# Empty GeoDataFrame
# Columns: [Biblioteche - Sede, Indirizzo, CAP, telefono, Orari, E-mail, Mezzi pubblici, Note, MUNICIPIO, ID_NIL, NIL, Location, long, lat, geometry, index_right, Neighborhood]
# Index: []

# %%
# Keeping only relevant variables
PolyLibraries = PolyLibraries[["Biblioteche - Sede", "MUNICIPIO", "Indirizzo",
                             "geometry", "Neighborhood"]]

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolyLibraries[PolyLibraries.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [Biblioteche - Sede, MUNICIPIO, Indirizzo, geometry, Neighborhood]
# Index: []

# %%
# Saving the file
PolyLibraries.to_file("PolyLibraries.geojson", driver="GeoJSON")

# %% [markdown]
# ## Suburban railway

# %%
# Load the GeoDataFrame
trains = gpd.read_file("geojson_files/sistema_ferroviario_urbano_layer_0_stazioni__final.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != trains.crs:
    trains = trains.to_crs(gdf_combined.crs)

# Perform the spatial join
PolyTrains = gpd.sjoin(trains, gdf_combined, how="left", predicate="within")
PolyTrains = PolyTrains[~PolyTrains["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolyTrains
# Out:
#                         Stazione   Ubicazione            Linee  \
# 0                Milano Lancetti  Sotterranea  S1 S2 S5 S6 S13
# 1                Milano Centrale   Superficie   Interregionali
# 2    Milano Porta Garibaldi Sup.   Superficie              S11
# 3                Milano Lambrate   Superficie               S9
# 4   Milano Porta Garibaldi Sott.  Sotterranea  S1 S2 S5 S6 S13
# 5              Milano Repubblica  Sotterranea  S1 S2 S5 S6 S13
# 6           Milano Porta Venezia  Sotterranea  S1 S2 S5 S6 S13
# 7                 Milano Cadorna   Superficie            S3 S4
# 8          Milano Porta Vittoria  Sotterranea  S1 S2 S5 S6 S13
# 9            Milano Porta Genova   Superficie   Interregionali
# 10           Milano Porta Romana   Superficie               S9
# 11         Milano San Cristoforo   Superficie               S9
# 12               Milano Rogoredo   Superficie        S1 S2 S13
# 13    Milano Bruzzano Parco Nord   Superficie            S2 S4
# 15          Milano Greco Pirelli   Superficie           S9 S11
# 17                 Milano Bovisa   Superficie  S1 S2 S3 S4 S13
# 18           Milano Villapizzone   Superficie        S5 S6 S11
# 19                  Milano Dateo  Sotterranea  S1 S2 S5 S6 S13
# 20                 Milano Romolo   Superficie               S9
# 21                Milano  Affori   Superficie            S2 S4
# 22            Milano Domodossola  Sotterranea            S3 S4
# 23              Milano Forlanini   Superficie         S5 S6 S9
#
#                               Note MUNICIPIO ID_NIL  \
# 0   Dati indicativi non ufficiali.         9     78
# 1   Dati indicativi non ufficiali.         2     10
# 2   Dati indicativi non ufficiali.         9      9
# 3   Dati indicativi non ufficiali.         3     22
# 4   Dati indicativi non ufficiali.         9      9
# 5   Dati indicativi non ufficiali.         2     10
# 6   Dati indicativi non ufficiali.         3     21
# 7   Dati indicativi non ufficiali.         1      7
# 8   Dati indicativi non ufficiali.         4     28
# 9   Dati indicativi non ufficiali.         6     50
# 10  Dati indicativi non ufficiali.         5     36
# 11  Dati indicativi non ufficiali.         6     49
# 12  Dati indicativi non ufficiali.         4     35
# 13  Dati indicativi non ufficiali.         9     83
# 15  Dati indicativi non ufficiali.         2     16
# 17  Dati indicativi non ufficiali.         9     77
# 18  Dati indicativi non ufficiali.         9     77
# 19  Dati indicativi non ufficiali.         3     21
# 20  Dati indicativi non ufficiali.         6     44
# 21  Dati indicativi non ufficiali.         9     80
# 22  Dati indicativi non ufficiali.         8     67
# 23  Dati indicativi non ufficiali.         4     25
#
#                                               NIL  LONG_X_4326  LAT_Y_4326  \
# 0                                          FARINI     9.177123   45.493741
# 1                STAZIONE CENTRALE - PONTE SEVESO     9.204197   45.486161
# 2                   PORTA GARIBALDI - PORTA NUOVA     9.186751   45.485593
# 3                                    CITTA' STUDI     9.236898   45.484872
# 4                   PORTA GARIBALDI - PORTA NUOVA     9.186162   45.484334
# 5                STAZIONE CENTRALE - PONTE SEVESO     9.198682   45.480436
# 6   BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE     9.208824   45.475790
# 7                            MAGENTA - S. VITTORE     9.175635   45.468178
# 8                    UMBRIA - MOLISE - CALVAIRATE     9.223610   45.459620
# 9                                    PORTA GENOVA     9.169245   45.453170
# 10                                   SCALO ROMANA     9.209106   45.445605
# 11                                    GIAMBELLINO     9.130274   45.442379
# 12                                LODI - CORVETTO     9.238962   45.433659
# 13                                       BRUZZANO     9.172812   45.533595
# 15                               GORLA - PRECOTTO     9.214696   45.512783
# 17                                         BOVISA     9.159051   45.502698
# 18                                         BOVISA     9.150908   45.502100
# 19  BUENOS AIRES - PORTA VENEZIA - PORTA MONFORTE     9.216684   45.467979
# 20                     PORTA TICINESE - CONCHETTA     9.167786   45.443257
# 21                                         AFFORI     9.167464   45.521241
# 22                                       PORTELLO     9.161725   45.481268
# 23                                        CORSICA     9.236735   45.464466
#
#                                 Location                  geometry  \
# 0   (45.4937410910517, 9.17712322085963)  POINT (9.17712 45.49374)
# 1    (45.486161235226, 9.20419675790644)   POINT (9.2042 45.48616)
# 2     (45.485593393828, 9.1867506782341)  POINT (9.18675 45.48559)
# 3   (45.4848723299094, 9.23689818170729)   POINT (9.2369 45.48487)
# 4   (45.4843344249528, 9.18616229197573)  POINT (9.18616 45.48433)
# 5   (45.4804361647545, 9.19868242499003)  POINT (9.19868 45.48044)
# 6   (45.4757903172868, 9.20882392812955)  POINT (9.20882 45.47579)
# 7   (45.4681776130004, 9.17563533371968)  POINT (9.17564 45.46818)
# 8   (45.4596197232533, 9.22360963993889)  POINT (9.22361 45.45962)
# 9   (45.4531702945483, 9.16924529212752)  POINT (9.16925 45.45317)
# 10   (45.4456052626033, 9.2091058832835)  POINT (9.20911 45.44561)
# 11  (45.4423790951393, 9.13027393739621)  POINT (9.13027 45.44238)
# 12  (45.4336585091805, 9.23896248984017)  POINT (9.23896 45.43366)
# 13  (45.5335952897409, 9.17281164241078)   POINT (9.17281 45.5336)
# 15  (45.5127833377175, 9.21469553385638)   POINT (9.2147 45.51278)
# 17  (45.5026975624513, 9.15905123169957)   POINT (9.15905 45.5027)
# 18   (45.5021001975202, 9.1509083102935)   POINT (9.15091 45.5021)
# 19   (45.4679794780654, 9.2166841331161)  POINT (9.21668 45.46798)
# 20  (45.4432569222744, 9.16778607252269)  POINT (9.16779 45.44326)
# 21  (45.5212407453538, 9.16746360961369)  POINT (9.16746 45.52124)
# 22  (45.4812682361026, 9.16172540146053)  POINT (9.16173 45.48127)
# 23  (45.4644657452816, 9.23673460813619)  POINT (9.23673 45.46447)
#
#     index_right            Neighborhood
# 0          23.0                  Farini
# 1          14.0                Centrale
# 2          24.0    GARIBALDI REPUBBLICA
# 3          16.0             Città Studi
# 4          24.0    GARIBALDI REPUBBLICA
# 5          14.0                Centrale
# 6          11.0  Buenos Aires - Venezia
# 7          38.0   Magenta - San Vittore
# 8          78.0         Umbria - Molise
# 9          74.0                 Tortona
# 10         68.0            Scalo Romana
# 11         27.0             Giambellino
# 12         34.0         Lodi - Corvetto
# 13         10.0                Bruzzano
# 15         79.0             Viale Monza
# 17          8.0                  Bovisa
# 18          8.0                  Bovisa
# 19         11.0  Buenos Aires - Venezia
# 20         42.0                 Navigli
# 21          2.0                  Affori
# 22         56.0                Portello
# 23         18.0                 Corsica

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolyTrains[PolyTrains.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates
# Out:
# Empty GeoDataFrame
# Columns: [Stazione, Ubicazione, Linee, Note, MUNICIPIO, ID_NIL, NIL, LONG_X_4326, LAT_Y_4326, Location, geometry, index_right, Neighborhood]
# Index: []

# %%
# Keeping only relevant variables
PolyTrains = PolyTrains[["Stazione", "Linee", "geometry", "Neighborhood"]].rename(columns={"Stazione": "Nome"})
PolyTrains["Mezzo"] = "Treno"

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolyTrains[PolyTrains.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [Nome, Linee, geometry, Neighborhood, Mezzo]
# Index: []

# %% [markdown]
# ## Metro stops

# %%
# Load the GeoDataFrame
metros = gpd.read_file("geojson_files/tpl_metrofermate.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != metros.crs:
    metros = metros.to_crs(gdf_combined.crs)

# Perform the spatial join
PolyMetros = gpd.sjoin(metros, gdf_combined, how="left", predicate="within")
PolyMetros = PolyMetros[~PolyMetros["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolyMetros
# Out:
#      id_amat           nome linee                  geometry  index_right  \
# 0        869        BOLIVAR     4  POINT (9.15315 45.45532)         74.0
# 1        870     CALIFORNIA     4  POINT (9.16006 45.45755)         74.0
# 2        871        SEGNERI     4  POINT (9.13057 45.44654)         27.0
# 3        872        TOLSTOJ     4   POINT (9.14802 45.4536)         27.0
# 4        873     CONI ZUGNA     4  POINT (9.16491 45.45909)         74.0
# ..       ...            ...   ...                       ...          ...
# 123      993     BANDE NERE     1   POINT (9.13648 45.4615)          4.0
# 126      996       AMENDOLA     1  POINT (9.15097 45.47368)         75.0
# 127      997      AFFORI FN     3  POINT (9.16825 45.52168)          2.0
# 128      998  AFFORI CENTRO     3  POINT (9.17398 45.51355)          2.0
# 129      999  ABBIATEGRASSO     2  POINT (9.17732 45.42999)         70.0
#
#     Neighborhood
# 0        Tortona
# 1        Tortona
# 2    Giambellino
# 3    Giambellino
# 4        Tortona
# ..           ...
# 123   Bande Nere
# 126    Tre Torri
# 127       Affori
# 128       Affori
# 129      Stadera
#
# [109 rows x 6 columns]

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolyMetros[PolyMetros.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates
# Out:
# Empty GeoDataFrame
# Columns: [id_amat, nome, linee, geometry, index_right, Neighborhood]
# Index: []

# %%
# Keeping only relevant variables
PolyMetros = PolyMetros[["nome", "linee", "geometry", "Neighborhood"]].rename(columns={"nome": "Nome",
                                                                                       "linee": "Linee"})
PolyMetros["Mezzo"] = "Metro"

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolyMetros[PolyMetros.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [Nome, Linee, geometry, Neighborhood, Mezzo]
# Index: []

# %% [markdown]
# ## Bus stops

# %%
# Load the GeoDataFrame
busses = gpd.read_file("geojson_files/tpl_fermate.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != busses.crs:
    busses = busses.to_crs(gdf_combined.crs)

# Perform the spatial join
PolyBusses = gpd.sjoin(busses, gdf_combined, how="left", predicate="within")
PolyBusses = PolyBusses[~PolyBusses["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolyBusses
# Out:
#       id_amat                                   ubicazione linee  \
# 2       10018  C.so Sempione, 83 prima di Via E. Filiberto    48
# 4       10022              Via Mosca prima V.Val Cavallina    63
# 5       10023            Via Mosca prima di Via Spinazzola    63
# 6       10024            Via Mosca, 42 dopo Via Spinazzola    63
# 8       10026                Via Bergognone dopo via Foppa    68
# ...       ...                                          ...   ...
# 4681    20159                              S.Cristoforo M4   154
# 4682    20160                               V.le Papiniano   154
# 4683    20161                                     S. Sofia   154
# 4684    20162                                    F. Sforza   154
# 4689    20168                                     Varesina    40
#
#                       geometry  index_right           Neighborhood
# 2     POINT (9.15805 45.48628)         56.0               Portello
# 4     POINT (9.07122 45.45214)         41.0               Muggiano
# 5     POINT (9.07367 45.45359)         41.0               Muggiano
# 6     POINT (9.07352 45.45362)         41.0               Muggiano
# 8       POINT (9.161 45.45767)         74.0                Tortona
# ...                        ...          ...                    ...
# 4681  POINT (9.12916 45.44497)         27.0            Giambellino
# 4682  POINT (9.16914 45.45823)         38.0  Magenta - San Vittore
# 4683   POINT (9.1931 45.45739)         80.0              Vigentina
# 4684   POINT (9.1953 45.45932)         31.0              Guastalla
# 4689  POINT (9.13858 45.50376)         81.0           Villapizzone
#
# [3058 rows x 6 columns]

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolyBusses[PolyBusses.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates # we keep the stop that is on the border between two neighborhoods for both of them
# Out:
#       id_amat         ubicazione linee                  geometry  index_right  \
# 1098    11396  Via Manduria, 102    79  POINT (9.17952 45.40155)          0.0
# 1098    11396  Via Manduria, 102    79  POINT (9.17952 45.40155)         64.0
#
#               Neighborhood
# 1098   Parco delle Abbazie
# 1098  Ronchetto delle Rane

# %%
# Keeping only relevant variables
PolyBusses = PolyBusses[["ubicazione", "linee", "geometry", "Neighborhood"]].rename(columns={"ubicazione": "Nome",
                                                                                       "linee": "Linee"})
PolyBusses["Mezzo"] = "Bus"

# %% [markdown]
# ### There are no missing values

# %%
# Rows with NaN
nan_rows = PolyBusses[PolyBusses.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [Nome, Linee, geometry, Neighborhood, Mezzo]
# Index: []

# %% [markdown]
# ## Concat Train Metro Bus

# %%
# Ensure all GeoDataFrames have the same columns
gdf1 = PolyTrains[["Nome", "Linee", "Mezzo", "geometry", "Neighborhood"]]
gdf2 = PolyMetros[["Nome", "Linee", "Mezzo", "geometry", "Neighborhood"]]
gdf3 = PolyBusses[["Nome", "Linee", "Mezzo", "geometry", "Neighborhood"]]

# Concatenate the three GeoDataFrames
PolyTransport = gpd.GeoDataFrame(pd.concat([gdf1, gdf2, gdf3], ignore_index=True))

# Inspect the combined GeoDataFrame
print(PolyTransport.head())
print(f"Total rows: {len(PolyTransport)}")

# Saving the file
PolyTransport.to_file("PolyTransport.geojson", driver="GeoJSON")
# Out:
#                            Nome            Linee  Mezzo  \
# 0               Milano Lancetti  S1 S2 S5 S6 S13  Treno
# 1               Milano Centrale   Interregionali  Treno
# 2   Milano Porta Garibaldi Sup.              S11  Treno
# 3               Milano Lambrate               S9  Treno
# 4  Milano Porta Garibaldi Sott.  S1 S2 S5 S6 S13  Treno
#
#                    geometry          Neighborhood
# 0  POINT (9.17712 45.49374)                Farini
# 1   POINT (9.2042 45.48616)              Centrale
# 2  POINT (9.18675 45.48559)  GARIBALDI REPUBBLICA
# 3   POINT (9.2369 45.48487)           Città Studi
# 4  POINT (9.18616 45.48433)  GARIBALDI REPUBBLICA
# Total rows: 3189

# %% [markdown]
# ## Supermarkets

# %% [raw]
# [out:json];
# area["name"="Milano"]["boundary"="administrative"]->.searchArea;
# (
#   node["shop"="supermarket"](area.searchArea);
#   way["shop"="supermarket"](area.searchArea);
#   relation["shop"="supermarket"](area.searchArea);
# );
# out body;
# >;
# out skel qt;

# %%
# Load the GeoDataFrame
supermarkets = gpd.read_file("C:/Users/edoar/Downloads/supermarkets.geojson")

# Ensure both GeoDataFrames have the same CRS
if gdf_combined.crs != supermarkets.crs:
    supermarkets = supermarkets.to_crs(gdf_combined.crs)

# Perform the spatial join
PolySupermarkets = gpd.sjoin(supermarkets, gdf_combined, how="left", predicate="within")
PolySupermarkets = PolySupermarkets[~PolySupermarkets["Neighborhood"].isna()]

# Inspect the resulting GeoDataFrame
PolySupermarkets
# Out:
#                    id               @id access addr:city addr:country  \
# 2        way/23911120      way/23911120   None      None         None
# 3        way/24396508      way/24396508   None      None         None
# 4        way/26009942      way/26009942   None      None         None
# 6        way/26971361      way/26971361   None      None         None
# 7        way/27134228      way/27134228   None      None         None
# ..                ...               ...    ...       ...          ...
# 733  node/11773518633  node/11773518633   None      None         None
# 734  node/11773889816  node/11773889816   None      None         None
# 738  node/11926789093  node/11926789093   None      None         None
# 739  node/11932616778  node/11932616778   None      None         None
# 747  node/12521559951  node/12521559951   None    Milano         None
#
#     addr:floor addr:hamlet addr:housename addr:housenumber addr:postcode  ...  \
# 2         None        None           None             None          None  ...
# 3         None        None           None             None          None  ...
# 4         None        None           None             None          None  ...
# 6         None        None           None             None          None  ...
# 7         None        None           None             None          None  ...
# ..         ...         ...            ...              ...           ...  ...
# 733       None        None           None             None          None  ...
# 734       None        None           None             None          None  ...
# 738       None        None           None             None          None  ...
# 739       None        None           None             None          None  ...
# 747       None        None           None               32         20123  ...
#
#     toilets toilets:access toilets:wheelchair  type  \
# 2      None           None               None  None
# 3      None           None               None  None
# 4      None           None               None  None
# 6      None           None               None  None
# 7      None           None               None  None
# ..      ...            ...                ...   ...
# 733    None           None               None  None
# 734    None           None               None  None
# 738    None           None               None  None
# 739    None           None               None  None
# 747    None           None               None  None
#
#                                                website wheelchair zero_waste  \
# 2                                                 None        yes       None
# 3    https://www.esselunga.it/default.aspx?idPage=4...       None       None
# 4    https://www.esselunga.it/cms/negozi/ricerca-ne...       None       None
# 6                                                 None       None       None
# 7                                                 None       None       None
# ..                                                 ...        ...        ...
# 733                                               None       None       None
# 734                                               None       None       None
# 738                                               None       None       None
# 739                                               None       None       None
# 747  https://negozi.naturasi.it/italia/milano/milan...       None       None
#
#                                               geometry index_right  \
# 2    POLYGON ((9.15524 45.44501, 9.15522 45.44481, ...        65.0
# 3    POLYGON ((9.24271 45.45815, 9.24274 45.45817, ...        40.0
# 4    POLYGON ((9.24774 45.47779, 9.24768 45.47794, ...        33.0
# 6    POLYGON ((9.12748 45.46851, 9.12728 45.46821, ...         4.0
# 7    POLYGON ((9.13725 45.47133, 9.13721 45.47086, ...        69.0
# ..                                                 ...         ...
# 733                           POINT (9.17162 45.46887)        38.0
# 734                           POINT (9.19694 45.50837)        43.0
# 738                           POINT (9.20447 45.45109)        55.0
# 739                            POINT (9.1736 45.48113)        67.0
# 747                           POINT (9.17189 45.46908)        38.0
#
#               Neighborhood
# 2           San Cristoforo
# 3                 Mecenate
# 4                 Lambrate
# 6               Bande Nere
# 7                Selinunte
# ..                     ...
# 733  Magenta - San Vittore
# 734   Niguarda - Cà Granda
# 738           Porta Romana
# 739                  Sarpi
# 747  Magenta - San Vittore
#
# [328 rows x 161 columns]

# %%
# Find duplicates based on the 'geometry' column
duplicates = PolySupermarkets[PolySupermarkets.duplicated(subset=['geometry'], keep=False)]

# Inspect the duplicate rows
duplicates
# Out:
# Empty GeoDataFrame
# Columns: [id, @id, access, addr:city, addr:country, addr:floor, addr:hamlet, addr:housename, addr:housenumber, addr:postcode, addr:province, addr:street, addr:unit, air_conditioning, alt_name, amenity, atm, baby_feeding, barrier, branch, brand, brand:website, brand:wikidata, brand:wikipedia, building, building:colour, building:levels, building:material, building:part, changing_table, changing_table:fee, check_date, check_date:opening_hours, colour, comment:en, comment:it, contact:city, contact:email, contact:facebook, contact:fax, contact:housenumber, contact:instagram, contact:phone, contact:phone:2, contact:postcode, contact:street, contact:website, contact:yelp, created_by, cuisine, currency:EUR, delivery, description, designation, diet:dairy_free, diet:fruitarian, diet:gluten_free, diet:halal, diet:kosher, diet:lacto_vegetarian, diet:lactose_free, diet:ovo_vegetarian, diet:pescetarian, diet:raw, diet:vegan, diet:vegetarian, disused:shop, drive_through, email, entrance, facebook, fax, fixme, height, indoor, internet_access, internet_access:fee, kids_area, landuse, layer, level, level:ref, loc_name, long_name, max_level, min_level, name, name:de, name:en, name:it, not:brand:wikidata, note, note:it, office, old_name, old_name:2, opening_hours, opening_hours:signed, opening_hours:url, operator, ...]
# Index: []
#
# [0 rows x 161 columns]

# %%
# Keeping only relevant variables
PolySupermarkets = PolySupermarkets[["name", "geometry", "Neighborhood"]]

# %% [markdown]
# ### There are four supermarkets with a not available name listed

# %%
# Rows with NaN
nan_rows = PolySupermarkets[PolySupermarkets.isna().any(axis=1)]

nan_rows
# Out:
#      name                                           geometry Neighborhood
# 151  None  POLYGON ((9.10075 45.50395, 9.10101 45.50384, ...  Gallaratese
# 409  None                           POINT (9.22037 45.46562)   XXII Marzo
# 527  None                           POINT (9.18773 45.47306)        Brera
# 716  None                           POINT (9.22689 45.47083)  Città Studi

# %%
# Saving the file
PolySupermarkets.to_file("PolySupermarkets.geojson", driver="GeoJSON")
