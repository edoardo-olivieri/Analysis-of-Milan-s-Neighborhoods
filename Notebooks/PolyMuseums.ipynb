# %%
import pandas as pd
import geopandas as gpd
import requests
import time
from shapely.geometry import Point
from geopandas.tools import sjoin

# %%
# Import of the Polygons
gdf_combined = gpd.read_file("C:/Users/edoar/combined_quartieri.geojson")

# %% [markdown]
# # YELP API

# %%
neighborhoods = [f"{name}, Milan" for name in gdf_combined["Neighborhood"].tolist()]
neighborhoods
# Out:
# ['Parco delle Abbazie, Milan',
#  'Adriano, Milan',
#  'Affori, Milan',
#  'Baggio, Milan',
#  'Bande Nere, Milan',
#  'Barona, Milan',
#  'Bicocca, Milan',
#  'Bovisasca, Milan',
#  'Bovisa, Milan',
#  'Brera, Milan',
#  'Bruzzano, Milan',
#  'Buenos Aires - Venezia, Milan',
#  'Cantalupa, Milan',
#  'Cascina Triulza - Expo, Milan',
#  'Centrale, Milan',
#  'Chiaravalle, Milan',
#  'Città Studi, Milan',
#  'Comasina, Milan',
#  'Corsica, Milan',
#  'De Angeli - Monte Rosa, Milan',
#  'Dergano, Milan',
#  'Duomo, Milan',
#  'Ex Om - Morivione, Milan',
#  'Farini, Milan',
#  'GARIBALDI REPUBBLICA, Milan',
#  'Gallaratese, Milan',
#  'Ghisolfa, Milan',
#  'Giambellino, Milan',
#  'Giardini Porta Venezia, Milan',
#  'Gratosoglio - Ticinello, Milan',
#  'Greco, Milan',
#  'Guastalla, Milan',
#  'Isola, Milan',
#  'Lambrate, Milan',
#  'Lodi - Corvetto, Milan',
#  'Lorenteggio, Milan',
#  'Loreto, Milan',
#  'Maciachini - Maggiolina, Milan',
#  'Magenta - San Vittore, Milan',
#  'Maggiore - Musocco, Milan',
#  'Mecenate, Milan',
#  'Muggiano, Milan',
#  'Navigli, Milan',
#  'Niguarda - Cà Granda, Milan',
#  'Ortomercato, Milan',
#  'Padova, Milan',
#  'Pagano, Milan',
#  'Parco Agricolo Sud, Milan',
#  'Parco Bosco In Città, Milan',
#  'Parco Forlanini - Ortica, Milan',
#  'Parco Lambro - Cimiano, Milan',
#  'Parco Monluè - Ponte Lambro, Milan',
#  'Parco Nord, Milan',
#  'Parco Sempione, Milan',
#  'Parco dei Navigli, Milan',
#  'Porta Romana, Milan',
#  'Portello, Milan',
#  'Qt 8, Milan',
#  'Quarto Cagnino, Milan',
#  'Quinto Romano, Milan',
#  'Quintosole, Milan',
#  'Ripamonti, Milan',
#  'Rogoredo, Milan',
#  'Ronchetto Sul Naviglio, Milan',
#  'Ronchetto delle Rane, Milan',
#  'San Cristoforo, Milan',
#  'San Siro, Milan',
#  'Sarpi, Milan',
#  'Scalo Romana, Milan',
#  'Selinunte, Milan',
#  'Stadera, Milan',
#  'Stephenson, Milan',
#  'Tibaldi, Milan',
#  'Ticinese, Milan',
#  'Tortona, Milan',
#  'Tre Torri, Milan',
#  'Trenno, Milan',
#  'Triulzo Superiore, Milan',
#  'Umbria - Molise, Milan',
#  'Viale Monza, Milan',
#  'Vigentina, Milan',
#  'Villapizzone, Milan',
#  'Washington, Milan',
#  'XXII Marzo, Milan',
#  'Forze Armate, Milan']

# %%
# Replace with your Yelp API key
API_KEY = "6CbFJGYPopltfBbkb00hIFGRI4XBrAsccPevTJ53ol4YIuJrF48kEylTmKvEl4-TEP8p0pEc3ydzUsatpgGI5aqSHCsysi5-yWyeJD3V-6al5x6_AcFkw23LehKEZ3Yx"
HEADERS = {"Authorization": f"Bearer {API_KEY}"}

# Constants
businesses_per_request = 48  # Maximum allowed by Yelp per request

def make_request(url, params=None):
    """
    Makes a request to the Yelp API.
    """
    response = requests.get(url, headers=HEADERS, params=params)
    response.raise_for_status()
    return response

def search_businesses(location, term="museum", limit=businesses_per_request, offset=0):
    """
    Searches for businesses (museums) in a given location with pagination.
    """
    url = "https://api.yelp.com/v3/businesses/search"
    params = {
        "location": location,
        "term": term,
        "limit": limit,
        "offset": offset
    }
    response = make_request(url, params=params)
    return response.json().get("businesses", [])

# Initialize data storage
data = []

try:
    for neighborhood in neighborhoods:  # Loop through each neighborhood
        offset = 0
        while True:  # Keep fetching data until no more results
            print(f"Fetching museums in {neighborhood} with offset: {offset}...")

            try:
                # fetch businesses using the current offset and location
                businesses = search_businesses(location=neighborhood, term="museum", limit=businesses_per_request, offset=offset)

                if not businesses:
                    # No more businesses to fetch
                    print(f"No more museums returned for {neighborhood}.")
                    break

                for biz in businesses:
                    name = biz.get("name", "N/A")
                    location_info = biz.get("location", {})
                    address = location_info.get("address1", "N/A")
                    categories = biz.get("categories", [])
                    category_list = [cat.get("title", "") for cat in categories if cat.get("title")]
                    category_str = ", ".join(category_list) if category_list else "N/A"
                    rating = biz.get("rating", "N/A")
                    review_count = biz.get("review_count", "N/A")

                    # Extract coordinates
                    coordinates = biz.get("coordinates", {})
                    latitude = coordinates.get("latitude", None)
                    longitude = coordinates.get("longitude", None)

                    # Append to data
                    data.append({
                        "Fetch Location": neighborhood,
                        "Museum Name": name,
                        "Museum Address": address,
                        "Categories": category_str,
                        "Average Star Rating": rating,
                        "Review Count": review_count,
                        "Latitude": latitude,
                        "Longitude": longitude
                    })

                # Increment offset for the next batch
                offset += len(businesses)

                # Optional: Sleep to respect API rate limits
                time.sleep(0.5)

                # Break if the offset exceeds Yelp's maximum results per query
                if offset >= 240:  # Maximum 240 results per query
                    print(f"Reached maximum results for {neighborhood}.")
                    break

            except requests.HTTPError as he:
                # Log the error and skip this neighborhood
                print(f"HTTP error occurred for {neighborhood}: {he}")
                break

    # Convert the collected data into a DataFrame
    df = pd.DataFrame(data)

    # Convert DataFrame to GeoDataFrame
    df["geometry"] = df.apply(
        lambda row: Point(row["Longitude"], row["Latitude"]) if row["Longitude"] and row["Latitude"] else None,
        axis=1
    )
    Museums = gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:4326")

    # Print summary
    print(Museums.head())
    print(f"Total museums collected: {len(data)}")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Fetching museums in Parco delle Abbazie, Milan with offset: 0...
# Fetching museums in Parco delle Abbazie, Milan with offset: 48...
# Fetching museums in Parco delle Abbazie, Milan with offset: 96...
# Fetching museums in Parco delle Abbazie, Milan with offset: 144...
# Fetching museums in Parco delle Abbazie, Milan with offset: 192...
# Reached maximum results for Parco delle Abbazie, Milan.
# Fetching museums in Adriano, Milan with offset: 0...
# HTTP error occurred for Adriano, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Adriano%2C+Milan&term=museum&limit=48&offset=0
# Fetching museums in Affori, Milan with offset: 0...
# Fetching museums in Affori, Milan with offset: 48...
# Fetching museums in Affori, Milan with offset: 96...
# Fetching museums in Affori, Milan with offset: 103...
# No more museums returned for Affori, Milan.
# Fetching museums in Baggio, Milan with offset: 0...
# Fetching museums in Baggio, Milan with offset: 48...
# Fetching museums in Baggio, Milan with offset: 96...
# Fetching museums in Baggio, Milan with offset: 144...
# Fetching museums in Baggio, Milan with offset: 192...
# Reached maximum results for Baggio, Milan.
# Fetching museums in Bande Nere, Milan with offset: 0...
# Fetching museums in Bande Nere, Milan with offset: 48...
# Fetching museums in Bande Nere, Milan with offset: 96...
# No more museums returned for Bande Nere, Milan.
# Fetching museums in Barona, Milan with offset: 0...
# Fetching museums in Barona, Milan with offset: 48...
# Fetching museums in Barona, Milan with offset: 96...
# Fetching museums in Barona, Milan with offset: 144...
# Fetching museums in Barona, Milan with offset: 192...
# Reached maximum results for Barona, Milan.
# Fetching museums in Bicocca, Milan with offset: 0...
# Fetching museums in Bicocca, Milan with offset: 48...
# Fetching museums in Bicocca, Milan with offset: 96...
# Fetching museums in Bicocca, Milan with offset: 103...
# No more museums returned for Bicocca, Milan.
# Fetching museums in Bovisasca, Milan with offset: 0...
# Fetching museums in Bovisasca, Milan with offset: 48...
# Fetching museums in Bovisasca, Milan with offset: 96...
# Fetching museums in Bovisasca, Milan with offset: 144...
# Fetching museums in Bovisasca, Milan with offset: 192...
# Reached maximum results for Bovisasca, Milan.
# Fetching museums in Bovisa, Milan with offset: 0...
# Fetching museums in Bovisa, Milan with offset: 48...
# Fetching museums in Bovisa, Milan with offset: 96...
# Fetching museums in Bovisa, Milan with offset: 144...
# Fetching museums in Bovisa, Milan with offset: 192...
# Reached maximum results for Bovisa, Milan.
# Fetching museums in Brera, Milan with offset: 0...
# Fetching museums in Brera, Milan with offset: 48...
# Fetching museums in Brera, Milan with offset: 77...
# No more museums returned for Brera, Milan.
# Fetching museums in Bruzzano, Milan with offset: 0...
# Fetching museums in Bruzzano, Milan with offset: 48...
# Fetching museums in Bruzzano, Milan with offset: 96...
# Fetching museums in Bruzzano, Milan with offset: 144...
# Fetching museums in Bruzzano, Milan with offset: 192...
# Reached maximum results for Bruzzano, Milan.
# Fetching museums in Buenos Aires - Venezia, Milan with offset: 0...
# Fetching museums in Buenos Aires - Venezia, Milan with offset: 48...
# Fetching museums in Buenos Aires - Venezia, Milan with offset: 96...
# Fetching museums in Buenos Aires - Venezia, Milan with offset: 118...
# No more museums returned for Buenos Aires - Venezia, Milan.
# Fetching museums in Cantalupa, Milan with offset: 0...
# Fetching museums in Cantalupa, Milan with offset: 48...
# Fetching museums in Cantalupa, Milan with offset: 96...
# No more museums returned for Cantalupa, Milan.
# Fetching museums in Cascina Triulza - Expo, Milan with offset: 0...
# Fetching museums in Cascina Triulza - Expo, Milan with offset: 48...
# Fetching museums in Cascina Triulza - Expo, Milan with offset: 84...
# No more museums returned for Cascina Triulza - Expo, Milan.
# Fetching museums in Centrale, Milan with offset: 0...
# Fetching museums in Centrale, Milan with offset: 44...
# No more museums returned for Centrale, Milan.
# Fetching museums in Chiaravalle, Milan with offset: 0...
# Fetching museums in Chiaravalle, Milan with offset: 48...
# Fetching museums in Chiaravalle, Milan with offset: 75...
# No more museums returned for Chiaravalle, Milan.
# Fetching museums in Città Studi, Milan with offset: 0...
# Fetching museums in Città Studi, Milan with offset: 48...
# Fetching museums in Città Studi, Milan with offset: 76...
# No more museums returned for Città Studi, Milan.
# Fetching museums in Comasina, Milan with offset: 0...
# Fetching museums in Comasina, Milan with offset: 48...
# Fetching museums in Comasina, Milan with offset: 96...
# Fetching museums in Comasina, Milan with offset: 144...
# Fetching museums in Comasina, Milan with offset: 192...
# Reached maximum results for Comasina, Milan.
# Fetching museums in Corsica, Milan with offset: 0...
# Fetching museums in Corsica, Milan with offset: 48...
# Fetching museums in Corsica, Milan with offset: 96...
# Fetching museums in Corsica, Milan with offset: 144...
# Fetching museums in Corsica, Milan with offset: 192...
# Reached maximum results for Corsica, Milan.
# Fetching museums in De Angeli - Monte Rosa, Milan with offset: 0...
# HTTP error occurred for De Angeli - Monte Rosa, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=De+Angeli+-+Monte+Rosa%2C+Milan&term=museum&limit=48&offset=0
# Fetching museums in Dergano, Milan with offset: 0...
# Fetching museums in Dergano, Milan with offset: 48...
# Fetching museums in Dergano, Milan with offset: 96...
# Fetching museums in Dergano, Milan with offset: 144...
# Fetching museums in Dergano, Milan with offset: 192...
# Reached maximum results for Dergano, Milan.
# Fetching museums in Duomo, Milan with offset: 0...
# Fetching museums in Duomo, Milan with offset: 48...
# Fetching museums in Duomo, Milan with offset: 96...
# Fetching museums in Duomo, Milan with offset: 99...
# No more museums returned for Duomo, Milan.
# Fetching museums in Ex Om - Morivione, Milan with offset: 0...
# Fetching museums in Ex Om - Morivione, Milan with offset: 48...
# Fetching museums in Ex Om - Morivione, Milan with offset: 96...
# No more museums returned for Ex Om - Morivione, Milan.
# Fetching museums in Farini, Milan with offset: 0...
# Fetching museums in Farini, Milan with offset: 48...
# Fetching museums in Farini, Milan with offset: 88...
# No more museums returned for Farini, Milan.
# Fetching museums in GARIBALDI REPUBBLICA, Milan with offset: 0...
# Fetching museums in GARIBALDI REPUBBLICA, Milan with offset: 48...
# Fetching museums in GARIBALDI REPUBBLICA, Milan with offset: 92...
# No more museums returned for GARIBALDI REPUBBLICA, Milan.
# Fetching museums in Gallaratese, Milan with offset: 0...
# Fetching museums in Gallaratese, Milan with offset: 48...
# Fetching museums in Gallaratese, Milan with offset: 96...
# Fetching museums in Gallaratese, Milan with offset: 144...
# Fetching museums in Gallaratese, Milan with offset: 192...
# Reached maximum results for Gallaratese, Milan.
# Fetching museums in Ghisolfa, Milan with offset: 0...
# Fetching museums in Ghisolfa, Milan with offset: 48...
# Fetching museums in Ghisolfa, Milan with offset: 96...
# Fetching museums in Ghisolfa, Milan with offset: 144...
# Fetching museums in Ghisolfa, Milan with offset: 192...
# Reached maximum results for Ghisolfa, Milan.
# Fetching museums in Giambellino, Milan with offset: 0...
# Fetching museums in Giambellino, Milan with offset: 48...
# Fetching museums in Giambellino, Milan with offset: 61...
# No more museums returned for Giambellino, Milan.
# Fetching museums in Giardini Porta Venezia, Milan with offset: 0...
# Fetching museums in Giardini Porta Venezia, Milan with offset: 48...
# Fetching museums in Giardini Porta Venezia, Milan with offset: 96...
# Fetching museums in Giardini Porta Venezia, Milan with offset: 100...
# No more museums returned for Giardini Porta Venezia, Milan.
# Fetching museums in Gratosoglio - Ticinello, Milan with offset: 0...
# Fetching museums in Gratosoglio - Ticinello, Milan with offset: 48...
# Fetching museums in Gratosoglio - Ticinello, Milan with offset: 96...
# Fetching museums in Gratosoglio - Ticinello, Milan with offset: 144...
# Fetching museums in Gratosoglio - Ticinello, Milan with offset: 192...
# Reached maximum results for Gratosoglio - Ticinello, Milan.
# Fetching museums in Greco, Milan with offset: 0...
# Fetching museums in Greco, Milan with offset: 48...
# Fetching museums in Greco, Milan with offset: 96...
# Fetching museums in Greco, Milan with offset: 144...
# Fetching museums in Greco, Milan with offset: 192...
# Reached maximum results for Greco, Milan.
# Fetching museums in Guastalla, Milan with offset: 0...
# Fetching museums in Guastalla, Milan with offset: 48...
# Fetching museums in Guastalla, Milan with offset: 63...
# No more museums returned for Guastalla, Milan.
# Fetching museums in Isola, Milan with offset: 0...
# Fetching museums in Isola, Milan with offset: 48...
# Fetching museums in Isola, Milan with offset: 96...
# Fetching museums in Isola, Milan with offset: 144...
# Fetching museums in Isola, Milan with offset: 192...
# Reached maximum results for Isola, Milan.
# Fetching museums in Lambrate, Milan with offset: 0...
# Fetching museums in Lambrate, Milan with offset: 48...
# Fetching museums in Lambrate, Milan with offset: 96...
# Fetching museums in Lambrate, Milan with offset: 99...
# No more museums returned for Lambrate, Milan.
# Fetching museums in Lodi - Corvetto, Milan with offset: 0...
# Fetching museums in Lodi - Corvetto, Milan with offset: 48...
# Fetching museums in Lodi - Corvetto, Milan with offset: 75...
# No more museums returned for Lodi - Corvetto, Milan.
# Fetching museums in Lorenteggio, Milan with offset: 0...
# Fetching museums in Lorenteggio, Milan with offset: 48...
# Fetching museums in Lorenteggio, Milan with offset: 61...
# No more museums returned for Lorenteggio, Milan.
# Fetching museums in Loreto, Milan with offset: 0...
# Fetching museums in Loreto, Milan with offset: 48...
# Fetching museums in Loreto, Milan with offset: 87...
# No more museums returned for Loreto, Milan.
# Fetching museums in Maciachini - Maggiolina, Milan with offset: 0...
# Fetching museums in Maciachini - Maggiolina, Milan with offset: 48...
# Fetching museums in Maciachini - Maggiolina, Milan with offset: 96...
# Fetching museums in Maciachini - Maggiolina, Milan with offset: 144...
# Fetching museums in Maciachini - Maggiolina, Milan with offset: 192...
# Reached maximum results for Maciachini - Maggiolina, Milan.
# Fetching museums in Magenta - San Vittore, Milan with offset: 0...
# Fetching museums in Magenta - San Vittore, Milan with offset: 48...
# Fetching museums in Magenta - San Vittore, Milan with offset: 62...
# No more museums returned for Magenta - San Vittore, Milan.
# Fetching museums in Maggiore - Musocco, Milan with offset: 0...
# Fetching museums in Maggiore - Musocco, Milan with offset: 48...
# Fetching museums in Maggiore - Musocco, Milan with offset: 96...
# Fetching museums in Maggiore - Musocco, Milan with offset: 97...
# No more museums returned for Maggiore - Musocco, Milan.
# Fetching museums in Mecenate, Milan with offset: 0...
# Fetching museums in Mecenate, Milan with offset: 48...
# Fetching museums in Mecenate, Milan with offset: 96...
# Fetching museums in Mecenate, Milan with offset: 144...
# Fetching museums in Mecenate, Milan with offset: 192...
# Reached maximum results for Mecenate, Milan.
# Fetching museums in Muggiano, Milan with offset: 0...
# Fetching museums in Muggiano, Milan with offset: 48...
# Fetching museums in Muggiano, Milan with offset: 96...
# Fetching museums in Muggiano, Milan with offset: 144...
# Fetching museums in Muggiano, Milan with offset: 192...
# Reached maximum results for Muggiano, Milan.
# Fetching museums in Navigli, Milan with offset: 0...
# Fetching museums in Navigli, Milan with offset: 27...
# No more museums returned for Navigli, Milan.
# Fetching museums in Niguarda - Cà Granda, Milan with offset: 0...
# Fetching museums in Niguarda - Cà Granda, Milan with offset: 48...
# Fetching museums in Niguarda - Cà Granda, Milan with offset: 96...
# Fetching museums in Niguarda - Cà Granda, Milan with offset: 100...
# No more museums returned for Niguarda - Cà Granda, Milan.
# Fetching museums in Ortomercato, Milan with offset: 0...
# Fetching museums in Ortomercato, Milan with offset: 32...
# No more museums returned for Ortomercato, Milan.
# Fetching museums in Padova, Milan with offset: 0...
# Fetching museums in Padova, Milan with offset: 48...
# Fetching museums in Padova, Milan with offset: 96...
# Fetching museums in Padova, Milan with offset: 144...
# Fetching museums in Padova, Milan with offset: 192...
# Reached maximum results for Padova, Milan.
# Fetching museums in Pagano, Milan with offset: 0...
# Fetching museums in Pagano, Milan with offset: 48...
# Fetching museums in Pagano, Milan with offset: 96...
# Fetching museums in Pagano, Milan with offset: 100...
# No more museums returned for Pagano, Milan.
# Fetching museums in Parco Agricolo Sud, Milan with offset: 0...
# Fetching museums in Parco Agricolo Sud, Milan with offset: 48...
# Fetching museums in Parco Agricolo Sud, Milan with offset: 96...
# Fetching museums in Parco Agricolo Sud, Milan with offset: 100...
# No more museums returned for Parco Agricolo Sud, Milan.
# Fetching museums in Parco Bosco In Città, Milan with offset: 0...
# Fetching museums in Parco Bosco In Città, Milan with offset: 48...
# Fetching museums in Parco Bosco In Città, Milan with offset: 70...
# No more museums returned for Parco Bosco In Città, Milan.
# Fetching museums in Parco Forlanini - Ortica, Milan with offset: 0...
# Fetching museums in Parco Forlanini - Ortica, Milan with offset: 48...
# Fetching museums in Parco Forlanini - Ortica, Milan with offset: 95...
# No more museums returned for Parco Forlanini - Ortica, Milan.
# Fetching museums in Parco Lambro - Cimiano, Milan with offset: 0...
# Fetching museums in Parco Lambro - Cimiano, Milan with offset: 48...
# Fetching museums in Parco Lambro - Cimiano, Milan with offset: 96...
# Fetching museums in Parco Lambro - Cimiano, Milan with offset: 99...
# No more museums returned for Parco Lambro - Cimiano, Milan.
# Fetching museums in Parco Monluè - Ponte Lambro, Milan with offset: 0...
# Fetching museums in Parco Monluè - Ponte Lambro, Milan with offset: 48...
# Fetching museums in Parco Monluè - Ponte Lambro, Milan with offset: 95...
# No more museums returned for Parco Monluè - Ponte Lambro, Milan.
# Fetching museums in Parco Nord, Milan with offset: 0...
# Fetching museums in Parco Nord, Milan with offset: 48...
# Fetching museums in Parco Nord, Milan with offset: 92...
# No more museums returned for Parco Nord, Milan.
# Fetching museums in Parco Sempione, Milan with offset: 0...
# Fetching museums in Parco Sempione, Milan with offset: 48...
# Fetching museums in Parco Sempione, Milan with offset: 62...
# No more museums returned for Parco Sempione, Milan.
# Fetching museums in Parco dei Navigli, Milan with offset: 0...
# Fetching museums in Parco dei Navigli, Milan with offset: 48...
# Fetching museums in Parco dei Navigli, Milan with offset: 96...
# Fetching museums in Parco dei Navigli, Milan with offset: 144...
# Fetching museums in Parco dei Navigli, Milan with offset: 192...
# Reached maximum results for Parco dei Navigli, Milan.
# Fetching museums in Porta Romana, Milan with offset: 0...
# Fetching museums in Porta Romana, Milan with offset: 48...
# Fetching museums in Porta Romana, Milan with offset: 80...
# No more museums returned for Porta Romana, Milan.
# Fetching museums in Portello, Milan with offset: 0...
# Fetching museums in Portello, Milan with offset: 48...
# Fetching museums in Portello, Milan with offset: 96...
# Fetching museums in Portello, Milan with offset: 144...
# Fetching museums in Portello, Milan with offset: 192...
# Reached maximum results for Portello, Milan.
# Fetching museums in Qt 8, Milan with offset: 0...
# Fetching museums in Qt 8, Milan with offset: 48...
# Fetching museums in Qt 8, Milan with offset: 96...
# Fetching museums in Qt 8, Milan with offset: 144...
# Fetching museums in Qt 8, Milan with offset: 192...
# Reached maximum results for Qt 8, Milan.
# Fetching museums in Quarto Cagnino, Milan with offset: 0...
# Fetching museums in Quarto Cagnino, Milan with offset: 48...
# Fetching museums in Quarto Cagnino, Milan with offset: 96...
# Fetching museums in Quarto Cagnino, Milan with offset: 144...
# Fetching museums in Quarto Cagnino, Milan with offset: 192...
# Reached maximum results for Quarto Cagnino, Milan.
# Fetching museums in Quinto Romano, Milan with offset: 0...
# Fetching museums in Quinto Romano, Milan with offset: 48...
# Fetching museums in Quinto Romano, Milan with offset: 96...
# Fetching museums in Quinto Romano, Milan with offset: 144...
# Fetching museums in Quinto Romano, Milan with offset: 192...
# Reached maximum results for Quinto Romano, Milan.
# Fetching museums in Quintosole, Milan with offset: 0...
# Fetching museums in Quintosole, Milan with offset: 48...
# Fetching museums in Quintosole, Milan with offset: 74...
# No more museums returned for Quintosole, Milan.
# Fetching museums in Ripamonti, Milan with offset: 0...
# Fetching museums in Ripamonti, Milan with offset: 48...
# Fetching museums in Ripamonti, Milan with offset: 93...
# No more museums returned for Ripamonti, Milan.
# Fetching museums in Rogoredo, Milan with offset: 0...
# Fetching museums in Rogoredo, Milan with offset: 48...
# Fetching museums in Rogoredo, Milan with offset: 95...
# No more museums returned for Rogoredo, Milan.
# Fetching museums in Ronchetto Sul Naviglio, Milan with offset: 0...
# Fetching museums in Ronchetto Sul Naviglio, Milan with offset: 48...
# Fetching museums in Ronchetto Sul Naviglio, Milan with offset: 96...
# No more museums returned for Ronchetto Sul Naviglio, Milan.
# Fetching museums in Ronchetto delle Rane, Milan with offset: 0...
# Fetching museums in Ronchetto delle Rane, Milan with offset: 48...
# Fetching museums in Ronchetto delle Rane, Milan with offset: 96...
# No more museums returned for Ronchetto delle Rane, Milan.
# Fetching museums in San Cristoforo, Milan with offset: 0...
# Fetching museums in San Cristoforo, Milan with offset: 48...
# Fetching museums in San Cristoforo, Milan with offset: 96...
# Fetching museums in San Cristoforo, Milan with offset: 144...
# Fetching museums in San Cristoforo, Milan with offset: 192...
# Reached maximum results for San Cristoforo, Milan.
# Fetching museums in San Siro, Milan with offset: 0...
# Fetching museums in San Siro, Milan with offset: 48...
# Fetching museums in San Siro, Milan with offset: 96...
# Fetching museums in San Siro, Milan with offset: 97...
# No more museums returned for San Siro, Milan.
# Fetching museums in Sarpi, Milan with offset: 0...
# Fetching museums in Sarpi, Milan with offset: 48...
# Fetching museums in Sarpi, Milan with offset: 94...
# No more museums returned for Sarpi, Milan.
# Fetching museums in Scalo Romana, Milan with offset: 0...
# Fetching museums in Scalo Romana, Milan with offset: 48...
# Fetching museums in Scalo Romana, Milan with offset: 95...
# No more museums returned for Scalo Romana, Milan.
# Fetching museums in Selinunte, Milan with offset: 0...
# Fetching museums in Selinunte, Milan with offset: 48...
# Fetching museums in Selinunte, Milan with offset: 96...
# Fetching museums in Selinunte, Milan with offset: 144...
# Fetching museums in Selinunte, Milan with offset: 192...
# Reached maximum results for Selinunte, Milan.
# Fetching museums in Stadera, Milan with offset: 0...
# Fetching museums in Stadera, Milan with offset: 48...
# Fetching museums in Stadera, Milan with offset: 74...
# No more museums returned for Stadera, Milan.
# Fetching museums in Stephenson, Milan with offset: 0...
# Fetching museums in Stephenson, Milan with offset: 48...
# Fetching museums in Stephenson, Milan with offset: 96...
# Fetching museums in Stephenson, Milan with offset: 144...
# Fetching museums in Stephenson, Milan with offset: 192...
# Fetching museums in Stephenson, Milan with offset: 232...
# HTTP error occurred for Stephenson, Milan: 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Stephenson%2C+Milan&term=museum&limit=48&offset=232
# Fetching museums in Tibaldi, Milan with offset: 0...
# Fetching museums in Tibaldi, Milan with offset: 48...
# Fetching museums in Tibaldi, Milan with offset: 80...
# No more museums returned for Tibaldi, Milan.
# Fetching museums in Ticinese, Milan with offset: 0...
# Fetching museums in Ticinese, Milan with offset: 48...
# Fetching museums in Ticinese, Milan with offset: 85...
# No more museums returned for Ticinese, Milan.
# Fetching museums in Tortona, Milan with offset: 0...
# Fetching museums in Tortona, Milan with offset: 45...
# No more museums returned for Tortona, Milan.
# Fetching museums in Tre Torri, Milan with offset: 0...
# Fetching museums in Tre Torri, Milan with offset: 32...
# No more museums returned for Tre Torri, Milan.
# Fetching museums in Trenno, Milan with offset: 0...
# Fetching museums in Trenno, Milan with offset: 48...
# Fetching museums in Trenno, Milan with offset: 96...
# Fetching museums in Trenno, Milan with offset: 144...
# Fetching museums in Trenno, Milan with offset: 192...
# Reached maximum results for Trenno, Milan.
# Fetching museums in Triulzo Superiore, Milan with offset: 0...
# Fetching museums in Triulzo Superiore, Milan with offset: 48...
# Fetching museums in Triulzo Superiore, Milan with offset: 89...
# No more museums returned for Triulzo Superiore, Milan.
# Fetching museums in Umbria - Molise, Milan with offset: 0...
# Fetching museums in Umbria - Molise, Milan with offset: 48...
# Fetching museums in Umbria - Molise, Milan with offset: 96...
# Fetching museums in Umbria - Molise, Milan with offset: 144...
# Fetching museums in Umbria - Molise, Milan with offset: 192...
# Reached maximum results for Umbria - Molise, Milan.
# Fetching museums in Viale Monza, Milan with offset: 0...
# Fetching museums in Viale Monza, Milan with offset: 48...
# Fetching museums in Viale Monza, Milan with offset: 96...
# Fetching museums in Viale Monza, Milan with offset: 101...
# No more museums returned for Viale Monza, Milan.
# Fetching museums in Vigentina, Milan with offset: 0...
# Fetching museums in Vigentina, Milan with offset: 38...
# No more museums returned for Vigentina, Milan.
# Fetching museums in Villapizzone, Milan with offset: 0...
# Fetching museums in Villapizzone, Milan with offset: 48...
# Fetching museums in Villapizzone, Milan with offset: 96...
# Fetching museums in Villapizzone, Milan with offset: 144...
# Fetching museums in Villapizzone, Milan with offset: 192...
# Reached maximum results for Villapizzone, Milan.
# Fetching museums in Washington, Milan with offset: 0...
# Fetching museums in Washington, Milan with offset: 48...
# Fetching museums in Washington, Milan with offset: 88...
# No more museums returned for Washington, Milan.
# Fetching museums in XXII Marzo, Milan with offset: 0...
# Fetching museums in XXII Marzo, Milan with offset: 34...
# No more museums returned for XXII Marzo, Milan.
# Fetching museums in Forze Armate, Milan with offset: 0...
# Fetching museums in Forze Armate, Milan with offset: 48...
# Fetching museums in Forze Armate, Milan with offset: 96...
# Fetching museums in Forze Armate, Milan with offset: 144...
# Fetching museums in Forze Armate, Milan with offset: 192...
# Reached maximum results for Forze Armate, Milan.
#                Fetch Location  \
# 0  Parco delle Abbazie, Milan
# 1  Parco delle Abbazie, Milan
# 2  Parco delle Abbazie, Milan
# 3  Parco delle Abbazie, Milan
# 4  Parco delle Abbazie, Milan
#
#                                         Museum Name        Museum Address  \
# 0                              Il Mondo di Leonardo  Piazza della Scala 1
# 1                               Pinacoteca di Brera          Via Brera 28
# 2                                    Armani / Silos     Via Bergognone 40
# 3                               Museo del Novecento         Via Marconi 1
# 4  Museo Nazionale della Scienza e della Tecnologia    Via San Vittore 21
#
#                                   Categories  Average Star Rating  \
# 0                                    Museums                  4.5
# 1  Museums, Landmarks & Historical Buildings                  4.4
# 2                              Art Galleries                  4.4
# 3                                    Museums                  4.2
# 4                                    Museums                  4.2
#
#    Review Count   Latitude  Longitude                  geometry
# 0             8  45.466500   9.189920   POINT (9.18992 45.4665)
# 1            39  45.471962   9.187842  POINT (9.18784 45.47196)
# 2             5  45.452744   9.164432  POINT (9.16443 45.45274)
# 3            36  45.463500   9.191450   POINT (9.19145 45.4635)
# 4            20  45.461129   9.171357  POINT (9.17136 45.46113)
# Total museums collected: 11502

# %%
Museums
# Out:
#                    Fetch Location  \
# 0      Parco delle Abbazie, Milan
# 1      Parco delle Abbazie, Milan
# 2      Parco delle Abbazie, Milan
# 3      Parco delle Abbazie, Milan
# 4      Parco delle Abbazie, Milan
# ...                           ...
# 11497         Forze Armate, Milan
# 11498         Forze Armate, Milan
# 11499         Forze Armate, Milan
# 11500         Forze Armate, Milan
# 11501         Forze Armate, Milan
#
#                                             Museum Name  \
# 0                                  Il Mondo di Leonardo
# 1                                   Pinacoteca di Brera
# 2                                        Armani / Silos
# 3                                   Museo del Novecento
# 4      Museo Nazionale della Scienza e della Tecnologia
# ...                                                 ...
# 11497     Municipio di S. Pellegrino Terme - Biblioteca
# 11498                                      Antiche Mura
# 11499                 Fondazione Castello di Padernello
# 11500                               Seminario Vescovile
# 11501                                  Perrone / Fabio
#
#                 Museum Address  \
# 0         Piazza della Scala 1
# 1                 Via Brera 28
# 2            Via Bergognone 40
# 3                Via Marconi 1
# 4           Via San Vittore 21
# ...                        ...
# 11497        Via S. Carlo, SNC
# 11498      Viale Partigiani 55
# 11499            Via Cavour, 1
# 11500            Via Milano, 5
# 11501  Via Giacomo Bertesi, 27
#
#                                               Categories  Average Star Rating  \
# 0                                                Museums                  4.5
# 1              Museums, Landmarks & Historical Buildings                  4.4
# 2                                          Art Galleries                  4.4
# 3                                                Museums                  4.2
# 4                                                Museums                  4.2
# ...                                                  ...                  ...
# 11497                                 Museums, Libraries                  0.0
# 11498                                            Museums                  2.0
# 11499                                            Museums                  0.0
# 11500  Museums, Elementary Schools, Specialty Schools...                  0.0
# 11501                                            Museums                  0.0
#
#        Review Count   Latitude  Longitude                   geometry
# 0                 8  45.466500   9.189920    POINT (9.18992 45.4665)
# 1                39  45.471962   9.187842   POINT (9.18784 45.47196)
# 2                 5  45.452744   9.164432   POINT (9.16443 45.45274)
# 3                36  45.463500   9.191450    POINT (9.19145 45.4635)
# 4                20  45.461129   9.171357   POINT (9.17136 45.46113)
# ...             ...        ...        ...                        ...
# 11497             0  45.837890   9.664110   POINT (9.66411 45.83789)
# 11498             1  44.902880   8.196650   POINT (8.19665 44.90288)
# 11499             0  45.359052   9.994929   POINT (9.99493 45.35905)
# 11500             0  45.142580  10.001750  POINT (10.00175 45.14258)
# 11501             0  45.140220  10.018870  POINT (10.01887 45.14022)
#
# [11502 rows x 9 columns]

# %%
# Removing the dupes
Museums_nodup = Museums.drop_duplicates(subset=['Museum Name','Museum Address','Categories','Average Star Rating',
                                                        'Review Count','geometry'])
Museums_nodup
# Out:
#                   Fetch Location  \
# 0     Parco delle Abbazie, Milan
# 1     Parco delle Abbazie, Milan
# 2     Parco delle Abbazie, Milan
# 3     Parco delle Abbazie, Milan
# 4     Parco delle Abbazie, Milan
# ...                          ...
# 9930           Stephenson, Milan
# 9945           Stephenson, Milan
# 9946           Stephenson, Milan
# 9947           Stephenson, Milan
# 9948           Stephenson, Milan
#
#                                            Museum Name  \
# 0                                 Il Mondo di Leonardo
# 1                                  Pinacoteca di Brera
# 2                                       Armani / Silos
# 3                                  Museo del Novecento
# 4     Museo Nazionale della Scienza e della Tecnologia
# ...                                                ...
# 9930                       Parrocchia di Ganna - Badia
# 9945                                Monastero di Torba
# 9946                       Fondazione Francesco Pellin
# 9947              Muel Museo Elettronico International
# 9948                 FAI Fondo per L'ambiente Italiano
#
#                   Museum Address                                 Categories  \
# 0           Piazza della Scala 1                                    Museums
# 1                   Via Brera 28  Museums, Landmarks & Historical Buildings
# 2              Via Bergognone 40                              Art Galleries
# 3                  Via Marconi 1                                    Museums
# 4             Via San Vittore 21                                    Museums
# ...                          ...                                        ...
# 9930               Via Perego, 3                                    Museums
# 9945                Via Stazione                                    Museums
# 9946           Via S. Albino, 24                                    Museums
# 9947  Via Francesco del Cairo, 4                                    Museums
# 9948             Piazza Litta, 1                Museums, Recreation Centers
#
#       Average Star Rating  Review Count   Latitude  Longitude  \
# 0                     4.5             8  45.466500   9.189920
# 1                     4.4            39  45.471962   9.187842
# 2                     4.4             5  45.452744   9.164432
# 3                     4.2            36  45.463500   9.191450
# 4                     4.2            20  45.461129   9.171357
# ...                   ...           ...        ...        ...
# 9930                  0.0             0  45.902450   8.822370
# 9945                  3.0             1  45.729044   8.863733
# 9946                  0.0             0  45.800990   8.830980
# 9947                  0.0             0  45.819400   8.825840
# 9948                  0.0             0  45.825610   8.828750
#
#                       geometry
# 0      POINT (9.18992 45.4665)
# 1     POINT (9.18784 45.47196)
# 2     POINT (9.16443 45.45274)
# 3      POINT (9.19145 45.4635)
# 4     POINT (9.17136 45.46113)
# ...                        ...
# 9930  POINT (8.82237 45.90245)
# 9945  POINT (8.86373 45.72904)
# 9946  POINT (8.83098 45.80099)
# 9947   POINT (8.82584 45.8194)
# 9948  POINT (8.82875 45.82561)
#
# [453 rows x 9 columns]

# %%
# Have to be the same type
print(Museums_nodup.crs)  # Restaurants CRS
print(gdf_combined.crs)  # Neighborhood polygons CRS
# Out:
# EPSG:4326
# EPSG:4326

# %% [markdown]
# # Spatial Join

# %%
# Perform the spatial join
joined = sjoin(Museums_nodup, gdf_combined, how="left", predicate="within")

# Check the result
joined
# Out:
#                  Fetch Location  \
# 0    Parco delle Abbazie, Milan
# 1    Parco delle Abbazie, Milan
# 2    Parco delle Abbazie, Milan
# 3    Parco delle Abbazie, Milan
# 4    Parco delle Abbazie, Milan
# ..                          ...
# 448           Stephenson, Milan
# 449           Stephenson, Milan
# 450           Stephenson, Milan
# 451           Stephenson, Milan
# 452           Stephenson, Milan
#
#                                           Museum Name  \
# 0                                Il Mondo di Leonardo
# 1                                 Pinacoteca di Brera
# 2                                      Armani / Silos
# 3                                 Museo del Novecento
# 4    Museo Nazionale della Scienza e della Tecnologia
# ..                                                ...
# 448                       Parrocchia di Ganna - Badia
# 449                                Monastero di Torba
# 450                       Fondazione Francesco Pellin
# 451              Muel Museo Elettronico International
# 452                 FAI Fondo per L'ambiente Italiano
#
#                  Museum Address                                 Categories  \
# 0          Piazza della Scala 1                                    Museums
# 1                  Via Brera 28  Museums, Landmarks & Historical Buildings
# 2             Via Bergognone 40                              Art Galleries
# 3                 Via Marconi 1                                    Museums
# 4            Via San Vittore 21                                    Museums
# ..                          ...                                        ...
# 448               Via Perego, 3                                    Museums
# 449                Via Stazione                                    Museums
# 450           Via S. Albino, 24                                    Museums
# 451  Via Francesco del Cairo, 4                                    Museums
# 452             Piazza Litta, 1                Museums, Recreation Centers
#
#      Average Star Rating  Review Count   Latitude  Longitude  \
# 0                    4.5             8  45.466500   9.189920
# 1                    4.4            39  45.471962   9.187842
# 2                    4.4             5  45.452744   9.164432
# 3                    4.2            36  45.463500   9.191450
# 4                    4.2            20  45.461129   9.171357
# ..                   ...           ...        ...        ...
# 448                  0.0             0  45.902450   8.822370
# 449                  3.0             1  45.729044   8.863733
# 450                  0.0             0  45.800990   8.830980
# 451                  0.0             0  45.819400   8.825840
# 452                  0.0             0  45.825610   8.828750
#
#                      geometry  index_right           Neighborhood
# 0     POINT (9.18992 45.4665)         21.0                  Duomo
# 1    POINT (9.18784 45.47196)          9.0                  Brera
# 2    POINT (9.16443 45.45274)         74.0                Tortona
# 3     POINT (9.19145 45.4635)         21.0                  Duomo
# 4    POINT (9.17136 45.46113)         38.0  Magenta - San Vittore
# ..                        ...          ...                    ...
# 448  POINT (8.82237 45.90245)          NaN                    NaN
# 449  POINT (8.86373 45.72904)          NaN                    NaN
# 450  POINT (8.83098 45.80099)          NaN                    NaN
# 451   POINT (8.82584 45.8194)          NaN                    NaN
# 452  POINT (8.82875 45.82561)          NaN                    NaN
#
# [453 rows x 11 columns]

# %%
joined[joined['Museum Name']=='Pinacoteca di Brera'] # correct
# Out:
#                Fetch Location          Museum Name Museum Address  \
# 1  Parco delle Abbazie, Milan  Pinacoteca di Brera   Via Brera 28
#
#                                   Categories  Average Star Rating  \
# 1  Museums, Landmarks & Historical Buildings                  4.4
#
#    Review Count   Latitude  Longitude                  geometry  index_right  \
# 1            39  45.471962   9.187842  POINT (9.18784 45.47196)          9.0
#
#   Neighborhood
# 1        Brera

# %%
joined.nunique()
# Out:
# Fetch Location          12
# Museum Name            440
# Museum Address         433
# Categories              67
# Average Star Rating     26
# Review Count            43
# Latitude               446
# Longitude              446
# geometry               446
# index_right             26
# Neighborhood            26
# dtype: int64

# %%
# Remove rows where the geometry is NaN
PolyMuseums = joined[~joined["Neighborhood"].isna()]

# Reset the index if needed
PolyMuseums = PolyMuseums.reset_index(drop=True)

# Keeping only relevant variables
PolyMuseums = PolyMuseums[["Museum Name", "Museum Address", "Categories", "Average Star Rating",
                           "Review Count", "geometry", "Neighborhood"]]
# Print the cleaned GeoDataFrame
PolyMuseums
# Out:
#                                          Museum Name  \
# 0                               Il Mondo di Leonardo
# 1                                Pinacoteca di Brera
# 2                                     Armani / Silos
# 3                                Museo del Novecento
# 4   Museo Nazionale della Scienza e della Tecnologia
# ..                                               ...
# 93                      Resti del Mausoleo Imperiale
# 94                  Studio Museo Achille Castiglioni
# 95                                   Pietà Rondanini
# 96                                   Palazzo Morando
# 97                                Domm International
#
#               Museum Address                                 Categories  \
# 0       Piazza della Scala 1                                    Museums
# 1               Via Brera 28  Museums, Landmarks & Historical Buildings
# 2          Via Bergognone 40                              Art Galleries
# 3              Via Marconi 1                                    Museums
# 4         Via San Vittore 21                                    Museums
# ..                       ...                                        ...
# 93     Via degli Olivetani 1  Landmarks & Historical Buildings, Museums
# 94        Piazza Castello 27                                    Museums
# 95         Piazza Castello 4                                    Museums
# 96         Via Sant'Andrea 6  Landmarks & Historical Buildings, Museums
# 97  Via Rossini Gioacchino 1    Museums, Travel Services, Art Galleries
#
#     Average Star Rating  Review Count                  geometry  \
# 0                   4.5             8   POINT (9.18992 45.4665)
# 1                   4.4            39  POINT (9.18784 45.47196)
# 2                   4.4             5  POINT (9.16443 45.45274)
# 3                   4.2            36   POINT (9.19145 45.4635)
# 4                   4.2            20  POINT (9.17136 45.46113)
# ..                  ...           ...                       ...
# 93                  0.0             0  POINT (9.16843 45.46179)
# 94                  0.0             0   POINT (9.1772 45.46958)
# 95                  0.0             0  POINT (9.17881 45.46981)
# 96                  4.5             4  POINT (9.19639 45.46877)
# 97                  0.0             0  POINT (9.20419 45.46938)
#
#              Neighborhood
# 0                   Duomo
# 1                   Brera
# 2                 Tortona
# 3                   Duomo
# 4   Magenta - San Vittore
# ..                    ...
# 93  Magenta - San Vittore
# 94                  Duomo
# 95                  Duomo
# 96                  Duomo
# 97              Guastalla
#
# [98 rows x 7 columns]

# %% [markdown]
# ### In contrast with the restaurants dataframe, this time there are no NaNs in the data retrieved, therefore this dataframe can be considered of high quality

# %%
# Rows with NaN
nan_rows = PolyMuseums[PolyMuseums.isna().any(axis=1)]

nan_rows
# Out:
# Empty GeoDataFrame
# Columns: [Museum Name, Museum Address, Categories, Average Star Rating, Review Count, Neighborhood, geometry]
# Index: []
